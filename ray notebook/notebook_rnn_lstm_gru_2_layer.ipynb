# %% [markdown]
# #### RNN, LSTM, GRU classification of mouse wheel movement based on Steinmetz `spks` dataset and code from [nma](https://deeplearning.neuromatch.io/projects/Neuroscience/neuro_seq_to_seq.html)
#
# __Note__: You must restart the notebook for training the LSTM and GRU models and each time you rerun a model. This appears to be an issue of the previous model remaining on the GPU after training.

# %% [markdown]
# ##### Imports

# %%
# Imports
import torch
import random
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets, io, models, ops, transforms, utils
from matplotlib import pyplot as plt

# %% [markdown]
# ##### Device

# %%
# @title Set device (GPU or CPU). Execute `set_device()`

# Inform the user if the notebook uses GPU or CPU.

def set_device():
  """
  Set the device. CUDA if available, CPU otherwise

  Args:
    None

  Returns:
    Nothing
  """
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
  else:
    print("GPU is enabled in this notebook.")

  return device

# %% [markdown]
# ##### Set random seed

# %%
# @markdown Executing `set_seed(seed=seed)` you are setting the seed

# For DL its critical to set the random seed so that students can have a
# baseline to compare their results to expected results.
# Read more here: https://pytorch.org/docs/stable/notes/randomness.html

# Call `set_seed` function in the exercises to ensure reproducibility.

def set_seed(seed=None, seed_torch=True):
  """
  Function that controls randomness. NumPy and random modules must be imported.

  Args:
    seed : Integer
      A non-negative integer that defines the random state. Default is `None`.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors, so pytorch module
      must be imported. Default is `True`.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):
  """
  DataLoader will reseed workers following randomness in
  multi-process data loading algorithm.

  Args:
    worker_id: integer
      ID of subprocess to seed. 0 means that
      the data will be loaded in the main process
      Refer: https://pytorch.org/docs/stable/data.html#data-loading-randomness for more details

  Returns:
    Nothing
  """
  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)

# %%
SEED = 2021
set_seed(seed=SEED)
device = set_device()
# Out:
# Random seed 2021 has been set.
# GPU is enabled in this notebook.

# %% [markdown]
# ##### Data retrieval

# %%
# store the dataset files in the datasets folder
import os, requests

fname = []
ds = "../datasets"

for j in range(3):
  fname.append('steinmetz_part%d.npz'%j)
url = ["https://osf.io/agvxh/download"]
url.append("https://osf.io/uv3mw/download")
url.append("https://osf.io/ehmw2/download")

for j in range(len(url)):
  if not os.path.isfile("/".join([ds, fname[j]])):
    try:
      r = requests.get(url[j])
    except requests.ConnectionError:
      print("!!! Failed to download data !!!")
    else:
      if r.status_code != requests.codes.ok:
        print("!!! Failed to download data !!!")
      else:
        with open("/".join([ds, fname[j]]), "wb") as fid:
          fid.write(r.content)

# %%
# data loading
alldat = np.array([])
for j in range(len(fname)):
  alldat = np.hstack((alldat,
                      np.load("/".join([ds, 'steinmetz_part%d.npz'%j]),
                              allow_pickle=True)['dat']))

# %% [markdown]
# ##### Select recording 11

# %%
# select recording 11
dat = alldat[11]

# %% [markdown]
# ##### Format dataset
# An RNN has specific data requirements fed into the network for training, testing, and prediction. The depth of the network in a time or data series is given by `hidden_size`. In the case of the `spks` dataset this is 250 because one trial lasts for this many samples. These are the 250 sequenced datapoints related to the same mouse event trial from the same probe sensor size of 698 neurons over a time period of 2500ms. Further mouse trials are added in sequence in the dataset, where the training and forward algorithms reset to the start of the RNN. This dataset is then 698 neurons wide with 250 datapoints and 340 trials in length, before being split into train and test sets.

# %%
def shuffle_dataset(X, y):
  """
  Helper function to shuffle and split data
  Assumes that set_seed has already been run

  Args:
    X: torch.tensor
      Input data trials X time samples X neurons
    y: torch.tensor
      Corresponding one hot target variables as trials x categories
      
  Returns:
    X: torch.tensor
    y: torch.tensor
  """

  # Number of trials
  N = X.shape[0]

  # Shuffle data
  shuffled_indices = np.random.permutation(N) 
  X = X[shuffled_indices, :, :]
  y = y[shuffled_indices, :]
  
  return X, y

# %%
# data are neurons X trials x time samples, but permute to trials X time samples X neurons
x = torch.tensor(dat['spks']).permute(1,2,0)
x = x[:,50:150,:]

# response is -1, 0, 1, but convert to one hot where 2 takes the place of -1 to satisfy torch one hot
dat['response'][dat['response'] == -1] = 2 
y = torch.as_tensor(dat['response']).long()
y = F.one_hot(y)

# shuffle dataset before split
x, y = shuffle_dataset(x, y)

# split into train (70%), validation(20%) and test(10%) sets using batch size of 34
n_trials = int(x.shape[0])
ntr = int(n_trials * 7 / 10)
nv = int(n_trials * 2 / 10) + ntr

X_train = x[:ntr, :, :].to(device).float()
X_val = x[ntr:nv, :, :].to(device).float()
X_test = x[nv:, :, :].to(device).float()

y_train = y[:ntr].to(device).float()
y_val = y[ntr:nv].to(device).float()
y_test = y[nv:].to(device).float()

# %%
print(y[0])
print(x.shape)
print(y.shape)
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# tensor([0, 0, 1])
# torch.Size([340, 100, 698])
# torch.Size([340, 3])
# torch.Size([238, 100, 698])
# torch.Size([238, 3])
# torch.Size([68, 100, 698])
# torch.Size([68, 3])
# torch.Size([34, 100, 698])
# torch.Size([34, 3])

# %%
##### Visualise data from one trial to show time slicing
plt.figure(figsize = (10, 6))
plt.imshow(x[0,:,:].T, cmap='gray_r', vmax = 3, vmin=0, aspect='auto')
plt.xticks([0, 20, 40, 60, 80], [500, 700, 900, 1100, 1300]) 
plt.xlabel('Time (ms) with 10ms bins')
plt.ylabel('Cell #')
plt.colorbar(orientation='vertical', label='# Spikes in 10ms time bin')
plt.title('Example trial')
plt.show()

# %% [markdown]
# ##### Dataloader

# %%
# batch_size of 34 used to match number of trials
batch_size = 34

# Create DataLoader for training data
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Create DataLoader for validation data
val_dataset = TensorDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Create DataLoader for test data
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### Hyperparameters

# %%
# number of hidden RNN stages, inputs and outputs
hidden_size = x.shape[1]
input_size = x.shape[2]
output_size = y_train.shape[1]
num_layers = 2
learning_rate = 0.001
number_of_epochs = 1000
RNN_number_of_epochs = 300
LSTM_number_of_epochs = 60
GRU_number_of_epochs = 250

# early stopping not used
# RNN_patience = 5
# LSTM_patience = 5
# GRU_patience = 5

# %%
print(hidden_size)
print(input_size)
print(output_size)
# Out:
# 100
# 698
# 3

# %% [markdown]
# ##### Define RNN
# Since the `hidden_size` is 250 we can expect to see either exploding or vanishing gradients in the RNN. For this case we can't expect the RNN to be able to predict well. But, as Dev did, we can reduce the `hidden_size` by slicing off data which doesn't correspond to wheel movement.

# %%
# chatgpt 3.5 generated code
# RNN Model with Softmax
class RNNWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(RNNWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Define the RNN layer
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        
        # Define the fully connected layer to map RNN output to class labels
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.rnn(x, h0)

        # Use only the last time step's output for classification
        out = self.fc(out[:, -1, :]) 

        # Apply softmax activation
        return nn.functional.softmax(out, dim=1)

# %% [markdown]
# ##### Train the RNN: setup

# %%
# chatgpt 3.5 generated code
model = RNNWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ##### Train the RNN and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code
# Training loop
# RNN_total_epochs = number_of_epochs
RNN_total_epochs = RNN_number_of_epochs

# Early stopping parameters
# best_val_loss = float('inf')
# epochs_since_best = 0

# Number of epochs to wait for improvement in validation loss
# patience = RNN_patience

# Lists to store training/validation losses and training/validation accuracies
RNN_train_losses = []  
RNN_val_losses = []    
RNN_train_accuracies = []  
RNN_val_accuracies = []    

for epoch in range(RNN_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    RNN_train_losses.append(average_train_loss)
    RNN_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{RNN_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Check if validation loss has improved
    # if average_val_loss < best_val_loss:
    #    best_val_loss = average_val_loss
    #    epochs_since_best = 0
    # else:
    #    epochs_since_best += 1

    # Store validation loss and accuracy values
    RNN_val_losses.append(average_val_loss)
    RNN_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{RNN_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')

    # Early stopping check
    # if epochs_since_best >= patience:
    #    print(f"Early stopping at epoch {epoch + 1}. Validation loss did not improve for {patience} epochs.")
    #    break

# Plot the losses and accuracies at the end of all epochs
RNN_x_epochs = list(range(1, RNN_total_epochs + 1))
plt.figure(figsize=(7, 5))

# Plot losses (dashed) and accuracies (solid)
plt.plot(RNN_x_epochs, RNN_train_losses, linestyle='--', label='RNN Training Loss')
plt.plot(RNN_x_epochs, RNN_val_losses, linestyle='--', label='RNN Validation Loss')
plt.plot(RNN_x_epochs, RNN_train_accuracies, label='RNN Training Accuracy')
plt.plot(RNN_x_epochs, RNN_val_accuracies, label='RNN Validation Accuracy')
plt.xlabel('RNN Epochs')
plt.ylabel('RNN Loss and Accuracy')
plt.title('RNN Training and Validation Losses for 2 RNN Layers')
plt.legend()

plt.tight_layout()
plt.savefig('eps/RNN_11_2_layer_spks_class.eps')
plt.savefig('svg/RNN_11_2_layer_spks_class.svg')
plt.show()
# Out:
# Epoch [1/300], Training Loss: 1.07413990, Training Accuracy: 0.3950
# Epoch [1/300], Validation Loss: 1.06037259, Validation Accuracy: 0.3676
# Epoch [2/300], Training Loss: 1.01903050, Training Accuracy: 0.4958
# Epoch [2/300], Validation Loss: 1.07440466, Validation Accuracy: 0.3235
# Epoch [3/300], Training Loss: 0.94564327, Training Accuracy: 0.7605
# Epoch [3/300], Validation Loss: 1.04913557, Validation Accuracy: 0.3824
# Epoch [4/300], Training Loss: 0.82345604, Training Accuracy: 0.9118
# Epoch [4/300], Validation Loss: 0.99224031, Validation Accuracy: 0.5882
# Epoch [5/300], Training Loss: 0.69204909, Training Accuracy: 0.9454
# Epoch [5/300], Validation Loss: 0.97689658, Validation Accuracy: 0.5147
# Epoch [6/300], Training Loss: 0.61185835, Training Accuracy: 0.9832
# Epoch [6/300], Validation Loss: 0.96535480, Validation Accuracy: 0.5441
# Epoch [7/300], Training Loss: 0.57810364, Training Accuracy: 0.9874
# Epoch [7/300], Validation Loss: 0.98165503, Validation Accuracy: 0.4853
# Epoch [8/300], Training Loss: 0.56090927, Training Accuracy: 1.0000
# Epoch [8/300], Validation Loss: 0.94045004, Validation Accuracy: 0.6029
# Epoch [9/300], Training Loss: 0.55619430, Training Accuracy: 1.0000
# Epoch [9/300], Validation Loss: 0.93606883, Validation Accuracy: 0.5735
# Epoch [10/300], Training Loss: 0.55428093, Training Accuracy: 1.0000
# Epoch [10/300], Validation Loss: 0.95017183, Validation Accuracy: 0.5441
# Epoch [11/300], Training Loss: 0.55362096, Training Accuracy: 1.0000
# Epoch [11/300], Validation Loss: 0.94904226, Validation Accuracy: 0.5588
# Epoch [12/300], Training Loss: 0.55318932, Training Accuracy: 1.0000
# Epoch [12/300], Validation Loss: 0.93635532, Validation Accuracy: 0.5588
# Epoch [13/300], Training Loss: 0.55291539, Training Accuracy: 1.0000
# Epoch [13/300], Validation Loss: 0.92233443, Validation Accuracy: 0.5441
# Epoch [14/300], Training Loss: 0.55274073, Training Accuracy: 1.0000
# Epoch [14/300], Validation Loss: 0.91358498, Validation Accuracy: 0.5441
# Epoch [15/300], Training Loss: 0.55261993, Training Accuracy: 1.0000
# Epoch [15/300], Validation Loss: 0.91159552, Validation Accuracy: 0.5588
# Epoch [16/300], Training Loss: 0.55251973, Training Accuracy: 1.0000
# Epoch [16/300], Validation Loss: 0.91192627, Validation Accuracy: 0.5735
# Epoch [17/300], Training Loss: 0.55243844, Training Accuracy: 1.0000
# Epoch [17/300], Validation Loss: 0.91143894, Validation Accuracy: 0.5735
# Epoch [18/300], Training Loss: 0.55236773, Training Accuracy: 1.0000
# Epoch [18/300], Validation Loss: 0.90956762, Validation Accuracy: 0.5735
# Epoch [19/300], Training Loss: 0.55230667, Training Accuracy: 1.0000
# Epoch [19/300], Validation Loss: 0.90623093, Validation Accuracy: 0.5882
# Epoch [20/300], Training Loss: 0.55225279, Training Accuracy: 1.0000
# Epoch [20/300], Validation Loss: 0.90502074, Validation Accuracy: 0.5882
# Epoch [21/300], Training Loss: 0.55220606, Training Accuracy: 1.0000
# Epoch [21/300], Validation Loss: 0.90288880, Validation Accuracy: 0.5882
# Epoch [22/300], Training Loss: 0.55216246, Training Accuracy: 1.0000
# Epoch [22/300], Validation Loss: 0.90076396, Validation Accuracy: 0.5882
# Epoch [23/300], Training Loss: 0.55212176, Training Accuracy: 1.0000
# Epoch [23/300], Validation Loss: 0.89857906, Validation Accuracy: 0.6029
# Epoch [24/300], Training Loss: 0.55208785, Training Accuracy: 1.0000
# Epoch [24/300], Validation Loss: 0.89793333, Validation Accuracy: 0.6029
# Epoch [25/300], Training Loss: 0.55205435, Training Accuracy: 1.0000
# Epoch [25/300], Validation Loss: 0.89546645, Validation Accuracy: 0.6029
# Epoch [26/300], Training Loss: 0.55202466, Training Accuracy: 1.0000
# Epoch [26/300], Validation Loss: 0.89244467, Validation Accuracy: 0.6029
# Epoch [27/300], Training Loss: 0.55199621, Training Accuracy: 1.0000
# Epoch [27/300], Validation Loss: 0.89304784, Validation Accuracy: 0.6324
# Epoch [28/300], Training Loss: 0.55196972, Training Accuracy: 1.0000
# Epoch [28/300], Validation Loss: 0.89189050, Validation Accuracy: 0.6324
# Epoch [29/300], Training Loss: 0.55194566, Training Accuracy: 1.0000
# Epoch [29/300], Validation Loss: 0.88960937, Validation Accuracy: 0.6324
# Epoch [30/300], Training Loss: 0.55192374, Training Accuracy: 1.0000
# Epoch [30/300], Validation Loss: 0.88683635, Validation Accuracy: 0.6324
# Epoch [31/300], Training Loss: 0.55190287, Training Accuracy: 1.0000
# Epoch [31/300], Validation Loss: 0.88540253, Validation Accuracy: 0.6324
# Epoch [32/300], Training Loss: 0.55188379, Training Accuracy: 1.0000
# Epoch [32/300], Validation Loss: 0.88484338, Validation Accuracy: 0.6324
# Epoch [33/300], Training Loss: 0.55186588, Training Accuracy: 1.0000
# Epoch [33/300], Validation Loss: 0.88486958, Validation Accuracy: 0.6471
# Epoch [34/300], Training Loss: 0.55184883, Training Accuracy: 1.0000
# Epoch [34/300], Validation Loss: 0.88294286, Validation Accuracy: 0.6471
# Epoch [35/300], Training Loss: 0.55183305, Training Accuracy: 1.0000
# Epoch [35/300], Validation Loss: 0.88118842, Validation Accuracy: 0.6471
# Epoch [36/300], Training Loss: 0.55181802, Training Accuracy: 1.0000
# Epoch [36/300], Validation Loss: 0.87985101, Validation Accuracy: 0.6471
# Epoch [37/300], Training Loss: 0.55180406, Training Accuracy: 1.0000
# Epoch [37/300], Validation Loss: 0.87930161, Validation Accuracy: 0.6618
# Epoch [38/300], Training Loss: 0.55179091, Training Accuracy: 1.0000
# Epoch [38/300], Validation Loss: 0.87833196, Validation Accuracy: 0.6618
# Epoch [39/300], Training Loss: 0.55177859, Training Accuracy: 1.0000
# Epoch [39/300], Validation Loss: 0.87652394, Validation Accuracy: 0.6618
# Epoch [40/300], Training Loss: 0.55176673, Training Accuracy: 1.0000
# Epoch [40/300], Validation Loss: 0.87538892, Validation Accuracy: 0.6618
# Epoch [41/300], Training Loss: 0.55175567, Training Accuracy: 1.0000
# Epoch [41/300], Validation Loss: 0.87403038, Validation Accuracy: 0.6618
# Epoch [42/300], Training Loss: 0.55174550, Training Accuracy: 1.0000
# Epoch [42/300], Validation Loss: 0.87417439, Validation Accuracy: 0.6618
# Epoch [43/300], Training Loss: 0.55173532, Training Accuracy: 1.0000
# Epoch [43/300], Validation Loss: 0.87307772, Validation Accuracy: 0.6618
# Epoch [44/300], Training Loss: 0.55172598, Training Accuracy: 1.0000
# Epoch [44/300], Validation Loss: 0.87137318, Validation Accuracy: 0.6618
# Epoch [45/300], Training Loss: 0.55171690, Training Accuracy: 1.0000
# Epoch [45/300], Validation Loss: 0.87009421, Validation Accuracy: 0.6618
# Epoch [46/300], Training Loss: 0.55170866, Training Accuracy: 1.0000
# Epoch [46/300], Validation Loss: 0.86980331, Validation Accuracy: 0.6618
# Epoch [47/300], Training Loss: 0.55170054, Training Accuracy: 1.0000
# Epoch [47/300], Validation Loss: 0.86924070, Validation Accuracy: 0.6618
# Epoch [48/300], Training Loss: 0.55169276, Training Accuracy: 1.0000
# Epoch [48/300], Validation Loss: 0.86780262, Validation Accuracy: 0.6618
# Epoch [49/300], Training Loss: 0.55168538, Training Accuracy: 1.0000
# Epoch [49/300], Validation Loss: 0.86738285, Validation Accuracy: 0.6618
# Epoch [50/300], Training Loss: 0.55167839, Training Accuracy: 1.0000
# Epoch [50/300], Validation Loss: 0.86671552, Validation Accuracy: 0.6618
# Epoch [51/300], Training Loss: 0.55167191, Training Accuracy: 1.0000
# Epoch [51/300], Validation Loss: 0.86586124, Validation Accuracy: 0.6618
# Epoch [52/300], Training Loss: 0.55166545, Training Accuracy: 1.0000
# Epoch [52/300], Validation Loss: 0.86479595, Validation Accuracy: 0.6618
# Epoch [53/300], Training Loss: 0.55165944, Training Accuracy: 1.0000
# Epoch [53/300], Validation Loss: 0.86428541, Validation Accuracy: 0.6618
# Epoch [54/300], Training Loss: 0.55165335, Training Accuracy: 1.0000
# Epoch [54/300], Validation Loss: 0.86329761, Validation Accuracy: 0.6618
# Epoch [55/300], Training Loss: 0.55164784, Training Accuracy: 1.0000
# Epoch [55/300], Validation Loss: 0.86259285, Validation Accuracy: 0.6618
# Epoch [56/300], Training Loss: 0.55164249, Training Accuracy: 1.0000
# Epoch [56/300], Validation Loss: 0.86203820, Validation Accuracy: 0.6618
# Epoch [57/300], Training Loss: 0.55163737, Training Accuracy: 1.0000
# Epoch [57/300], Validation Loss: 0.86149961, Validation Accuracy: 0.6618
# Epoch [58/300], Training Loss: 0.55163244, Training Accuracy: 1.0000
# Epoch [58/300], Validation Loss: 0.86050564, Validation Accuracy: 0.6618
# Epoch [59/300], Training Loss: 0.55162770, Training Accuracy: 1.0000
# Epoch [59/300], Validation Loss: 0.85964856, Validation Accuracy: 0.6618
# Epoch [60/300], Training Loss: 0.55162325, Training Accuracy: 1.0000
# Epoch [60/300], Validation Loss: 0.85920379, Validation Accuracy: 0.6618
# Epoch [61/300], Training Loss: 0.55161879, Training Accuracy: 1.0000
# Epoch [61/300], Validation Loss: 0.85814720, Validation Accuracy: 0.6618
# Epoch [62/300], Training Loss: 0.55161466, Training Accuracy: 1.0000
# Epoch [62/300], Validation Loss: 0.85719812, Validation Accuracy: 0.6618
# Epoch [63/300], Training Loss: 0.55161061, Training Accuracy: 1.0000
# Epoch [63/300], Validation Loss: 0.85677677, Validation Accuracy: 0.6618
# Epoch [64/300], Training Loss: 0.55160667, Training Accuracy: 1.0000
# Epoch [64/300], Validation Loss: 0.85636663, Validation Accuracy: 0.6618
# Epoch [65/300], Training Loss: 0.55160295, Training Accuracy: 1.0000
# Epoch [65/300], Validation Loss: 0.85564250, Validation Accuracy: 0.6618
# Epoch [66/300], Training Loss: 0.55159925, Training Accuracy: 1.0000
# Epoch [66/300], Validation Loss: 0.85514256, Validation Accuracy: 0.6618
# Epoch [67/300], Training Loss: 0.55159588, Training Accuracy: 1.0000
# Epoch [67/300], Validation Loss: 0.85547453, Validation Accuracy: 0.6618
# Epoch [68/300], Training Loss: 0.55159249, Training Accuracy: 1.0000
# Epoch [68/300], Validation Loss: 0.85434431, Validation Accuracy: 0.6618
# Epoch [69/300], Training Loss: 0.55158928, Training Accuracy: 1.0000
# Epoch [69/300], Validation Loss: 0.85379043, Validation Accuracy: 0.6618
# Epoch [70/300], Training Loss: 0.55158608, Training Accuracy: 1.0000
# Epoch [70/300], Validation Loss: 0.85279530, Validation Accuracy: 0.6618
# Epoch [71/300], Training Loss: 0.55158309, Training Accuracy: 1.0000
# Epoch [71/300], Validation Loss: 0.85214934, Validation Accuracy: 0.6618
# Epoch [72/300], Training Loss: 0.55158015, Training Accuracy: 1.0000
# Epoch [72/300], Validation Loss: 0.85185727, Validation Accuracy: 0.6765
# Epoch [73/300], Training Loss: 0.55157726, Training Accuracy: 1.0000
# Epoch [73/300], Validation Loss: 0.85135338, Validation Accuracy: 0.6618
# Epoch [74/300], Training Loss: 0.55157455, Training Accuracy: 1.0000
# Epoch [74/300], Validation Loss: 0.85026950, Validation Accuracy: 0.6765
# Epoch [75/300], Training Loss: 0.55157201, Training Accuracy: 1.0000
# Epoch [75/300], Validation Loss: 0.84973681, Validation Accuracy: 0.6618
# Epoch [76/300], Training Loss: 0.55156942, Training Accuracy: 1.0000
# Epoch [76/300], Validation Loss: 0.84965834, Validation Accuracy: 0.6765
# Epoch [77/300], Training Loss: 0.55156683, Training Accuracy: 1.0000
# Epoch [77/300], Validation Loss: 0.84928495, Validation Accuracy: 0.6765
# Epoch [78/300], Training Loss: 0.55156452, Training Accuracy: 1.0000
# Epoch [78/300], Validation Loss: 0.84916136, Validation Accuracy: 0.6765
# Epoch [79/300], Training Loss: 0.55156217, Training Accuracy: 1.0000
# Epoch [79/300], Validation Loss: 0.84813815, Validation Accuracy: 0.6765
# Epoch [80/300], Training Loss: 0.55155992, Training Accuracy: 1.0000
# Epoch [80/300], Validation Loss: 0.84763411, Validation Accuracy: 0.6765
# Epoch [81/300], Training Loss: 0.55155769, Training Accuracy: 1.0000
# Epoch [81/300], Validation Loss: 0.84743693, Validation Accuracy: 0.6765
# Epoch [82/300], Training Loss: 0.55155552, Training Accuracy: 1.0000
# Epoch [82/300], Validation Loss: 0.84656936, Validation Accuracy: 0.6765
# Epoch [83/300], Training Loss: 0.55155350, Training Accuracy: 1.0000
# Epoch [83/300], Validation Loss: 0.84594703, Validation Accuracy: 0.6765
# Epoch [84/300], Training Loss: 0.55155144, Training Accuracy: 1.0000
# Epoch [84/300], Validation Loss: 0.84540689, Validation Accuracy: 0.6912
# Epoch [85/300], Training Loss: 0.55154955, Training Accuracy: 1.0000
# Epoch [85/300], Validation Loss: 0.84500352, Validation Accuracy: 0.6912
# Epoch [86/300], Training Loss: 0.55154761, Training Accuracy: 1.0000
# Epoch [86/300], Validation Loss: 0.84466216, Validation Accuracy: 0.6912
# Epoch [87/300], Training Loss: 0.55154582, Training Accuracy: 1.0000
# Epoch [87/300], Validation Loss: 0.84434402, Validation Accuracy: 0.6912
# Epoch [88/300], Training Loss: 0.55154397, Training Accuracy: 1.0000
# Epoch [88/300], Validation Loss: 0.84372029, Validation Accuracy: 0.6912
# Epoch [89/300], Training Loss: 0.55154232, Training Accuracy: 1.0000
# Epoch [89/300], Validation Loss: 0.84397686, Validation Accuracy: 0.6912
# Epoch [90/300], Training Loss: 0.55154050, Training Accuracy: 1.0000
# Epoch [90/300], Validation Loss: 0.84332055, Validation Accuracy: 0.6912
# Epoch [91/300], Training Loss: 0.55153892, Training Accuracy: 1.0000
# Epoch [91/300], Validation Loss: 0.84278351, Validation Accuracy: 0.6912
# Epoch [92/300], Training Loss: 0.55153726, Training Accuracy: 1.0000
# Epoch [92/300], Validation Loss: 0.84207678, Validation Accuracy: 0.6912
# Epoch [93/300], Training Loss: 0.55153573, Training Accuracy: 1.0000
# Epoch [93/300], Validation Loss: 0.84173065, Validation Accuracy: 0.6912
# Epoch [94/300], Training Loss: 0.55153419, Training Accuracy: 1.0000
# Epoch [94/300], Validation Loss: 0.84138459, Validation Accuracy: 0.6912
# Epoch [95/300], Training Loss: 0.55153273, Training Accuracy: 1.0000
# Epoch [95/300], Validation Loss: 0.84101036, Validation Accuracy: 0.6912
# Epoch [96/300], Training Loss: 0.55153129, Training Accuracy: 1.0000
# Epoch [96/300], Validation Loss: 0.83983272, Validation Accuracy: 0.7059
# Epoch [97/300], Training Loss: 0.55152988, Training Accuracy: 1.0000
# Epoch [97/300], Validation Loss: 0.83977535, Validation Accuracy: 0.7059
# Epoch [98/300], Training Loss: 0.55152848, Training Accuracy: 1.0000
# Epoch [98/300], Validation Loss: 0.83964920, Validation Accuracy: 0.7059
# Epoch [99/300], Training Loss: 0.55152718, Training Accuracy: 1.0000
# Epoch [99/300], Validation Loss: 0.83912659, Validation Accuracy: 0.7059
# Epoch [100/300], Training Loss: 0.55152589, Training Accuracy: 1.0000
# Epoch [100/300], Validation Loss: 0.83846411, Validation Accuracy: 0.7059
# Epoch [101/300], Training Loss: 0.55152462, Training Accuracy: 1.0000
# Epoch [101/300], Validation Loss: 0.83827740, Validation Accuracy: 0.7059
# Epoch [102/300], Training Loss: 0.55152336, Training Accuracy: 1.0000
# Epoch [102/300], Validation Loss: 0.83825278, Validation Accuracy: 0.7059
# Epoch [103/300], Training Loss: 0.55152212, Training Accuracy: 1.0000
# Epoch [103/300], Validation Loss: 0.83811554, Validation Accuracy: 0.7059
# Epoch [104/300], Training Loss: 0.55152093, Training Accuracy: 1.0000
# Epoch [104/300], Validation Loss: 0.83737686, Validation Accuracy: 0.7059
# Epoch [105/300], Training Loss: 0.55151979, Training Accuracy: 1.0000
# Epoch [105/300], Validation Loss: 0.83694693, Validation Accuracy: 0.7206
# Epoch [106/300], Training Loss: 0.55151864, Training Accuracy: 1.0000
# Epoch [106/300], Validation Loss: 0.83704910, Validation Accuracy: 0.7059
# Epoch [107/300], Training Loss: 0.55151757, Training Accuracy: 1.0000
# Epoch [107/300], Validation Loss: 0.83673251, Validation Accuracy: 0.7206
# Epoch [108/300], Training Loss: 0.55151650, Training Accuracy: 1.0000
# Epoch [108/300], Validation Loss: 0.83616027, Validation Accuracy: 0.7206
# Epoch [109/300], Training Loss: 0.55151544, Training Accuracy: 1.0000
# Epoch [109/300], Validation Loss: 0.83567324, Validation Accuracy: 0.7353
# Epoch [110/300], Training Loss: 0.55151439, Training Accuracy: 1.0000
# Epoch [110/300], Validation Loss: 0.83523256, Validation Accuracy: 0.7353
# Epoch [111/300], Training Loss: 0.55151342, Training Accuracy: 1.0000
# Epoch [111/300], Validation Loss: 0.83484909, Validation Accuracy: 0.7353
# Epoch [112/300], Training Loss: 0.55151240, Training Accuracy: 1.0000
# Epoch [112/300], Validation Loss: 0.83468357, Validation Accuracy: 0.7353
# Epoch [113/300], Training Loss: 0.55151145, Training Accuracy: 1.0000
# Epoch [113/300], Validation Loss: 0.83460838, Validation Accuracy: 0.7353
# Epoch [114/300], Training Loss: 0.55151051, Training Accuracy: 1.0000
# Epoch [114/300], Validation Loss: 0.83458260, Validation Accuracy: 0.7206
# Epoch [115/300], Training Loss: 0.55150961, Training Accuracy: 1.0000
# Epoch [115/300], Validation Loss: 0.83413094, Validation Accuracy: 0.7206
# Epoch [116/300], Training Loss: 0.55150868, Training Accuracy: 1.0000
# Epoch [116/300], Validation Loss: 0.83382565, Validation Accuracy: 0.7206
# Epoch [117/300], Training Loss: 0.55150781, Training Accuracy: 1.0000
# Epoch [117/300], Validation Loss: 0.83351696, Validation Accuracy: 0.7206
# Epoch [118/300], Training Loss: 0.55150693, Training Accuracy: 1.0000
# Epoch [118/300], Validation Loss: 0.83297035, Validation Accuracy: 0.7206
# Epoch [119/300], Training Loss: 0.55150613, Training Accuracy: 1.0000
# Epoch [119/300], Validation Loss: 0.83272839, Validation Accuracy: 0.7206
# Epoch [120/300], Training Loss: 0.55150527, Training Accuracy: 1.0000
# Epoch [120/300], Validation Loss: 0.83208632, Validation Accuracy: 0.7206
# Epoch [121/300], Training Loss: 0.55150445, Training Accuracy: 1.0000
# Epoch [121/300], Validation Loss: 0.83182916, Validation Accuracy: 0.7206
# Epoch [122/300], Training Loss: 0.55150368, Training Accuracy: 1.0000
# Epoch [122/300], Validation Loss: 0.83132291, Validation Accuracy: 0.7206
# Epoch [123/300], Training Loss: 0.55150290, Training Accuracy: 1.0000
# Epoch [123/300], Validation Loss: 0.83130047, Validation Accuracy: 0.7206
# Epoch [124/300], Training Loss: 0.55150211, Training Accuracy: 1.0000
# Epoch [124/300], Validation Loss: 0.83110166, Validation Accuracy: 0.7206
# Epoch [125/300], Training Loss: 0.55150135, Training Accuracy: 1.0000
# Epoch [125/300], Validation Loss: 0.83083868, Validation Accuracy: 0.7206
# Epoch [126/300], Training Loss: 0.55150067, Training Accuracy: 1.0000
# Epoch [126/300], Validation Loss: 0.83077255, Validation Accuracy: 0.7206
# Epoch [127/300], Training Loss: 0.55149994, Training Accuracy: 1.0000
# Epoch [127/300], Validation Loss: 0.83055958, Validation Accuracy: 0.7206
# Epoch [128/300], Training Loss: 0.55149925, Training Accuracy: 1.0000
# Epoch [128/300], Validation Loss: 0.83023307, Validation Accuracy: 0.7206
# Epoch [129/300], Training Loss: 0.55149854, Training Accuracy: 1.0000
# Epoch [129/300], Validation Loss: 0.82965815, Validation Accuracy: 0.7206
# Epoch [130/300], Training Loss: 0.55149783, Training Accuracy: 1.0000
# Epoch [130/300], Validation Loss: 0.82903016, Validation Accuracy: 0.7206
# Epoch [131/300], Training Loss: 0.55149721, Training Accuracy: 1.0000
# Epoch [131/300], Validation Loss: 0.82902780, Validation Accuracy: 0.7206
# Epoch [132/300], Training Loss: 0.55149655, Training Accuracy: 1.0000
# Epoch [132/300], Validation Loss: 0.82862976, Validation Accuracy: 0.7206
# Epoch [133/300], Training Loss: 0.55149593, Training Accuracy: 1.0000
# Epoch [133/300], Validation Loss: 0.82866323, Validation Accuracy: 0.7206
# Epoch [134/300], Training Loss: 0.55149527, Training Accuracy: 1.0000
# Epoch [134/300], Validation Loss: 0.82880154, Validation Accuracy: 0.7206
# Epoch [135/300], Training Loss: 0.55149467, Training Accuracy: 1.0000
# Epoch [135/300], Validation Loss: 0.82852224, Validation Accuracy: 0.7206
# Epoch [136/300], Training Loss: 0.55149405, Training Accuracy: 1.0000
# Epoch [136/300], Validation Loss: 0.82826033, Validation Accuracy: 0.7206
# Epoch [137/300], Training Loss: 0.55149347, Training Accuracy: 1.0000
# Epoch [137/300], Validation Loss: 0.82781720, Validation Accuracy: 0.7206
# Epoch [138/300], Training Loss: 0.55149288, Training Accuracy: 1.0000
# Epoch [138/300], Validation Loss: 0.82755569, Validation Accuracy: 0.7206
# Epoch [139/300], Training Loss: 0.55149228, Training Accuracy: 1.0000
# Epoch [139/300], Validation Loss: 0.82744175, Validation Accuracy: 0.7206
# Epoch [140/300], Training Loss: 0.55149174, Training Accuracy: 1.0000
# Epoch [140/300], Validation Loss: 0.82707933, Validation Accuracy: 0.7206
# Epoch [141/300], Training Loss: 0.55149116, Training Accuracy: 1.0000
# Epoch [141/300], Validation Loss: 0.82671499, Validation Accuracy: 0.7206
# Epoch [142/300], Training Loss: 0.55149066, Training Accuracy: 1.0000
# Epoch [142/300], Validation Loss: 0.82681349, Validation Accuracy: 0.7206
# Epoch [143/300], Training Loss: 0.55149011, Training Accuracy: 1.0000
# Epoch [143/300], Validation Loss: 0.82644197, Validation Accuracy: 0.7206
# Epoch [144/300], Training Loss: 0.55148963, Training Accuracy: 1.0000
# Epoch [144/300], Validation Loss: 0.82650310, Validation Accuracy: 0.7206
# Epoch [145/300], Training Loss: 0.55148903, Training Accuracy: 1.0000
# Epoch [145/300], Validation Loss: 0.82632586, Validation Accuracy: 0.7206
# Epoch [146/300], Training Loss: 0.55148860, Training Accuracy: 1.0000
# Epoch [146/300], Validation Loss: 0.82570747, Validation Accuracy: 0.7206
# Epoch [147/300], Training Loss: 0.55148808, Training Accuracy: 1.0000
# Epoch [147/300], Validation Loss: 0.82550290, Validation Accuracy: 0.7206
# Epoch [148/300], Training Loss: 0.55148759, Training Accuracy: 1.0000
# Epoch [148/300], Validation Loss: 0.82533723, Validation Accuracy: 0.7206
# Epoch [149/300], Training Loss: 0.55148711, Training Accuracy: 1.0000
# Epoch [149/300], Validation Loss: 0.82537559, Validation Accuracy: 0.7206
# Epoch [150/300], Training Loss: 0.55148663, Training Accuracy: 1.0000
# Epoch [150/300], Validation Loss: 0.82519418, Validation Accuracy: 0.7206
# Epoch [151/300], Training Loss: 0.55148620, Training Accuracy: 1.0000
# Epoch [151/300], Validation Loss: 0.82495350, Validation Accuracy: 0.7206
# Epoch [152/300], Training Loss: 0.55148575, Training Accuracy: 1.0000
# Epoch [152/300], Validation Loss: 0.82461649, Validation Accuracy: 0.7353
# Epoch [153/300], Training Loss: 0.55148531, Training Accuracy: 1.0000
# Epoch [153/300], Validation Loss: 0.82433930, Validation Accuracy: 0.7206
# Epoch [154/300], Training Loss: 0.55148484, Training Accuracy: 1.0000
# Epoch [154/300], Validation Loss: 0.82382408, Validation Accuracy: 0.7353
# Epoch [155/300], Training Loss: 0.55148441, Training Accuracy: 1.0000
# Epoch [155/300], Validation Loss: 0.82396522, Validation Accuracy: 0.7353
# Epoch [156/300], Training Loss: 0.55148396, Training Accuracy: 1.0000
# Epoch [156/300], Validation Loss: 0.82370326, Validation Accuracy: 0.7353
# Epoch [157/300], Training Loss: 0.55148356, Training Accuracy: 1.0000
# Epoch [157/300], Validation Loss: 0.82371035, Validation Accuracy: 0.7353
# Epoch [158/300], Training Loss: 0.55148315, Training Accuracy: 1.0000
# Epoch [158/300], Validation Loss: 0.82363591, Validation Accuracy: 0.7353
# Epoch [159/300], Training Loss: 0.55148276, Training Accuracy: 1.0000
# Epoch [159/300], Validation Loss: 0.82314292, Validation Accuracy: 0.7353
# Epoch [160/300], Training Loss: 0.55148235, Training Accuracy: 1.0000
# Epoch [160/300], Validation Loss: 0.82303670, Validation Accuracy: 0.7353
# Epoch [161/300], Training Loss: 0.55148198, Training Accuracy: 1.0000
# Epoch [161/300], Validation Loss: 0.82277408, Validation Accuracy: 0.7353
# Epoch [162/300], Training Loss: 0.55148160, Training Accuracy: 1.0000
# Epoch [162/300], Validation Loss: 0.82250416, Validation Accuracy: 0.7353
# Epoch [163/300], Training Loss: 0.55148120, Training Accuracy: 1.0000
# Epoch [163/300], Validation Loss: 0.82257700, Validation Accuracy: 0.7353
# Epoch [164/300], Training Loss: 0.55148079, Training Accuracy: 1.0000
# Epoch [164/300], Validation Loss: 0.82246253, Validation Accuracy: 0.7353
# Epoch [165/300], Training Loss: 0.55148045, Training Accuracy: 1.0000
# Epoch [165/300], Validation Loss: 0.82238010, Validation Accuracy: 0.7353
# Epoch [166/300], Training Loss: 0.55148008, Training Accuracy: 1.0000
# Epoch [166/300], Validation Loss: 0.82202011, Validation Accuracy: 0.7353
# Epoch [167/300], Training Loss: 0.55147971, Training Accuracy: 1.0000
# Epoch [167/300], Validation Loss: 0.82185769, Validation Accuracy: 0.7353
# Epoch [168/300], Training Loss: 0.55147937, Training Accuracy: 1.0000
# Epoch [168/300], Validation Loss: 0.82161489, Validation Accuracy: 0.7353
# Epoch [169/300], Training Loss: 0.55147901, Training Accuracy: 1.0000
# Epoch [169/300], Validation Loss: 0.82164657, Validation Accuracy: 0.7353
# Epoch [170/300], Training Loss: 0.55147866, Training Accuracy: 1.0000
# Epoch [170/300], Validation Loss: 0.82122436, Validation Accuracy: 0.7353
# Epoch [171/300], Training Loss: 0.55147833, Training Accuracy: 1.0000
# Epoch [171/300], Validation Loss: 0.82092044, Validation Accuracy: 0.7353
# Epoch [172/300], Training Loss: 0.55147801, Training Accuracy: 1.0000
# Epoch [172/300], Validation Loss: 0.82097518, Validation Accuracy: 0.7353
# Epoch [173/300], Training Loss: 0.55147767, Training Accuracy: 1.0000
# Epoch [173/300], Validation Loss: 0.82079947, Validation Accuracy: 0.7353
# Epoch [174/300], Training Loss: 0.55147736, Training Accuracy: 1.0000
# Epoch [174/300], Validation Loss: 0.82083005, Validation Accuracy: 0.7353
# Epoch [175/300], Training Loss: 0.55147702, Training Accuracy: 1.0000
# Epoch [175/300], Validation Loss: 0.82059664, Validation Accuracy: 0.7353
# Epoch [176/300], Training Loss: 0.55147669, Training Accuracy: 1.0000
# Epoch [176/300], Validation Loss: 0.82056850, Validation Accuracy: 0.7353
# Epoch [177/300], Training Loss: 0.55147640, Training Accuracy: 1.0000
# Epoch [177/300], Validation Loss: 0.82042012, Validation Accuracy: 0.7353
# Epoch [178/300], Training Loss: 0.55147610, Training Accuracy: 1.0000
# Epoch [178/300], Validation Loss: 0.82012960, Validation Accuracy: 0.7353
# Epoch [179/300], Training Loss: 0.55147578, Training Accuracy: 1.0000
# Epoch [179/300], Validation Loss: 0.81981584, Validation Accuracy: 0.7353
# Epoch [180/300], Training Loss: 0.55147550, Training Accuracy: 1.0000
# Epoch [180/300], Validation Loss: 0.81991690, Validation Accuracy: 0.7353
# Epoch [181/300], Training Loss: 0.55147518, Training Accuracy: 1.0000
# Epoch [181/300], Validation Loss: 0.81981283, Validation Accuracy: 0.7353
# Epoch [182/300], Training Loss: 0.55147493, Training Accuracy: 1.0000
# Epoch [182/300], Validation Loss: 0.81932032, Validation Accuracy: 0.7353
# Epoch [183/300], Training Loss: 0.55147466, Training Accuracy: 1.0000
# Epoch [183/300], Validation Loss: 0.81927091, Validation Accuracy: 0.7353
# Epoch [184/300], Training Loss: 0.55147436, Training Accuracy: 1.0000
# Epoch [184/300], Validation Loss: 0.81918615, Validation Accuracy: 0.7353
# Epoch [185/300], Training Loss: 0.55147410, Training Accuracy: 1.0000
# Epoch [185/300], Validation Loss: 0.81924552, Validation Accuracy: 0.7353
# Epoch [186/300], Training Loss: 0.55147380, Training Accuracy: 1.0000
# Epoch [186/300], Validation Loss: 0.81898725, Validation Accuracy: 0.7353
# Epoch [187/300], Training Loss: 0.55147353, Training Accuracy: 1.0000
# Epoch [187/300], Validation Loss: 0.81890765, Validation Accuracy: 0.7353
# Epoch [188/300], Training Loss: 0.55147324, Training Accuracy: 1.0000
# Epoch [188/300], Validation Loss: 0.81868121, Validation Accuracy: 0.7353
# Epoch [189/300], Training Loss: 0.55147297, Training Accuracy: 1.0000
# Epoch [189/300], Validation Loss: 0.81870478, Validation Accuracy: 0.7353
# Epoch [190/300], Training Loss: 0.55147276, Training Accuracy: 1.0000
# Epoch [190/300], Validation Loss: 0.81859106, Validation Accuracy: 0.7353
# Epoch [191/300], Training Loss: 0.55147248, Training Accuracy: 1.0000
# Epoch [191/300], Validation Loss: 0.81832972, Validation Accuracy: 0.7353
# Epoch [192/300], Training Loss: 0.55147226, Training Accuracy: 1.0000
# Epoch [192/300], Validation Loss: 0.81836689, Validation Accuracy: 0.7353
# Epoch [193/300], Training Loss: 0.55147203, Training Accuracy: 1.0000
# Epoch [193/300], Validation Loss: 0.81823924, Validation Accuracy: 0.7353
# Epoch [194/300], Training Loss: 0.55147177, Training Accuracy: 1.0000
# Epoch [194/300], Validation Loss: 0.81810957, Validation Accuracy: 0.7353
# Epoch [195/300], Training Loss: 0.55147151, Training Accuracy: 1.0000
# Epoch [195/300], Validation Loss: 0.81794587, Validation Accuracy: 0.7353
# Epoch [196/300], Training Loss: 0.55147131, Training Accuracy: 1.0000
# Epoch [196/300], Validation Loss: 0.81782579, Validation Accuracy: 0.7353
# Epoch [197/300], Training Loss: 0.55147105, Training Accuracy: 1.0000
# Epoch [197/300], Validation Loss: 0.81778049, Validation Accuracy: 0.7353
# Epoch [198/300], Training Loss: 0.55147082, Training Accuracy: 1.0000
# Epoch [198/300], Validation Loss: 0.81754744, Validation Accuracy: 0.7353
# Epoch [199/300], Training Loss: 0.55147056, Training Accuracy: 1.0000
# Epoch [199/300], Validation Loss: 0.81739131, Validation Accuracy: 0.7353
# Epoch [200/300], Training Loss: 0.55147034, Training Accuracy: 1.0000
# Epoch [200/300], Validation Loss: 0.81703603, Validation Accuracy: 0.7353
# Epoch [201/300], Training Loss: 0.55147011, Training Accuracy: 1.0000
# Epoch [201/300], Validation Loss: 0.81709230, Validation Accuracy: 0.7353
# Epoch [202/300], Training Loss: 0.55146990, Training Accuracy: 1.0000
# Epoch [202/300], Validation Loss: 0.81715801, Validation Accuracy: 0.7353
# Epoch [203/300], Training Loss: 0.55146968, Training Accuracy: 1.0000
# Epoch [203/300], Validation Loss: 0.81707713, Validation Accuracy: 0.7353
# Epoch [204/300], Training Loss: 0.55146950, Training Accuracy: 1.0000
# Epoch [204/300], Validation Loss: 0.81691259, Validation Accuracy: 0.7353
# Epoch [205/300], Training Loss: 0.55146924, Training Accuracy: 1.0000
# Epoch [205/300], Validation Loss: 0.81676695, Validation Accuracy: 0.7353
# Epoch [206/300], Training Loss: 0.55146905, Training Accuracy: 1.0000
# Epoch [206/300], Validation Loss: 0.81672043, Validation Accuracy: 0.7353
# Epoch [207/300], Training Loss: 0.55146885, Training Accuracy: 1.0000
# Epoch [207/300], Validation Loss: 0.81639093, Validation Accuracy: 0.7353
# Epoch [208/300], Training Loss: 0.55146865, Training Accuracy: 1.0000
# Epoch [208/300], Validation Loss: 0.81629184, Validation Accuracy: 0.7353
# Epoch [209/300], Training Loss: 0.55146845, Training Accuracy: 1.0000
# Epoch [209/300], Validation Loss: 0.81601533, Validation Accuracy: 0.7353
# Epoch [210/300], Training Loss: 0.55146825, Training Accuracy: 1.0000
# Epoch [210/300], Validation Loss: 0.81622869, Validation Accuracy: 0.7353
# Epoch [211/300], Training Loss: 0.55146804, Training Accuracy: 1.0000
# Epoch [211/300], Validation Loss: 0.81616819, Validation Accuracy: 0.7353
# Epoch [212/300], Training Loss: 0.55146787, Training Accuracy: 1.0000
# Epoch [212/300], Validation Loss: 0.81566030, Validation Accuracy: 0.7353
# Epoch [213/300], Training Loss: 0.55146767, Training Accuracy: 1.0000
# Epoch [213/300], Validation Loss: 0.81561315, Validation Accuracy: 0.7353
# Epoch [214/300], Training Loss: 0.55146749, Training Accuracy: 1.0000
# Epoch [214/300], Validation Loss: 0.81568232, Validation Accuracy: 0.7353
# Epoch [215/300], Training Loss: 0.55146725, Training Accuracy: 1.0000
# Epoch [215/300], Validation Loss: 0.81548715, Validation Accuracy: 0.7353
# Epoch [216/300], Training Loss: 0.55146708, Training Accuracy: 1.0000
# Epoch [216/300], Validation Loss: 0.81551301, Validation Accuracy: 0.7353
# Epoch [217/300], Training Loss: 0.55146695, Training Accuracy: 1.0000
# Epoch [217/300], Validation Loss: 0.81541198, Validation Accuracy: 0.7353
# Epoch [218/300], Training Loss: 0.55146675, Training Accuracy: 1.0000
# Epoch [218/300], Validation Loss: 0.81529027, Validation Accuracy: 0.7353
# Epoch [219/300], Training Loss: 0.55146656, Training Accuracy: 1.0000
# Epoch [219/300], Validation Loss: 0.81528789, Validation Accuracy: 0.7353
# Epoch [220/300], Training Loss: 0.55146641, Training Accuracy: 1.0000
# Epoch [220/300], Validation Loss: 0.81520852, Validation Accuracy: 0.7353
# Epoch [221/300], Training Loss: 0.55146623, Training Accuracy: 1.0000
# Epoch [221/300], Validation Loss: 0.81506023, Validation Accuracy: 0.7353
# Epoch [222/300], Training Loss: 0.55146605, Training Accuracy: 1.0000
# Epoch [222/300], Validation Loss: 0.81477571, Validation Accuracy: 0.7353
# Epoch [223/300], Training Loss: 0.55146585, Training Accuracy: 1.0000
# Epoch [223/300], Validation Loss: 0.81470773, Validation Accuracy: 0.7353
# Epoch [224/300], Training Loss: 0.55146569, Training Accuracy: 1.0000
# Epoch [224/300], Validation Loss: 0.81443465, Validation Accuracy: 0.7353
# Epoch [225/300], Training Loss: 0.55146554, Training Accuracy: 1.0000
# Epoch [225/300], Validation Loss: 0.81456518, Validation Accuracy: 0.7353
# Epoch [226/300], Training Loss: 0.55146534, Training Accuracy: 1.0000
# Epoch [226/300], Validation Loss: 0.81440938, Validation Accuracy: 0.7353
# Epoch [227/300], Training Loss: 0.55146520, Training Accuracy: 1.0000
# Epoch [227/300], Validation Loss: 0.81432846, Validation Accuracy: 0.7353
# Epoch [228/300], Training Loss: 0.55146504, Training Accuracy: 1.0000
# Epoch [228/300], Validation Loss: 0.81428534, Validation Accuracy: 0.7353
# Epoch [229/300], Training Loss: 0.55146490, Training Accuracy: 1.0000
# Epoch [229/300], Validation Loss: 0.81410515, Validation Accuracy: 0.7353
# Epoch [230/300], Training Loss: 0.55146474, Training Accuracy: 1.0000
# Epoch [230/300], Validation Loss: 0.81405625, Validation Accuracy: 0.7353
# Epoch [231/300], Training Loss: 0.55146463, Training Accuracy: 1.0000
# Epoch [231/300], Validation Loss: 0.81400761, Validation Accuracy: 0.7353
# Epoch [232/300], Training Loss: 0.55146443, Training Accuracy: 1.0000
# Epoch [232/300], Validation Loss: 0.81407046, Validation Accuracy: 0.7353
# Epoch [233/300], Training Loss: 0.55146429, Training Accuracy: 1.0000
# Epoch [233/300], Validation Loss: 0.81382105, Validation Accuracy: 0.7353
# Epoch [234/300], Training Loss: 0.55146412, Training Accuracy: 1.0000
# Epoch [234/300], Validation Loss: 0.81381077, Validation Accuracy: 0.7353
# Epoch [235/300], Training Loss: 0.55146397, Training Accuracy: 1.0000
# Epoch [235/300], Validation Loss: 0.81373644, Validation Accuracy: 0.7353
# Epoch [236/300], Training Loss: 0.55146383, Training Accuracy: 1.0000
# Epoch [236/300], Validation Loss: 0.81361243, Validation Accuracy: 0.7353
# Epoch [237/300], Training Loss: 0.55146366, Training Accuracy: 1.0000
# Epoch [237/300], Validation Loss: 0.81356412, Validation Accuracy: 0.7353
# Epoch [238/300], Training Loss: 0.55146354, Training Accuracy: 1.0000
# Epoch [238/300], Validation Loss: 0.81346512, Validation Accuracy: 0.7353
# Epoch [239/300], Training Loss: 0.55146340, Training Accuracy: 1.0000
# Epoch [239/300], Validation Loss: 0.81341699, Validation Accuracy: 0.7353
# Epoch [240/300], Training Loss: 0.55146326, Training Accuracy: 1.0000
# Epoch [240/300], Validation Loss: 0.81336570, Validation Accuracy: 0.7353
# Epoch [241/300], Training Loss: 0.55146310, Training Accuracy: 1.0000
# Epoch [241/300], Validation Loss: 0.81317016, Validation Accuracy: 0.7353
# Epoch [242/300], Training Loss: 0.55146297, Training Accuracy: 1.0000
# Epoch [242/300], Validation Loss: 0.81309634, Validation Accuracy: 0.7353
# Epoch [243/300], Training Loss: 0.55146281, Training Accuracy: 1.0000
# Epoch [243/300], Validation Loss: 0.81298387, Validation Accuracy: 0.7353
# Epoch [244/300], Training Loss: 0.55146266, Training Accuracy: 1.0000
# Epoch [244/300], Validation Loss: 0.81290278, Validation Accuracy: 0.7353
# Epoch [245/300], Training Loss: 0.55146256, Training Accuracy: 1.0000
# Epoch [245/300], Validation Loss: 0.81295401, Validation Accuracy: 0.7353
# Epoch [246/300], Training Loss: 0.55146244, Training Accuracy: 1.0000
# Epoch [246/300], Validation Loss: 0.81276307, Validation Accuracy: 0.7353
# Epoch [247/300], Training Loss: 0.55146232, Training Accuracy: 1.0000
# Epoch [247/300], Validation Loss: 0.81253877, Validation Accuracy: 0.7353
# Epoch [248/300], Training Loss: 0.55146213, Training Accuracy: 1.0000
# Epoch [248/300], Validation Loss: 0.81256136, Validation Accuracy: 0.7353
# Epoch [249/300], Training Loss: 0.55146203, Training Accuracy: 1.0000
# Epoch [249/300], Validation Loss: 0.81270248, Validation Accuracy: 0.7353
# Epoch [250/300], Training Loss: 0.55146192, Training Accuracy: 1.0000
# Epoch [250/300], Validation Loss: 0.81253627, Validation Accuracy: 0.7353
# Epoch [251/300], Training Loss: 0.55146178, Training Accuracy: 1.0000
# Epoch [251/300], Validation Loss: 0.81241623, Validation Accuracy: 0.7353
# Epoch [252/300], Training Loss: 0.55146166, Training Accuracy: 1.0000
# Epoch [252/300], Validation Loss: 0.81234682, Validation Accuracy: 0.7353
# Epoch [253/300], Training Loss: 0.55146155, Training Accuracy: 1.0000
# Epoch [253/300], Validation Loss: 0.81215730, Validation Accuracy: 0.7353
# Epoch [254/300], Training Loss: 0.55146141, Training Accuracy: 1.0000
# Epoch [254/300], Validation Loss: 0.81208885, Validation Accuracy: 0.7353
# Epoch [255/300], Training Loss: 0.55146131, Training Accuracy: 1.0000
# Epoch [255/300], Validation Loss: 0.81209993, Validation Accuracy: 0.7353
# Epoch [256/300], Training Loss: 0.55146117, Training Accuracy: 1.0000
# Epoch [256/300], Validation Loss: 0.81200838, Validation Accuracy: 0.7353
# Epoch [257/300], Training Loss: 0.55146105, Training Accuracy: 1.0000
# Epoch [257/300], Validation Loss: 0.81191313, Validation Accuracy: 0.7353
# Epoch [258/300], Training Loss: 0.55146092, Training Accuracy: 1.0000
# Epoch [258/300], Validation Loss: 0.81186360, Validation Accuracy: 0.7353
# Epoch [259/300], Training Loss: 0.55146083, Training Accuracy: 1.0000
# Epoch [259/300], Validation Loss: 0.81188196, Validation Accuracy: 0.7353
# Epoch [260/300], Training Loss: 0.55146072, Training Accuracy: 1.0000
# Epoch [260/300], Validation Loss: 0.81163648, Validation Accuracy: 0.7500
# Epoch [261/300], Training Loss: 0.55146061, Training Accuracy: 1.0000
# Epoch [261/300], Validation Loss: 0.81144822, Validation Accuracy: 0.7500
# Epoch [262/300], Training Loss: 0.55146051, Training Accuracy: 1.0000
# Epoch [262/300], Validation Loss: 0.81148496, Validation Accuracy: 0.7500
# Epoch [263/300], Training Loss: 0.55146037, Training Accuracy: 1.0000
# Epoch [263/300], Validation Loss: 0.81143746, Validation Accuracy: 0.7500
# Epoch [264/300], Training Loss: 0.55146026, Training Accuracy: 1.0000
# Epoch [264/300], Validation Loss: 0.81137186, Validation Accuracy: 0.7500
# Epoch [265/300], Training Loss: 0.55146015, Training Accuracy: 1.0000
# Epoch [265/300], Validation Loss: 0.81115338, Validation Accuracy: 0.7500
# Epoch [266/300], Training Loss: 0.55146008, Training Accuracy: 1.0000
# Epoch [266/300], Validation Loss: 0.81115603, Validation Accuracy: 0.7500
# Epoch [267/300], Training Loss: 0.55145993, Training Accuracy: 1.0000
# Epoch [267/300], Validation Loss: 0.81111464, Validation Accuracy: 0.7500
# Epoch [268/300], Training Loss: 0.55145987, Training Accuracy: 1.0000
# Epoch [268/300], Validation Loss: 0.81099731, Validation Accuracy: 0.7500
# Epoch [269/300], Training Loss: 0.55145975, Training Accuracy: 1.0000
# Epoch [269/300], Validation Loss: 0.81079641, Validation Accuracy: 0.7500
# Epoch [270/300], Training Loss: 0.55145964, Training Accuracy: 1.0000
# Epoch [270/300], Validation Loss: 0.81072757, Validation Accuracy: 0.7500
# Epoch [271/300], Training Loss: 0.55145955, Training Accuracy: 1.0000
# Epoch [271/300], Validation Loss: 0.81074846, Validation Accuracy: 0.7500
# Epoch [272/300], Training Loss: 0.55145946, Training Accuracy: 1.0000
# Epoch [272/300], Validation Loss: 0.81064299, Validation Accuracy: 0.7500
# Epoch [273/300], Training Loss: 0.55145934, Training Accuracy: 1.0000
# Epoch [273/300], Validation Loss: 0.81069162, Validation Accuracy: 0.7500
# Epoch [274/300], Training Loss: 0.55145924, Training Accuracy: 1.0000
# Epoch [274/300], Validation Loss: 0.81067932, Validation Accuracy: 0.7500
# Epoch [275/300], Training Loss: 0.55145914, Training Accuracy: 1.0000
# Epoch [275/300], Validation Loss: 0.81065038, Validation Accuracy: 0.7500
# Epoch [276/300], Training Loss: 0.55145902, Training Accuracy: 1.0000
# Epoch [276/300], Validation Loss: 0.81064591, Validation Accuracy: 0.7500
# Epoch [277/300], Training Loss: 0.55145895, Training Accuracy: 1.0000
# Epoch [277/300], Validation Loss: 0.81056702, Validation Accuracy: 0.7500
# Epoch [278/300], Training Loss: 0.55145883, Training Accuracy: 1.0000
# Epoch [278/300], Validation Loss: 0.81024349, Validation Accuracy: 0.7500
# Epoch [279/300], Training Loss: 0.55145873, Training Accuracy: 1.0000
# Epoch [279/300], Validation Loss: 0.81029329, Validation Accuracy: 0.7500
# Epoch [280/300], Training Loss: 0.55145863, Training Accuracy: 1.0000
# Epoch [280/300], Validation Loss: 0.81019273, Validation Accuracy: 0.7500
# Epoch [281/300], Training Loss: 0.55145856, Training Accuracy: 1.0000
# Epoch [281/300], Validation Loss: 0.81027886, Validation Accuracy: 0.7500
# Epoch [282/300], Training Loss: 0.55145844, Training Accuracy: 1.0000
# Epoch [282/300], Validation Loss: 0.80992192, Validation Accuracy: 0.7500
# Epoch [283/300], Training Loss: 0.55145837, Training Accuracy: 1.0000
# Epoch [283/300], Validation Loss: 0.80984876, Validation Accuracy: 0.7500
# Epoch [284/300], Training Loss: 0.55145827, Training Accuracy: 1.0000
# Epoch [284/300], Validation Loss: 0.80983910, Validation Accuracy: 0.7500
# Epoch [285/300], Training Loss: 0.55145821, Training Accuracy: 1.0000
# Epoch [285/300], Validation Loss: 0.80976349, Validation Accuracy: 0.7500
# Epoch [286/300], Training Loss: 0.55145814, Training Accuracy: 1.0000
# Epoch [286/300], Validation Loss: 0.80971810, Validation Accuracy: 0.7500
# Epoch [287/300], Training Loss: 0.55145803, Training Accuracy: 1.0000
# Epoch [287/300], Validation Loss: 0.80964416, Validation Accuracy: 0.7500
# Epoch [288/300], Training Loss: 0.55145790, Training Accuracy: 1.0000
# Epoch [288/300], Validation Loss: 0.80967650, Validation Accuracy: 0.7500
# Epoch [289/300], Training Loss: 0.55145781, Training Accuracy: 1.0000
# Epoch [289/300], Validation Loss: 0.80955860, Validation Accuracy: 0.7500
# Epoch [290/300], Training Loss: 0.55145775, Training Accuracy: 1.0000
# Epoch [290/300], Validation Loss: 0.80955777, Validation Accuracy: 0.7500
# Epoch [291/300], Training Loss: 0.55145763, Training Accuracy: 1.0000
# Epoch [291/300], Validation Loss: 0.80961367, Validation Accuracy: 0.7500
# Epoch [292/300], Training Loss: 0.55145757, Training Accuracy: 1.0000
# Epoch [292/300], Validation Loss: 0.80956185, Validation Accuracy: 0.7500
# Epoch [293/300], Training Loss: 0.55145750, Training Accuracy: 1.0000
# Epoch [293/300], Validation Loss: 0.80946675, Validation Accuracy: 0.7500
# Epoch [294/300], Training Loss: 0.55145741, Training Accuracy: 1.0000
# Epoch [294/300], Validation Loss: 0.80925864, Validation Accuracy: 0.7500
# Epoch [295/300], Training Loss: 0.55145735, Training Accuracy: 1.0000
# Epoch [295/300], Validation Loss: 0.80917898, Validation Accuracy: 0.7500
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Epoch [296/300], Training Loss: 0.55145727, Training Accuracy: 1.0000
# Epoch [296/300], Validation Loss: 0.80898634, Validation Accuracy: 0.7500
# Epoch [297/300], Training Loss: 0.55145722, Training Accuracy: 1.0000
# Epoch [297/300], Validation Loss: 0.80904120, Validation Accuracy: 0.7500
# Epoch [298/300], Training Loss: 0.55145711, Training Accuracy: 1.0000
# Epoch [298/300], Validation Loss: 0.80894506, Validation Accuracy: 0.7500
# Epoch [299/300], Training Loss: 0.55145699, Training Accuracy: 1.0000
# Epoch [299/300], Validation Loss: 0.80884725, Validation Accuracy: 0.7500
# Epoch [300/300], Training Loss: 0.55145694, Training Accuracy: 1.0000
# Epoch [300/300], Validation Loss: 0.80871829, Validation Accuracy: 0.7500

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.5f}')
# Out:
# Test Accuracy: 0.64706

# %% [markdown]
# ##### Analysis RNN
# Validation accuracy is 0.75 at 300 epochs. Test accuracy is 0.64706.

# %% [markdown]
# ##### Define LSTM

# %%
# chatgpt 3.5 generated code
# LSTM Model with Softmax
class LSTMWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(LSTMWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])  # Use only the last time step's output for classification
        return nn.functional.softmax(out, dim=1)  # Apply softmax activation

# %% [markdown]
# ##### Train LSTM: setup

# %%
# chatgpt 3.5 generated code
model = LSTMWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the LSTM and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code (this code is a copy of the RNN code)
# Training loop
# LSTM_total_epochs = number_of_epochs
LSTM_total_epochs = LSTM_number_of_epochs

# Lists to store training/validation losses and training/validation accuracies
LSTM_train_losses = []  
LSTM_val_losses = []    
LSTM_train_accuracies = []  
LSTM_val_accuracies = []    

for epoch in range(LSTM_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    LSTM_train_losses.append(average_train_loss)
    LSTM_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{LSTM_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Store validation loss and accuracy values
    LSTM_val_losses.append(average_val_loss)
    LSTM_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{LSTM_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')

# Plot the losses and accuracies at the end of all epochs
LSTM_x_epochs = list(range(1, LSTM_total_epochs + 1))
plt.figure(figsize=(7, 5))

# Plot losses (dashed) and accuracies (solid)
plt.plot(LSTM_x_epochs, LSTM_train_losses, linestyle='--', label='LSTM Training Loss')
plt.plot(LSTM_x_epochs, LSTM_val_losses, linestyle='--', label='LSTM Validation Loss')
plt.plot(LSTM_x_epochs, LSTM_train_accuracies, label='LSTM Training Accuracy')
plt.plot(LSTM_x_epochs, LSTM_val_accuracies, label='LSTM Validation Accuracy')
plt.xlabel('LSTM Epochs')
plt.ylabel('LSTM Loss and Accuracy')
plt.title('LSTM Training and Validation Losses for 2 LSTM Layers')
plt.legend()

plt.tight_layout()
plt.savefig('eps/LSTM_11_2_layer_spks_class.eps')
plt.savefig('svg/LSTM_11_2_layer_spks_class.svg')
plt.show()
# Out:
# Epoch [1/60], Training Loss: 1.09020785, Training Accuracy: 0.3782
# Epoch [1/60], Validation Loss: 1.07615918, Validation Accuracy: 0.3088
# Epoch [2/60], Training Loss: 1.05661379, Training Accuracy: 0.4328
# Epoch [2/60], Validation Loss: 1.09946203, Validation Accuracy: 0.3088
# Epoch [3/60], Training Loss: 1.03557929, Training Accuracy: 0.4622
# Epoch [3/60], Validation Loss: 1.04634362, Validation Accuracy: 0.5147
# Epoch [4/60], Training Loss: 1.01326660, Training Accuracy: 0.5210
# Epoch [4/60], Validation Loss: 1.02286965, Validation Accuracy: 0.4853
# Epoch [5/60], Training Loss: 0.88155822, Training Accuracy: 0.7353
# Epoch [5/60], Validation Loss: 0.86066446, Validation Accuracy: 0.6912
# Epoch [6/60], Training Loss: 0.85147125, Training Accuracy: 0.6849
# Epoch [6/60], Validation Loss: 0.80751622, Validation Accuracy: 0.7206
# Epoch [7/60], Training Loss: 0.81471763, Training Accuracy: 0.7101
# Epoch [7/60], Validation Loss: 0.83949554, Validation Accuracy: 0.6912
# Epoch [8/60], Training Loss: 0.77554494, Training Accuracy: 0.7689
# Epoch [8/60], Validation Loss: 0.88654697, Validation Accuracy: 0.5882
# Epoch [9/60], Training Loss: 0.74065943, Training Accuracy: 0.7941
# Epoch [9/60], Validation Loss: 0.81933096, Validation Accuracy: 0.7059
# Epoch [10/60], Training Loss: 0.73218060, Training Accuracy: 0.7731
# Epoch [10/60], Validation Loss: 0.85036016, Validation Accuracy: 0.6471
# Epoch [11/60], Training Loss: 0.70110870, Training Accuracy: 0.8529
# Epoch [11/60], Validation Loss: 0.75410753, Validation Accuracy: 0.8088
# Epoch [12/60], Training Loss: 0.68508183, Training Accuracy: 0.8950
# Epoch [12/60], Validation Loss: 0.73912820, Validation Accuracy: 0.8088
# Epoch [13/60], Training Loss: 0.66202424, Training Accuracy: 0.9370
# Epoch [13/60], Validation Loss: 0.71745992, Validation Accuracy: 0.8676
# Epoch [14/60], Training Loss: 0.63549206, Training Accuracy: 0.9538
# Epoch [14/60], Validation Loss: 0.69530889, Validation Accuracy: 0.8824
# Epoch [15/60], Training Loss: 0.60843429, Training Accuracy: 0.9664
# Epoch [15/60], Validation Loss: 0.70037118, Validation Accuracy: 0.8676
# Epoch [16/60], Training Loss: 0.59237418, Training Accuracy: 0.9664
# Epoch [16/60], Validation Loss: 0.66309682, Validation Accuracy: 0.9118
# Epoch [17/60], Training Loss: 0.58008476, Training Accuracy: 0.9748
# Epoch [17/60], Validation Loss: 0.66240042, Validation Accuracy: 0.8824
# Epoch [18/60], Training Loss: 0.58809217, Training Accuracy: 0.9664
# Epoch [18/60], Validation Loss: 0.71914443, Validation Accuracy: 0.8235
# Epoch [19/60], Training Loss: 0.58161619, Training Accuracy: 0.9706
# Epoch [19/60], Validation Loss: 0.72227421, Validation Accuracy: 0.7941
# Epoch [20/60], Training Loss: 0.58912839, Training Accuracy: 0.9664
# Epoch [20/60], Validation Loss: 0.65064242, Validation Accuracy: 0.9118
# Epoch [21/60], Training Loss: 0.57685194, Training Accuracy: 0.9790
# Epoch [21/60], Validation Loss: 0.70255226, Validation Accuracy: 0.8676
# Epoch [22/60], Training Loss: 0.58083407, Training Accuracy: 0.9748
# Epoch [22/60], Validation Loss: 0.69411147, Validation Accuracy: 0.8824
# Epoch [23/60], Training Loss: 0.57091553, Training Accuracy: 0.9874
# Epoch [23/60], Validation Loss: 0.66821581, Validation Accuracy: 0.9118
# Epoch [24/60], Training Loss: 0.56150153, Training Accuracy: 0.9916
# Epoch [24/60], Validation Loss: 0.67959681, Validation Accuracy: 0.8824
# Epoch [25/60], Training Loss: 0.56382642, Training Accuracy: 0.9916
# Epoch [25/60], Validation Loss: 0.67666534, Validation Accuracy: 0.8676
# Epoch [26/60], Training Loss: 0.55963924, Training Accuracy: 0.9916
# Epoch [26/60], Validation Loss: 0.71002322, Validation Accuracy: 0.8382
# Epoch [27/60], Training Loss: 0.55472699, Training Accuracy: 1.0000
# Epoch [27/60], Validation Loss: 0.68026221, Validation Accuracy: 0.8676
# Epoch [28/60], Training Loss: 0.55272704, Training Accuracy: 1.0000
# Epoch [28/60], Validation Loss: 0.66071078, Validation Accuracy: 0.8971
# Epoch [29/60], Training Loss: 0.55228508, Training Accuracy: 1.0000
# Epoch [29/60], Validation Loss: 0.66841948, Validation Accuracy: 0.8824
# Epoch [30/60], Training Loss: 0.55208964, Training Accuracy: 1.0000
# Epoch [30/60], Validation Loss: 0.67479488, Validation Accuracy: 0.8824
# Epoch [31/60], Training Loss: 0.55202218, Training Accuracy: 1.0000
# Epoch [31/60], Validation Loss: 0.67177564, Validation Accuracy: 0.8824
# Epoch [32/60], Training Loss: 0.55194377, Training Accuracy: 1.0000
# Epoch [32/60], Validation Loss: 0.66323906, Validation Accuracy: 0.8824
# Epoch [33/60], Training Loss: 0.55186582, Training Accuracy: 1.0000
# Epoch [33/60], Validation Loss: 0.65997806, Validation Accuracy: 0.8824
# Epoch [34/60], Training Loss: 0.55183129, Training Accuracy: 1.0000
# Epoch [34/60], Validation Loss: 0.65868908, Validation Accuracy: 0.8824
# Epoch [35/60], Training Loss: 0.55180121, Training Accuracy: 1.0000
# Epoch [35/60], Validation Loss: 0.65859300, Validation Accuracy: 0.8824
# Epoch [36/60], Training Loss: 0.55178002, Training Accuracy: 1.0000
# Epoch [36/60], Validation Loss: 0.65887988, Validation Accuracy: 0.8824
# Epoch [37/60], Training Loss: 0.55176227, Training Accuracy: 1.0000
# Epoch [37/60], Validation Loss: 0.65925413, Validation Accuracy: 0.8824
# Epoch [38/60], Training Loss: 0.55174731, Training Accuracy: 1.0000
# Epoch [38/60], Validation Loss: 0.65961921, Validation Accuracy: 0.8824
# Epoch [39/60], Training Loss: 0.55173475, Training Accuracy: 1.0000
# Epoch [39/60], Validation Loss: 0.65993714, Validation Accuracy: 0.8824
# Epoch [40/60], Training Loss: 0.55172305, Training Accuracy: 1.0000
# Epoch [40/60], Validation Loss: 0.66021174, Validation Accuracy: 0.8824
# Epoch [41/60], Training Loss: 0.55171170, Training Accuracy: 1.0000
# Epoch [41/60], Validation Loss: 0.66038993, Validation Accuracy: 0.8824
# Epoch [42/60], Training Loss: 0.55170266, Training Accuracy: 1.0000
# Epoch [42/60], Validation Loss: 0.66058657, Validation Accuracy: 0.8824
# Epoch [43/60], Training Loss: 0.55169344, Training Accuracy: 1.0000
# Epoch [43/60], Validation Loss: 0.66085851, Validation Accuracy: 0.8824
# Epoch [44/60], Training Loss: 0.55168500, Training Accuracy: 1.0000
# Epoch [44/60], Validation Loss: 0.66086775, Validation Accuracy: 0.8824
# Epoch [45/60], Training Loss: 0.55167706, Training Accuracy: 1.0000
# Epoch [45/60], Validation Loss: 0.66101497, Validation Accuracy: 0.8824
# Epoch [46/60], Training Loss: 0.55166967, Training Accuracy: 1.0000
# Epoch [46/60], Validation Loss: 0.66109380, Validation Accuracy: 0.8824
# Epoch [47/60], Training Loss: 0.55166265, Training Accuracy: 1.0000
# Epoch [47/60], Validation Loss: 0.66130409, Validation Accuracy: 0.8824
# Epoch [48/60], Training Loss: 0.55165598, Training Accuracy: 1.0000
# Epoch [48/60], Validation Loss: 0.66142407, Validation Accuracy: 0.8824
# Epoch [49/60], Training Loss: 0.55164994, Training Accuracy: 1.0000
# Epoch [49/60], Validation Loss: 0.66147012, Validation Accuracy: 0.8824
# Epoch [50/60], Training Loss: 0.55164380, Training Accuracy: 1.0000
# Epoch [50/60], Validation Loss: 0.66168782, Validation Accuracy: 0.8824
# Epoch [51/60], Training Loss: 0.55163844, Training Accuracy: 1.0000
# Epoch [51/60], Validation Loss: 0.66182676, Validation Accuracy: 0.8824
# Epoch [52/60], Training Loss: 0.55163292, Training Accuracy: 1.0000
# Epoch [52/60], Validation Loss: 0.66191104, Validation Accuracy: 0.8824
# Epoch [53/60], Training Loss: 0.55162789, Training Accuracy: 1.0000
# Epoch [53/60], Validation Loss: 0.66202736, Validation Accuracy: 0.8971
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Epoch [54/60], Training Loss: 0.55162316, Training Accuracy: 1.0000
# Epoch [54/60], Validation Loss: 0.66219777, Validation Accuracy: 0.8971
# Epoch [55/60], Training Loss: 0.55161850, Training Accuracy: 1.0000
# Epoch [55/60], Validation Loss: 0.66243437, Validation Accuracy: 0.8971
# Epoch [56/60], Training Loss: 0.55161403, Training Accuracy: 1.0000
# Epoch [56/60], Validation Loss: 0.66255945, Validation Accuracy: 0.8971
# Epoch [57/60], Training Loss: 0.55160989, Training Accuracy: 1.0000
# Epoch [57/60], Validation Loss: 0.66273212, Validation Accuracy: 0.8971
# Epoch [58/60], Training Loss: 0.55160571, Training Accuracy: 1.0000
# Epoch [58/60], Validation Loss: 0.66282693, Validation Accuracy: 0.8971
# Epoch [59/60], Training Loss: 0.55160189, Training Accuracy: 1.0000
# Epoch [59/60], Validation Loss: 0.66303408, Validation Accuracy: 0.8971
# Epoch [60/60], Training Loss: 0.55159826, Training Accuracy: 1.0000
# Epoch [60/60], Validation Loss: 0.66324407, Validation Accuracy: 0.8971

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.5f}')
# Out:
# Test Accuracy: 0.88235

# %% [markdown]
# ##### Analysis LSTM
# Validation accuracy is 0.8971 at 60 epochs. Test accuracy is 0.88235.

# %% [markdown]
# ##### Define GRU

# %%
# chatgpt 3.5 generated code
# GRU Model with Softmax
class GRUWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(GRUWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.gru(x, h0)
        out = self.fc(out[:, -1, :])  # Use only the last time step's output for classification
        return nn.functional.softmax(out, dim=1)  # Apply softmax activation

# %% [markdown]
# ##### Train GRU: setup

# %%
# chatgpt 3.5 generated code
model = GRUWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the GRU and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code (this code is a copy of the RNN code)
# Training loop
# GRU_total_epochs = number_of_epochs
GRU_total_epochs = GRU_number_of_epochs

# Lists to store training/validation losses and training/validation accuracies
GRU_train_losses = []  
GRU_val_losses = []    
GRU_train_accuracies = []  
GRU_val_accuracies = []    

for epoch in range(GRU_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    GRU_train_losses.append(average_train_loss)
    GRU_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{GRU_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Store validation loss and accuracy values
    GRU_val_losses.append(average_val_loss)
    GRU_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{GRU_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')

# Plot the losses and accuracies at the end of all epochs
GRU_x_epochs = list(range(1, GRU_total_epochs + 1))
plt.figure(figsize=(7, 5))

# Plot losses (dashed) and accuracies (solid)
plt.plot(GRU_x_epochs, GRU_train_losses, linestyle='--', label='GRU Training Loss')
plt.plot(GRU_x_epochs, GRU_val_losses, linestyle='--', label='GRU Validation Loss')
plt.plot(GRU_x_epochs, GRU_train_accuracies, label='GRU Training Accuracy')
plt.plot(GRU_x_epochs, GRU_val_accuracies, label='GRU Validation Accuracy')
plt.xlabel('GRU Epochs')
plt.ylabel('GRU Loss and Accuracy')
plt.title('GRU Training and Validation Losses for 2 GRU Layers')
plt.legend()

plt.tight_layout()
plt.savefig('eps/GRU_11_2_layer_spks_class.eps')
plt.savefig('svg/GRU_11_2_layer_spks_class.svg')
plt.show()
# Out:
# Epoch [1/250], Training Loss: 1.08661478, Training Accuracy: 0.3697
# Epoch [1/250], Validation Loss: 1.07334125, Validation Accuracy: 0.3088
# Epoch [2/250], Training Loss: 1.03304340, Training Accuracy: 0.4328
# Epoch [2/250], Validation Loss: 1.06350315, Validation Accuracy: 0.3088
# Epoch [3/250], Training Loss: 0.99249459, Training Accuracy: 0.6261
# Epoch [3/250], Validation Loss: 1.01317954, Validation Accuracy: 0.5882
# Epoch [4/250], Training Loss: 0.90084497, Training Accuracy: 0.7479
# Epoch [4/250], Validation Loss: 0.95667347, Validation Accuracy: 0.5441
# Epoch [5/250], Training Loss: 0.78955842, Training Accuracy: 0.7689
# Epoch [5/250], Validation Loss: 0.84679511, Validation Accuracy: 0.7059
# Epoch [6/250], Training Loss: 0.74194476, Training Accuracy: 0.7899
# Epoch [6/250], Validation Loss: 0.81834543, Validation Accuracy: 0.7353
# Epoch [7/250], Training Loss: 0.70641415, Training Accuracy: 0.8277
# Epoch [7/250], Validation Loss: 0.81021556, Validation Accuracy: 0.7647
# Epoch [8/250], Training Loss: 0.66655804, Training Accuracy: 0.9286
# Epoch [8/250], Validation Loss: 0.80989206, Validation Accuracy: 0.7500
# Epoch [9/250], Training Loss: 0.65138710, Training Accuracy: 0.9244
# Epoch [9/250], Validation Loss: 0.75703430, Validation Accuracy: 0.7941
# Epoch [10/250], Training Loss: 0.62142139, Training Accuracy: 0.9412
# Epoch [10/250], Validation Loss: 0.73800001, Validation Accuracy: 0.8382
# Epoch [11/250], Training Loss: 0.59572097, Training Accuracy: 0.9664
# Epoch [11/250], Validation Loss: 0.72513652, Validation Accuracy: 0.8088
# Epoch [12/250], Training Loss: 0.58381334, Training Accuracy: 0.9748
# Epoch [12/250], Validation Loss: 0.72991979, Validation Accuracy: 0.8088
# Epoch [13/250], Training Loss: 0.57245525, Training Accuracy: 0.9832
# Epoch [13/250], Validation Loss: 0.76223508, Validation Accuracy: 0.7941
# Epoch [14/250], Training Loss: 0.56607669, Training Accuracy: 0.9874
# Epoch [14/250], Validation Loss: 0.72282353, Validation Accuracy: 0.8382
# Epoch [15/250], Training Loss: 0.56224234, Training Accuracy: 0.9916
# Epoch [15/250], Validation Loss: 0.71725845, Validation Accuracy: 0.7941
# Epoch [16/250], Training Loss: 0.56197779, Training Accuracy: 0.9916
# Epoch [16/250], Validation Loss: 0.71811289, Validation Accuracy: 0.7941
# Epoch [17/250], Training Loss: 0.56107352, Training Accuracy: 0.9916
# Epoch [17/250], Validation Loss: 0.71275863, Validation Accuracy: 0.8529
# Epoch [18/250], Training Loss: 0.56069709, Training Accuracy: 0.9916
# Epoch [18/250], Validation Loss: 0.71075162, Validation Accuracy: 0.8382
# Epoch [19/250], Training Loss: 0.56053426, Training Accuracy: 0.9916
# Epoch [19/250], Validation Loss: 0.71146384, Validation Accuracy: 0.8382
# Epoch [20/250], Training Loss: 0.56042701, Training Accuracy: 0.9916
# Epoch [20/250], Validation Loss: 0.71208394, Validation Accuracy: 0.8382
# Epoch [21/250], Training Loss: 0.56021775, Training Accuracy: 0.9916
# Epoch [21/250], Validation Loss: 0.71675798, Validation Accuracy: 0.8235
# Epoch [22/250], Training Loss: 0.55947365, Training Accuracy: 0.9958
# Epoch [22/250], Validation Loss: 0.73019618, Validation Accuracy: 0.8235
# Epoch [23/250], Training Loss: 0.55455243, Training Accuracy: 1.0000
# Epoch [23/250], Validation Loss: 0.71274912, Validation Accuracy: 0.8235
# Epoch [24/250], Training Loss: 0.55239388, Training Accuracy: 1.0000
# Epoch [24/250], Validation Loss: 0.71139023, Validation Accuracy: 0.8382
# Epoch [25/250], Training Loss: 0.55247772, Training Accuracy: 1.0000
# Epoch [25/250], Validation Loss: 0.71127874, Validation Accuracy: 0.8235
# Epoch [26/250], Training Loss: 0.55227516, Training Accuracy: 1.0000
# Epoch [26/250], Validation Loss: 0.70738357, Validation Accuracy: 0.8382
# Epoch [27/250], Training Loss: 0.55208509, Training Accuracy: 1.0000
# Epoch [27/250], Validation Loss: 0.70253477, Validation Accuracy: 0.8382
# Epoch [28/250], Training Loss: 0.55196836, Training Accuracy: 1.0000
# Epoch [28/250], Validation Loss: 0.69911075, Validation Accuracy: 0.8382
# Epoch [29/250], Training Loss: 0.55191306, Training Accuracy: 1.0000
# Epoch [29/250], Validation Loss: 0.69741067, Validation Accuracy: 0.8529
# Epoch [30/250], Training Loss: 0.55187297, Training Accuracy: 1.0000
# Epoch [30/250], Validation Loss: 0.69629890, Validation Accuracy: 0.8676
# Epoch [31/250], Training Loss: 0.55184488, Training Accuracy: 1.0000
# Epoch [31/250], Validation Loss: 0.69564027, Validation Accuracy: 0.8676
# Epoch [32/250], Training Loss: 0.55182027, Training Accuracy: 1.0000
# Epoch [32/250], Validation Loss: 0.69506910, Validation Accuracy: 0.8676
# Epoch [33/250], Training Loss: 0.55179799, Training Accuracy: 1.0000
# Epoch [33/250], Validation Loss: 0.69438532, Validation Accuracy: 0.8676
# Epoch [34/250], Training Loss: 0.55177939, Training Accuracy: 1.0000
# Epoch [34/250], Validation Loss: 0.69387954, Validation Accuracy: 0.8676
# Epoch [35/250], Training Loss: 0.55176276, Training Accuracy: 1.0000
# Epoch [35/250], Validation Loss: 0.69360617, Validation Accuracy: 0.8676
# Epoch [36/250], Training Loss: 0.55174738, Training Accuracy: 1.0000
# Epoch [36/250], Validation Loss: 0.69340163, Validation Accuracy: 0.8529
# Epoch [37/250], Training Loss: 0.55173334, Training Accuracy: 1.0000
# Epoch [37/250], Validation Loss: 0.69316605, Validation Accuracy: 0.8529
# Epoch [38/250], Training Loss: 0.55172117, Training Accuracy: 1.0000
# Epoch [38/250], Validation Loss: 0.69319630, Validation Accuracy: 0.8529
# Epoch [39/250], Training Loss: 0.55170932, Training Accuracy: 1.0000
# Epoch [39/250], Validation Loss: 0.69319686, Validation Accuracy: 0.8529
# Epoch [40/250], Training Loss: 0.55169902, Training Accuracy: 1.0000
# Epoch [40/250], Validation Loss: 0.69319040, Validation Accuracy: 0.8529
# Epoch [41/250], Training Loss: 0.55168920, Training Accuracy: 1.0000
# Epoch [41/250], Validation Loss: 0.69326648, Validation Accuracy: 0.8529
# Epoch [42/250], Training Loss: 0.55167992, Training Accuracy: 1.0000
# Epoch [42/250], Validation Loss: 0.69346261, Validation Accuracy: 0.8529
# Epoch [43/250], Training Loss: 0.55167122, Training Accuracy: 1.0000
# Epoch [43/250], Validation Loss: 0.69370714, Validation Accuracy: 0.8529
# Epoch [44/250], Training Loss: 0.55166324, Training Accuracy: 1.0000
# Epoch [44/250], Validation Loss: 0.69385526, Validation Accuracy: 0.8529
# Epoch [45/250], Training Loss: 0.55165575, Training Accuracy: 1.0000
# Epoch [45/250], Validation Loss: 0.69400451, Validation Accuracy: 0.8529
# Epoch [46/250], Training Loss: 0.55164866, Training Accuracy: 1.0000
# Epoch [46/250], Validation Loss: 0.69416565, Validation Accuracy: 0.8529
# Epoch [47/250], Training Loss: 0.55164198, Training Accuracy: 1.0000
# Epoch [47/250], Validation Loss: 0.69446668, Validation Accuracy: 0.8529
# Epoch [48/250], Training Loss: 0.55163587, Training Accuracy: 1.0000
# Epoch [48/250], Validation Loss: 0.69473010, Validation Accuracy: 0.8529
# Epoch [49/250], Training Loss: 0.55162988, Training Accuracy: 1.0000
# Epoch [49/250], Validation Loss: 0.69508937, Validation Accuracy: 0.8382
# Epoch [50/250], Training Loss: 0.55162433, Training Accuracy: 1.0000
# Epoch [50/250], Validation Loss: 0.69528413, Validation Accuracy: 0.8382
# Epoch [51/250], Training Loss: 0.55161904, Training Accuracy: 1.0000
# Epoch [51/250], Validation Loss: 0.69555196, Validation Accuracy: 0.8382
# Epoch [52/250], Training Loss: 0.55161400, Training Accuracy: 1.0000
# Epoch [52/250], Validation Loss: 0.69584990, Validation Accuracy: 0.8382
# Epoch [53/250], Training Loss: 0.55160913, Training Accuracy: 1.0000
# Epoch [53/250], Validation Loss: 0.69614458, Validation Accuracy: 0.8382
# Epoch [54/250], Training Loss: 0.55160455, Training Accuracy: 1.0000
# Epoch [54/250], Validation Loss: 0.69638425, Validation Accuracy: 0.8382
# Epoch [55/250], Training Loss: 0.55160037, Training Accuracy: 1.0000
# Epoch [55/250], Validation Loss: 0.69661981, Validation Accuracy: 0.8382
# Epoch [56/250], Training Loss: 0.55159597, Training Accuracy: 1.0000
# Epoch [56/250], Validation Loss: 0.69690949, Validation Accuracy: 0.8382
# Epoch [57/250], Training Loss: 0.55159209, Training Accuracy: 1.0000
# Epoch [57/250], Validation Loss: 0.69714656, Validation Accuracy: 0.8382
# Epoch [58/250], Training Loss: 0.55158819, Training Accuracy: 1.0000
# Epoch [58/250], Validation Loss: 0.69738299, Validation Accuracy: 0.8382
# Epoch [59/250], Training Loss: 0.55158470, Training Accuracy: 1.0000
# Epoch [59/250], Validation Loss: 0.69756541, Validation Accuracy: 0.8382
# Epoch [60/250], Training Loss: 0.55158120, Training Accuracy: 1.0000
# Epoch [60/250], Validation Loss: 0.69778833, Validation Accuracy: 0.8382
# Epoch [61/250], Training Loss: 0.55157797, Training Accuracy: 1.0000
# Epoch [61/250], Validation Loss: 0.69817016, Validation Accuracy: 0.8382
# Epoch [62/250], Training Loss: 0.55157474, Training Accuracy: 1.0000
# Epoch [62/250], Validation Loss: 0.69834927, Validation Accuracy: 0.8382
# Epoch [63/250], Training Loss: 0.55157158, Training Accuracy: 1.0000
# Epoch [63/250], Validation Loss: 0.69857597, Validation Accuracy: 0.8382
# Epoch [64/250], Training Loss: 0.55156870, Training Accuracy: 1.0000
# Epoch [64/250], Validation Loss: 0.69884366, Validation Accuracy: 0.8382
# Epoch [65/250], Training Loss: 0.55156587, Training Accuracy: 1.0000
# Epoch [65/250], Validation Loss: 0.69896379, Validation Accuracy: 0.8382
# Epoch [66/250], Training Loss: 0.55156316, Training Accuracy: 1.0000
# Epoch [66/250], Validation Loss: 0.69914302, Validation Accuracy: 0.8382
# Epoch [67/250], Training Loss: 0.55156046, Training Accuracy: 1.0000
# Epoch [67/250], Validation Loss: 0.69930029, Validation Accuracy: 0.8382
# Epoch [68/250], Training Loss: 0.55155792, Training Accuracy: 1.0000
# Epoch [68/250], Validation Loss: 0.69943342, Validation Accuracy: 0.8382
# Epoch [69/250], Training Loss: 0.55155540, Training Accuracy: 1.0000
# Epoch [69/250], Validation Loss: 0.69964823, Validation Accuracy: 0.8382
# Epoch [70/250], Training Loss: 0.55155314, Training Accuracy: 1.0000
# Epoch [70/250], Validation Loss: 0.69978619, Validation Accuracy: 0.8382
# Epoch [71/250], Training Loss: 0.55155080, Training Accuracy: 1.0000
# Epoch [71/250], Validation Loss: 0.70002395, Validation Accuracy: 0.8382
# Epoch [72/250], Training Loss: 0.55154866, Training Accuracy: 1.0000
# Epoch [72/250], Validation Loss: 0.70012289, Validation Accuracy: 0.8382
# Epoch [73/250], Training Loss: 0.55154651, Training Accuracy: 1.0000
# Epoch [73/250], Validation Loss: 0.70028320, Validation Accuracy: 0.8382
# Epoch [74/250], Training Loss: 0.55154449, Training Accuracy: 1.0000
# Epoch [74/250], Validation Loss: 0.70035383, Validation Accuracy: 0.8382
# Epoch [75/250], Training Loss: 0.55154255, Training Accuracy: 1.0000
# Epoch [75/250], Validation Loss: 0.70045233, Validation Accuracy: 0.8382
# Epoch [76/250], Training Loss: 0.55154049, Training Accuracy: 1.0000
# Epoch [76/250], Validation Loss: 0.70053089, Validation Accuracy: 0.8382
# Epoch [77/250], Training Loss: 0.55153875, Training Accuracy: 1.0000
# Epoch [77/250], Validation Loss: 0.70065805, Validation Accuracy: 0.8382
# Epoch [78/250], Training Loss: 0.55153690, Training Accuracy: 1.0000
# Epoch [78/250], Validation Loss: 0.70071432, Validation Accuracy: 0.8382
# Epoch [79/250], Training Loss: 0.55153515, Training Accuracy: 1.0000
# Epoch [79/250], Validation Loss: 0.70078060, Validation Accuracy: 0.8382
# Epoch [80/250], Training Loss: 0.55153344, Training Accuracy: 1.0000
# Epoch [80/250], Validation Loss: 0.70084998, Validation Accuracy: 0.8382
# Epoch [81/250], Training Loss: 0.55153179, Training Accuracy: 1.0000
# Epoch [81/250], Validation Loss: 0.70089215, Validation Accuracy: 0.8382
# Epoch [82/250], Training Loss: 0.55153025, Training Accuracy: 1.0000
# Epoch [82/250], Validation Loss: 0.70097011, Validation Accuracy: 0.8382
# Epoch [83/250], Training Loss: 0.55152860, Training Accuracy: 1.0000
# Epoch [83/250], Validation Loss: 0.70101959, Validation Accuracy: 0.8382
# Epoch [84/250], Training Loss: 0.55152714, Training Accuracy: 1.0000
# Epoch [84/250], Validation Loss: 0.70109224, Validation Accuracy: 0.8382
# Epoch [85/250], Training Loss: 0.55152569, Training Accuracy: 1.0000
# Epoch [85/250], Validation Loss: 0.70107538, Validation Accuracy: 0.8382
# Epoch [86/250], Training Loss: 0.55152423, Training Accuracy: 1.0000
# Epoch [86/250], Validation Loss: 0.70107123, Validation Accuracy: 0.8382
# Epoch [87/250], Training Loss: 0.55152293, Training Accuracy: 1.0000
# Epoch [87/250], Validation Loss: 0.70106226, Validation Accuracy: 0.8382
# Epoch [88/250], Training Loss: 0.55152154, Training Accuracy: 1.0000
# Epoch [88/250], Validation Loss: 0.70109320, Validation Accuracy: 0.8382
# Epoch [89/250], Training Loss: 0.55152027, Training Accuracy: 1.0000
# Epoch [89/250], Validation Loss: 0.70104918, Validation Accuracy: 0.8382
# Epoch [90/250], Training Loss: 0.55151894, Training Accuracy: 1.0000
# Epoch [90/250], Validation Loss: 0.70106047, Validation Accuracy: 0.8382
# Epoch [91/250], Training Loss: 0.55151777, Training Accuracy: 1.0000
# Epoch [91/250], Validation Loss: 0.70102695, Validation Accuracy: 0.8382
# Epoch [92/250], Training Loss: 0.55151658, Training Accuracy: 1.0000
# Epoch [92/250], Validation Loss: 0.70103762, Validation Accuracy: 0.8382
# Epoch [93/250], Training Loss: 0.55151531, Training Accuracy: 1.0000
# Epoch [93/250], Validation Loss: 0.70103323, Validation Accuracy: 0.8382
# Epoch [94/250], Training Loss: 0.55151426, Training Accuracy: 1.0000
# Epoch [94/250], Validation Loss: 0.70100451, Validation Accuracy: 0.8382
# Epoch [95/250], Training Loss: 0.55151309, Training Accuracy: 1.0000
# Epoch [95/250], Validation Loss: 0.70089114, Validation Accuracy: 0.8382
# Epoch [96/250], Training Loss: 0.55151205, Training Accuracy: 1.0000
# Epoch [96/250], Validation Loss: 0.70089191, Validation Accuracy: 0.8382
# Epoch [97/250], Training Loss: 0.55151096, Training Accuracy: 1.0000
# Epoch [97/250], Validation Loss: 0.70082426, Validation Accuracy: 0.8382
# Epoch [98/250], Training Loss: 0.55150997, Training Accuracy: 1.0000
# Epoch [98/250], Validation Loss: 0.70072845, Validation Accuracy: 0.8382
# Epoch [99/250], Training Loss: 0.55150889, Training Accuracy: 1.0000
# Epoch [99/250], Validation Loss: 0.70063117, Validation Accuracy: 0.8382
# Epoch [100/250], Training Loss: 0.55150799, Training Accuracy: 1.0000
# Epoch [100/250], Validation Loss: 0.70064965, Validation Accuracy: 0.8382
# Epoch [101/250], Training Loss: 0.55150705, Training Accuracy: 1.0000
# Epoch [101/250], Validation Loss: 0.70055309, Validation Accuracy: 0.8529
# Epoch [102/250], Training Loss: 0.55150605, Training Accuracy: 1.0000
# Epoch [102/250], Validation Loss: 0.70056319, Validation Accuracy: 0.8529
# Epoch [103/250], Training Loss: 0.55150516, Training Accuracy: 1.0000
# Epoch [103/250], Validation Loss: 0.70050561, Validation Accuracy: 0.8529
# Epoch [104/250], Training Loss: 0.55150424, Training Accuracy: 1.0000
# Epoch [104/250], Validation Loss: 0.70037940, Validation Accuracy: 0.8529
# Epoch [105/250], Training Loss: 0.55150337, Training Accuracy: 1.0000
# Epoch [105/250], Validation Loss: 0.70029488, Validation Accuracy: 0.8529
# Epoch [106/250], Training Loss: 0.55150252, Training Accuracy: 1.0000
# Epoch [106/250], Validation Loss: 0.70021626, Validation Accuracy: 0.8529
# Epoch [107/250], Training Loss: 0.55150173, Training Accuracy: 1.0000
# Epoch [107/250], Validation Loss: 0.70010599, Validation Accuracy: 0.8529
# Epoch [108/250], Training Loss: 0.55150092, Training Accuracy: 1.0000
# Epoch [108/250], Validation Loss: 0.70001122, Validation Accuracy: 0.8529
# Epoch [109/250], Training Loss: 0.55150008, Training Accuracy: 1.0000
# Epoch [109/250], Validation Loss: 0.69989279, Validation Accuracy: 0.8529
# Epoch [110/250], Training Loss: 0.55149932, Training Accuracy: 1.0000
# Epoch [110/250], Validation Loss: 0.69981009, Validation Accuracy: 0.8529
# Epoch [111/250], Training Loss: 0.55149856, Training Accuracy: 1.0000
# Epoch [111/250], Validation Loss: 0.69968235, Validation Accuracy: 0.8529
# Epoch [112/250], Training Loss: 0.55149782, Training Accuracy: 1.0000
# Epoch [112/250], Validation Loss: 0.69969845, Validation Accuracy: 0.8529
# Epoch [113/250], Training Loss: 0.55149708, Training Accuracy: 1.0000
# Epoch [113/250], Validation Loss: 0.69960466, Validation Accuracy: 0.8529
# Epoch [114/250], Training Loss: 0.55149634, Training Accuracy: 1.0000
# Epoch [114/250], Validation Loss: 0.69950524, Validation Accuracy: 0.8529
# Epoch [115/250], Training Loss: 0.55149568, Training Accuracy: 1.0000
# Epoch [115/250], Validation Loss: 0.69945478, Validation Accuracy: 0.8529
# Epoch [116/250], Training Loss: 0.55149500, Training Accuracy: 1.0000
# Epoch [116/250], Validation Loss: 0.69931093, Validation Accuracy: 0.8529
# Epoch [117/250], Training Loss: 0.55149432, Training Accuracy: 1.0000
# Epoch [117/250], Validation Loss: 0.69923604, Validation Accuracy: 0.8529
# Epoch [118/250], Training Loss: 0.55149370, Training Accuracy: 1.0000
# Epoch [118/250], Validation Loss: 0.69917727, Validation Accuracy: 0.8529
# Epoch [119/250], Training Loss: 0.55149305, Training Accuracy: 1.0000
# Epoch [119/250], Validation Loss: 0.69908586, Validation Accuracy: 0.8529
# Epoch [120/250], Training Loss: 0.55149241, Training Accuracy: 1.0000
# Epoch [120/250], Validation Loss: 0.69902226, Validation Accuracy: 0.8529
# Epoch [121/250], Training Loss: 0.55149181, Training Accuracy: 1.0000
# Epoch [121/250], Validation Loss: 0.69891337, Validation Accuracy: 0.8529
# Epoch [122/250], Training Loss: 0.55149117, Training Accuracy: 1.0000
# Epoch [122/250], Validation Loss: 0.69886872, Validation Accuracy: 0.8529
# Epoch [123/250], Training Loss: 0.55149055, Training Accuracy: 1.0000
# Epoch [123/250], Validation Loss: 0.69875175, Validation Accuracy: 0.8529
# Epoch [124/250], Training Loss: 0.55148999, Training Accuracy: 1.0000
# Epoch [124/250], Validation Loss: 0.69872952, Validation Accuracy: 0.8529
# Epoch [125/250], Training Loss: 0.55148943, Training Accuracy: 1.0000
# Epoch [125/250], Validation Loss: 0.69865784, Validation Accuracy: 0.8529
# Epoch [126/250], Training Loss: 0.55148893, Training Accuracy: 1.0000
# Epoch [126/250], Validation Loss: 0.69860488, Validation Accuracy: 0.8529
# Epoch [127/250], Training Loss: 0.55148832, Training Accuracy: 1.0000
# Epoch [127/250], Validation Loss: 0.69850260, Validation Accuracy: 0.8529
# Epoch [128/250], Training Loss: 0.55148779, Training Accuracy: 1.0000
# Epoch [128/250], Validation Loss: 0.69845816, Validation Accuracy: 0.8529
# Epoch [129/250], Training Loss: 0.55148726, Training Accuracy: 1.0000
# Epoch [129/250], Validation Loss: 0.69837794, Validation Accuracy: 0.8529
# Epoch [130/250], Training Loss: 0.55148676, Training Accuracy: 1.0000
# Epoch [130/250], Validation Loss: 0.69831005, Validation Accuracy: 0.8529
# Epoch [131/250], Training Loss: 0.55148628, Training Accuracy: 1.0000
# Epoch [131/250], Validation Loss: 0.69822505, Validation Accuracy: 0.8529
# Epoch [132/250], Training Loss: 0.55148577, Training Accuracy: 1.0000
# Epoch [132/250], Validation Loss: 0.69819260, Validation Accuracy: 0.8529
# Epoch [133/250], Training Loss: 0.55148527, Training Accuracy: 1.0000
# Epoch [133/250], Validation Loss: 0.69815391, Validation Accuracy: 0.8529
# Epoch [134/250], Training Loss: 0.55148481, Training Accuracy: 1.0000
# Epoch [134/250], Validation Loss: 0.69809899, Validation Accuracy: 0.8529
# Epoch [135/250], Training Loss: 0.55148431, Training Accuracy: 1.0000
# Epoch [135/250], Validation Loss: 0.69807950, Validation Accuracy: 0.8529
# Epoch [136/250], Training Loss: 0.55148388, Training Accuracy: 1.0000
# Epoch [136/250], Validation Loss: 0.69802266, Validation Accuracy: 0.8529
# Epoch [137/250], Training Loss: 0.55148338, Training Accuracy: 1.0000
# Epoch [137/250], Validation Loss: 0.69796094, Validation Accuracy: 0.8529
# Epoch [138/250], Training Loss: 0.55148295, Training Accuracy: 1.0000
# Epoch [138/250], Validation Loss: 0.69795036, Validation Accuracy: 0.8529
# Epoch [139/250], Training Loss: 0.55148255, Training Accuracy: 1.0000
# Epoch [139/250], Validation Loss: 0.69792944, Validation Accuracy: 0.8529
# Epoch [140/250], Training Loss: 0.55148212, Training Accuracy: 1.0000
# Epoch [140/250], Validation Loss: 0.69785899, Validation Accuracy: 0.8529
# Epoch [141/250], Training Loss: 0.55148170, Training Accuracy: 1.0000
# Epoch [141/250], Validation Loss: 0.69781896, Validation Accuracy: 0.8529
# Epoch [142/250], Training Loss: 0.55148128, Training Accuracy: 1.0000
# Epoch [142/250], Validation Loss: 0.69777867, Validation Accuracy: 0.8529
# Epoch [143/250], Training Loss: 0.55148083, Training Accuracy: 1.0000
# Epoch [143/250], Validation Loss: 0.69774899, Validation Accuracy: 0.8529
# Epoch [144/250], Training Loss: 0.55148046, Training Accuracy: 1.0000
# Epoch [144/250], Validation Loss: 0.69775450, Validation Accuracy: 0.8529
# Epoch [145/250], Training Loss: 0.55148003, Training Accuracy: 1.0000
# Epoch [145/250], Validation Loss: 0.69772026, Validation Accuracy: 0.8529
# Epoch [146/250], Training Loss: 0.55147968, Training Accuracy: 1.0000
# Epoch [146/250], Validation Loss: 0.69770515, Validation Accuracy: 0.8529
# Epoch [147/250], Training Loss: 0.55147930, Training Accuracy: 1.0000
# Epoch [147/250], Validation Loss: 0.69768125, Validation Accuracy: 0.8529
# Epoch [148/250], Training Loss: 0.55147892, Training Accuracy: 1.0000
# Epoch [148/250], Validation Loss: 0.69768548, Validation Accuracy: 0.8529
# Epoch [149/250], Training Loss: 0.55147856, Training Accuracy: 1.0000
# Epoch [149/250], Validation Loss: 0.69766620, Validation Accuracy: 0.8529
# Epoch [150/250], Training Loss: 0.55147817, Training Accuracy: 1.0000
# Epoch [150/250], Validation Loss: 0.69763979, Validation Accuracy: 0.8529
# Epoch [151/250], Training Loss: 0.55147782, Training Accuracy: 1.0000
# Epoch [151/250], Validation Loss: 0.69762197, Validation Accuracy: 0.8529
# Epoch [152/250], Training Loss: 0.55147747, Training Accuracy: 1.0000
# Epoch [152/250], Validation Loss: 0.69761711, Validation Accuracy: 0.8529
# Epoch [153/250], Training Loss: 0.55147714, Training Accuracy: 1.0000
# Epoch [153/250], Validation Loss: 0.69759378, Validation Accuracy: 0.8529
# Epoch [154/250], Training Loss: 0.55147685, Training Accuracy: 1.0000
# Epoch [154/250], Validation Loss: 0.69758302, Validation Accuracy: 0.8529
# Epoch [155/250], Training Loss: 0.55147650, Training Accuracy: 1.0000
# Epoch [155/250], Validation Loss: 0.69757169, Validation Accuracy: 0.8529
# Epoch [156/250], Training Loss: 0.55147615, Training Accuracy: 1.0000
# Epoch [156/250], Validation Loss: 0.69757396, Validation Accuracy: 0.8529
# Epoch [157/250], Training Loss: 0.55147583, Training Accuracy: 1.0000
# Epoch [157/250], Validation Loss: 0.69757780, Validation Accuracy: 0.8529
# Epoch [158/250], Training Loss: 0.55147549, Training Accuracy: 1.0000
# Epoch [158/250], Validation Loss: 0.69757438, Validation Accuracy: 0.8529
# Epoch [159/250], Training Loss: 0.55147520, Training Accuracy: 1.0000
# Epoch [159/250], Validation Loss: 0.69756117, Validation Accuracy: 0.8529
# Epoch [160/250], Training Loss: 0.55147485, Training Accuracy: 1.0000
# Epoch [160/250], Validation Loss: 0.69757271, Validation Accuracy: 0.8529
# Epoch [161/250], Training Loss: 0.55147455, Training Accuracy: 1.0000
# Epoch [161/250], Validation Loss: 0.69755954, Validation Accuracy: 0.8529
# Epoch [162/250], Training Loss: 0.55147425, Training Accuracy: 1.0000
# Epoch [162/250], Validation Loss: 0.69756353, Validation Accuracy: 0.8529
# Epoch [163/250], Training Loss: 0.55147397, Training Accuracy: 1.0000
# Epoch [163/250], Validation Loss: 0.69756410, Validation Accuracy: 0.8529
# Epoch [164/250], Training Loss: 0.55147369, Training Accuracy: 1.0000
# Epoch [164/250], Validation Loss: 0.69756129, Validation Accuracy: 0.8529
# Epoch [165/250], Training Loss: 0.55147339, Training Accuracy: 1.0000
# Epoch [165/250], Validation Loss: 0.69755670, Validation Accuracy: 0.8529
# Epoch [166/250], Training Loss: 0.55147312, Training Accuracy: 1.0000
# Epoch [166/250], Validation Loss: 0.69756845, Validation Accuracy: 0.8529
# Epoch [167/250], Training Loss: 0.55147284, Training Accuracy: 1.0000
# Epoch [167/250], Validation Loss: 0.69757679, Validation Accuracy: 0.8529
# Epoch [168/250], Training Loss: 0.55147256, Training Accuracy: 1.0000
# Epoch [168/250], Validation Loss: 0.69757539, Validation Accuracy: 0.8529
# Epoch [169/250], Training Loss: 0.55147230, Training Accuracy: 1.0000
# Epoch [169/250], Validation Loss: 0.69758311, Validation Accuracy: 0.8529
# Epoch [170/250], Training Loss: 0.55147203, Training Accuracy: 1.0000
# Epoch [170/250], Validation Loss: 0.69759300, Validation Accuracy: 0.8529
# Epoch [171/250], Training Loss: 0.55147178, Training Accuracy: 1.0000
# Epoch [171/250], Validation Loss: 0.69759405, Validation Accuracy: 0.8529
# Epoch [172/250], Training Loss: 0.55147149, Training Accuracy: 1.0000
# Epoch [172/250], Validation Loss: 0.69759715, Validation Accuracy: 0.8529
# Epoch [173/250], Training Loss: 0.55147126, Training Accuracy: 1.0000
# Epoch [173/250], Validation Loss: 0.69759610, Validation Accuracy: 0.8529
# Epoch [174/250], Training Loss: 0.55147102, Training Accuracy: 1.0000
# Epoch [174/250], Validation Loss: 0.69759968, Validation Accuracy: 0.8529
# Epoch [175/250], Training Loss: 0.55147076, Training Accuracy: 1.0000
# Epoch [175/250], Validation Loss: 0.69759893, Validation Accuracy: 0.8529
# Epoch [176/250], Training Loss: 0.55147053, Training Accuracy: 1.0000
# Epoch [176/250], Validation Loss: 0.69762152, Validation Accuracy: 0.8529
# Epoch [177/250], Training Loss: 0.55147027, Training Accuracy: 1.0000
# Epoch [177/250], Validation Loss: 0.69762841, Validation Accuracy: 0.8529
# Epoch [178/250], Training Loss: 0.55147002, Training Accuracy: 1.0000
# Epoch [178/250], Validation Loss: 0.69764286, Validation Accuracy: 0.8529
# Epoch [179/250], Training Loss: 0.55146981, Training Accuracy: 1.0000
# Epoch [179/250], Validation Loss: 0.69765505, Validation Accuracy: 0.8529
# Epoch [180/250], Training Loss: 0.55146957, Training Accuracy: 1.0000
# Epoch [180/250], Validation Loss: 0.69767451, Validation Accuracy: 0.8529
# Epoch [181/250], Training Loss: 0.55146933, Training Accuracy: 1.0000
# Epoch [181/250], Validation Loss: 0.69767946, Validation Accuracy: 0.8529
# Epoch [182/250], Training Loss: 0.55146914, Training Accuracy: 1.0000
# Epoch [182/250], Validation Loss: 0.69768086, Validation Accuracy: 0.8529
# Epoch [183/250], Training Loss: 0.55146888, Training Accuracy: 1.0000
# Epoch [183/250], Validation Loss: 0.69770384, Validation Accuracy: 0.8529
# Epoch [184/250], Training Loss: 0.55146870, Training Accuracy: 1.0000
# Epoch [184/250], Validation Loss: 0.69771832, Validation Accuracy: 0.8529
# Epoch [185/250], Training Loss: 0.55146853, Training Accuracy: 1.0000
# Epoch [185/250], Validation Loss: 0.69772288, Validation Accuracy: 0.8529
# Epoch [186/250], Training Loss: 0.55146828, Training Accuracy: 1.0000
# Epoch [186/250], Validation Loss: 0.69772434, Validation Accuracy: 0.8529
# Epoch [187/250], Training Loss: 0.55146807, Training Accuracy: 1.0000
# Epoch [187/250], Validation Loss: 0.69773954, Validation Accuracy: 0.8529
# Epoch [188/250], Training Loss: 0.55146784, Training Accuracy: 1.0000
# Epoch [188/250], Validation Loss: 0.69774750, Validation Accuracy: 0.8529
# Epoch [189/250], Training Loss: 0.55146764, Training Accuracy: 1.0000
# Epoch [189/250], Validation Loss: 0.69776404, Validation Accuracy: 0.8529
# Epoch [190/250], Training Loss: 0.55146745, Training Accuracy: 1.0000
# Epoch [190/250], Validation Loss: 0.69775808, Validation Accuracy: 0.8529
# Epoch [191/250], Training Loss: 0.55146723, Training Accuracy: 1.0000
# Epoch [191/250], Validation Loss: 0.69775063, Validation Accuracy: 0.8529
# Epoch [192/250], Training Loss: 0.55146707, Training Accuracy: 1.0000
# Epoch [192/250], Validation Loss: 0.69777071, Validation Accuracy: 0.8529
# Epoch [193/250], Training Loss: 0.55146687, Training Accuracy: 1.0000
# Epoch [193/250], Validation Loss: 0.69780225, Validation Accuracy: 0.8529
# Epoch [194/250], Training Loss: 0.55146669, Training Accuracy: 1.0000
# Epoch [194/250], Validation Loss: 0.69781259, Validation Accuracy: 0.8529
# Epoch [195/250], Training Loss: 0.55146643, Training Accuracy: 1.0000
# Epoch [195/250], Validation Loss: 0.69783548, Validation Accuracy: 0.8529
# Epoch [196/250], Training Loss: 0.55146630, Training Accuracy: 1.0000
# Epoch [196/250], Validation Loss: 0.69783598, Validation Accuracy: 0.8529
# Epoch [197/250], Training Loss: 0.55146612, Training Accuracy: 1.0000
# Epoch [197/250], Validation Loss: 0.69783032, Validation Accuracy: 0.8529
# Epoch [198/250], Training Loss: 0.55146593, Training Accuracy: 1.0000
# Epoch [198/250], Validation Loss: 0.69784898, Validation Accuracy: 0.8529
# Epoch [199/250], Training Loss: 0.55146575, Training Accuracy: 1.0000
# Epoch [199/250], Validation Loss: 0.69787121, Validation Accuracy: 0.8529
# Epoch [200/250], Training Loss: 0.55146557, Training Accuracy: 1.0000
# Epoch [200/250], Validation Loss: 0.69788247, Validation Accuracy: 0.8529
# Epoch [201/250], Training Loss: 0.55146539, Training Accuracy: 1.0000
# Epoch [201/250], Validation Loss: 0.69788536, Validation Accuracy: 0.8529
# Epoch [202/250], Training Loss: 0.55146525, Training Accuracy: 1.0000
# Epoch [202/250], Validation Loss: 0.69790038, Validation Accuracy: 0.8529
# Epoch [203/250], Training Loss: 0.55146506, Training Accuracy: 1.0000
# Epoch [203/250], Validation Loss: 0.69789791, Validation Accuracy: 0.8529
# Epoch [204/250], Training Loss: 0.55146488, Training Accuracy: 1.0000
# Epoch [204/250], Validation Loss: 0.69789839, Validation Accuracy: 0.8529
# Epoch [205/250], Training Loss: 0.55146473, Training Accuracy: 1.0000
# Epoch [205/250], Validation Loss: 0.69790706, Validation Accuracy: 0.8529
# Epoch [206/250], Training Loss: 0.55146455, Training Accuracy: 1.0000
# Epoch [206/250], Validation Loss: 0.69792828, Validation Accuracy: 0.8529
# Epoch [207/250], Training Loss: 0.55146437, Training Accuracy: 1.0000
# Epoch [207/250], Validation Loss: 0.69792423, Validation Accuracy: 0.8529
# Epoch [208/250], Training Loss: 0.55146421, Training Accuracy: 1.0000
# Epoch [208/250], Validation Loss: 0.69794011, Validation Accuracy: 0.8529
# Epoch [209/250], Training Loss: 0.55146410, Training Accuracy: 1.0000
# Epoch [209/250], Validation Loss: 0.69793525, Validation Accuracy: 0.8529
# Epoch [210/250], Training Loss: 0.55146393, Training Accuracy: 1.0000
# Epoch [210/250], Validation Loss: 0.69797215, Validation Accuracy: 0.8529
# Epoch [211/250], Training Loss: 0.55146376, Training Accuracy: 1.0000
# Epoch [211/250], Validation Loss: 0.69801128, Validation Accuracy: 0.8529
# Epoch [212/250], Training Loss: 0.55146359, Training Accuracy: 1.0000
# Epoch [212/250], Validation Loss: 0.69802347, Validation Accuracy: 0.8529
# Epoch [213/250], Training Loss: 0.55146348, Training Accuracy: 1.0000
# Epoch [213/250], Validation Loss: 0.69801956, Validation Accuracy: 0.8529
# Epoch [214/250], Training Loss: 0.55146328, Training Accuracy: 1.0000
# Epoch [214/250], Validation Loss: 0.69805044, Validation Accuracy: 0.8529
# Epoch [215/250], Training Loss: 0.55146315, Training Accuracy: 1.0000
# Epoch [215/250], Validation Loss: 0.69804251, Validation Accuracy: 0.8529
# Epoch [216/250], Training Loss: 0.55146302, Training Accuracy: 1.0000
# Epoch [216/250], Validation Loss: 0.69805294, Validation Accuracy: 0.8529
# Epoch [217/250], Training Loss: 0.55146285, Training Accuracy: 1.0000
# Epoch [217/250], Validation Loss: 0.69803771, Validation Accuracy: 0.8529
# Epoch [218/250], Training Loss: 0.55146272, Training Accuracy: 1.0000
# Epoch [218/250], Validation Loss: 0.69803891, Validation Accuracy: 0.8529
# Epoch [219/250], Training Loss: 0.55146260, Training Accuracy: 1.0000
# Epoch [219/250], Validation Loss: 0.69806302, Validation Accuracy: 0.8529
# Epoch [220/250], Training Loss: 0.55146243, Training Accuracy: 1.0000
# Epoch [220/250], Validation Loss: 0.69808301, Validation Accuracy: 0.8529
# Epoch [221/250], Training Loss: 0.55146235, Training Accuracy: 1.0000
# Epoch [221/250], Validation Loss: 0.69805619, Validation Accuracy: 0.8529
# Epoch [222/250], Training Loss: 0.55146216, Training Accuracy: 1.0000
# Epoch [222/250], Validation Loss: 0.69808021, Validation Accuracy: 0.8529
# Epoch [223/250], Training Loss: 0.55146203, Training Accuracy: 1.0000
# Epoch [223/250], Validation Loss: 0.69806609, Validation Accuracy: 0.8529
# Epoch [224/250], Training Loss: 0.55146189, Training Accuracy: 1.0000
# Epoch [224/250], Validation Loss: 0.69806743, Validation Accuracy: 0.8529
# Epoch [225/250], Training Loss: 0.55146178, Training Accuracy: 1.0000
# Epoch [225/250], Validation Loss: 0.69808790, Validation Accuracy: 0.8529
# Epoch [226/250], Training Loss: 0.55146165, Training Accuracy: 1.0000
# Epoch [226/250], Validation Loss: 0.69815546, Validation Accuracy: 0.8529
# Epoch [227/250], Training Loss: 0.55146149, Training Accuracy: 1.0000
# Epoch [227/250], Validation Loss: 0.69813982, Validation Accuracy: 0.8529
# Epoch [228/250], Training Loss: 0.55146138, Training Accuracy: 1.0000
# Epoch [228/250], Validation Loss: 0.69819391, Validation Accuracy: 0.8529
# Epoch [229/250], Training Loss: 0.55146123, Training Accuracy: 1.0000
# Epoch [229/250], Validation Loss: 0.69817042, Validation Accuracy: 0.8529
# Epoch [230/250], Training Loss: 0.55146112, Training Accuracy: 1.0000
# Epoch [230/250], Validation Loss: 0.69816127, Validation Accuracy: 0.8529
# Epoch [231/250], Training Loss: 0.55146099, Training Accuracy: 1.0000
# Epoch [231/250], Validation Loss: 0.69810471, Validation Accuracy: 0.8529
# Epoch [232/250], Training Loss: 0.55146089, Training Accuracy: 1.0000
# Epoch [232/250], Validation Loss: 0.69818199, Validation Accuracy: 0.8529
# Epoch [233/250], Training Loss: 0.55146078, Training Accuracy: 1.0000
# Epoch [233/250], Validation Loss: 0.69815090, Validation Accuracy: 0.8529
# Epoch [234/250], Training Loss: 0.55146065, Training Accuracy: 1.0000
# Epoch [234/250], Validation Loss: 0.69820225, Validation Accuracy: 0.8529
# Epoch [235/250], Training Loss: 0.55146057, Training Accuracy: 1.0000
# Epoch [235/250], Validation Loss: 0.69815573, Validation Accuracy: 0.8529
# Epoch [236/250], Training Loss: 0.55146039, Training Accuracy: 1.0000
# Epoch [236/250], Validation Loss: 0.69817248, Validation Accuracy: 0.8529
# Epoch [237/250], Training Loss: 0.55146029, Training Accuracy: 1.0000
# Epoch [237/250], Validation Loss: 0.69820520, Validation Accuracy: 0.8529
# Epoch [238/250], Training Loss: 0.55146019, Training Accuracy: 1.0000
# Epoch [238/250], Validation Loss: 0.69821048, Validation Accuracy: 0.8529
# Epoch [239/250], Training Loss: 0.55146007, Training Accuracy: 1.0000
# Epoch [239/250], Validation Loss: 0.69818935, Validation Accuracy: 0.8529
# Epoch [240/250], Training Loss: 0.55145999, Training Accuracy: 1.0000
# Epoch [240/250], Validation Loss: 0.69813517, Validation Accuracy: 0.8529
# Epoch [241/250], Training Loss: 0.55145987, Training Accuracy: 1.0000
# Epoch [241/250], Validation Loss: 0.69813132, Validation Accuracy: 0.8529
# Epoch [242/250], Training Loss: 0.55145971, Training Accuracy: 1.0000
# Epoch [242/250], Validation Loss: 0.69820350, Validation Accuracy: 0.8529
# Epoch [243/250], Training Loss: 0.55145962, Training Accuracy: 1.0000
# Epoch [243/250], Validation Loss: 0.69815782, Validation Accuracy: 0.8529
# Epoch [244/250], Training Loss: 0.55145953, Training Accuracy: 1.0000
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Epoch [244/250], Validation Loss: 0.69813824, Validation Accuracy: 0.8529
# Epoch [245/250], Training Loss: 0.55145942, Training Accuracy: 1.0000
# Epoch [245/250], Validation Loss: 0.69819173, Validation Accuracy: 0.8529
# Epoch [246/250], Training Loss: 0.55145934, Training Accuracy: 1.0000
# Epoch [246/250], Validation Loss: 0.69817498, Validation Accuracy: 0.8529
# Epoch [247/250], Training Loss: 0.55145923, Training Accuracy: 1.0000
# Epoch [247/250], Validation Loss: 0.69813871, Validation Accuracy: 0.8529
# Epoch [248/250], Training Loss: 0.55145909, Training Accuracy: 1.0000
# Epoch [248/250], Validation Loss: 0.69815651, Validation Accuracy: 0.8529
# Epoch [249/250], Training Loss: 0.55145900, Training Accuracy: 1.0000
# Epoch [249/250], Validation Loss: 0.69818738, Validation Accuracy: 0.8529
# Epoch [250/250], Training Loss: 0.55145890, Training Accuracy: 1.0000
# Epoch [250/250], Validation Loss: 0.69818339, Validation Accuracy: 0.8529

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.5f}')
# Out:
# Test Accuracy: 0.85294

# %% [markdown]
# ##### Analysis GRU
# Validation accuracy is 0.8529 at 250 epochs. Test accuracy is 0.85294.

# %% [markdown]
# ##### Final notes on the 2 layer runs
# |  | epochs | validation accuracy (%) | test accuracy (%) | time (s) |
# | --- | --- | ---| --- | --- |
# | RNN | 300 | 75.00 | 64.706 | 4.9 |
# | LSTM | 60 | 89.71 | 88.235 | 1.9 |
# | GRU | 250 | 85.29 | 85.294 | 4.6 |
#
# LSTM is rated highest and matches its own single layer performance. Next is GRU which rates about 3% lower than LSTM, RNN which is more than 20% down.
#
# The LSTM was the fastest here, but also faster than its single layer performance. What is not shown in the figures is how the different methods react when approaching their training limits. The RNN validation accuracy flattens out while the LSTM and GRU both jump to lower validation accuracy at higher epochs.
#
# When the dataset was not shuffled all methods showed lower test accuracies, with the RNN being the worst at about 53%.
#
# Generally we have an expectation of uniformity in the trials data of the dataset when we assume data leakage must be present to explain such a large variance in test accuracy. However, shuffling prior to slicing into training, validation and test sets cannot introduce data leakage because no results from training were carried over to the selection of data from the dataset. The test set was always held in reserve to be evaluated after training.
#
# The uniformity hypothesis, however, is rarely true for neural data recordings. For the Steinmetz `spks` dataset, 340 trials were recorded in one session. We can expect to see reductions in probe sensitivity and mouse responses over time, and therefore trials, as the recording session progesses. When the trials are not shuffled the first 238 trials go towards the training set, the next 68 trials go into the validation set and the last 32 trials go into the test set. Therefore the test set is heavily biased towards reduced probe sensitivity effects and fatigued mouse behaviours.
#
# By shuffling the dataset before slicing into training, validation and test sets we spread out the variance introduced by reduced probe sensitivity and mouse fatigue over the complete trial set, thereby increasing training ability and validation and test accuracies.
#
# Dropout was tried, but there was a small reduction in accuracies. There was a warning that dropout should not be applied to a single layer (which is true for the RNN, LSTM, or GRU methods used in this notebook), so dropout was dropped.
#
# Except for LSTM, the 2 layer methods performed poorly compared with their single layer values.
