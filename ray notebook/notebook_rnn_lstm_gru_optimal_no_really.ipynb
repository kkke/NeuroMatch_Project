# %% [markdown]
# #### RNN, LSTM, GRU classification of mouse wheel movement based on Steinmetz `spks` dataset and code from [nma](https://deeplearning.neuromatch.io/projects/Neuroscience/neuro_seq_to_seq.html)
#
# __Note__: You must restart the notebook for training the LSTM and GRU models and each time you rerun a model. This appears to be an issue of the previous model remaining on the GPU after training.

# %% [markdown]
# ##### Imports

# %%
# Imports
import torch
import random
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets, io, models, ops, transforms, utils
from matplotlib import pyplot as plt

# %% [markdown]
# ##### Device

# %%
# @title Set device (GPU or CPU). Execute `set_device()`

# Inform the user if the notebook uses GPU or CPU.

def set_device():
  """
  Set the device. CUDA if available, CPU otherwise

  Args:
    None

  Returns:
    Nothing
  """
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
  else:
    print("GPU is enabled in this notebook.")

  return device

# %% [markdown]
# ##### Set random seed

# %%
# @markdown Executing `set_seed(seed=seed)` you are setting the seed

# For DL its critical to set the random seed so that students can have a
# baseline to compare their results to expected results.
# Read more here: https://pytorch.org/docs/stable/notes/randomness.html

# Call `set_seed` function in the exercises to ensure reproducibility.

def set_seed(seed=None, seed_torch=True):
  """
  Function that controls randomness. NumPy and random modules must be imported.

  Args:
    seed : Integer
      A non-negative integer that defines the random state. Default is `None`.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors, so pytorch module
      must be imported. Default is `True`.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):
  """
  DataLoader will reseed workers following randomness in
  multi-process data loading algorithm.

  Args:
    worker_id: integer
      ID of subprocess to seed. 0 means that
      the data will be loaded in the main process
      Refer: https://pytorch.org/docs/stable/data.html#data-loading-randomness for more details

  Returns:
    Nothing
  """
  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)

# %%
SEED = 2021
set_seed(seed=SEED)
device = set_device()
# Out:
# Random seed 2021 has been set.
# GPU is enabled in this notebook.

# %% [markdown]
# ##### Data retrieval

# %%
# store the dataset files in the datasets folder
import os, requests

fname = []
ds = "../datasets"

for j in range(3):
  fname.append('steinmetz_part%d.npz'%j)
url = ["https://osf.io/agvxh/download"]
url.append("https://osf.io/uv3mw/download")
url.append("https://osf.io/ehmw2/download")

for j in range(len(url)):
  if not os.path.isfile("/".join([ds, fname[j]])):
    try:
      r = requests.get(url[j])
    except requests.ConnectionError:
      print("!!! Failed to download data !!!")
    else:
      if r.status_code != requests.codes.ok:
        print("!!! Failed to download data !!!")
      else:
        with open("/".join([ds, fname[j]]), "wb") as fid:
          fid.write(r.content)

# %%
# data loading
alldat = np.array([])
for j in range(len(fname)):
  alldat = np.hstack((alldat,
                      np.load("/".join([ds, 'steinmetz_part%d.npz'%j]),
                              allow_pickle=True)['dat']))

# %% [markdown]
# ##### Select recording 11

# %%
# select recording 11
dat = alldat[11]

# %% [markdown]
# ##### Format dataset
# An RNN has specific data requirements fed into the network for training, testing, and prediction. The depth of the network in a time or data series is given by `hidden_size`. In the case of the `spks` dataset this is 250 because one trial lasts for this many samples. These are the 250 sequenced datapoints related to the same mouse event trial from the same probe sensor size of 698 neurons over a time period of 2500ms. Further mouse trials are added in sequence in the dataset, where the training and forward algorithms reset to the start of the RNN. This dataset is then 698 neurons wide with 250 datapoints and 340 trials in length, before being split into train and test sets.

# %%
# data are neurons X trials x time samples, but permute to trials X time samples X neurons
x = torch.tensor(dat['spks']).permute(1,2,0)
x = x[:,50:150,:]

# response is -1, 0, 1, but convert to one hot where 2 takes the place of -1 to satisfy torch one hot
dat['response'][dat['response'] == -1] = 2 
y = torch.as_tensor(dat['response']).long()
y = F.one_hot(y)

# shuffle dataset


# split into train (70%), validation(20%) and test(10%) sets using batch size of 34
n_trials = int(x.shape[0])
ntr = int(n_trials * 7 / 10)
nv = int(n_trials * 2 / 10) + ntr

X_train = x[:ntr, :, :].to(device).float()
X_val = x[ntr:nv, :, :].to(device).float()
X_test = x[nv:, :, :].to(device).float()

y_train = y[:ntr].to(device).float()
y_val = y[ntr:nv].to(device).float()
y_test = y[nv:].to(device).float()

# %%
print(y[0])
print(x.shape)
print(y.shape)
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# tensor([1, 0, 0])
# torch.Size([340, 100, 698])
# torch.Size([340, 3])
# torch.Size([238, 100, 698])
# torch.Size([238, 3])
# torch.Size([68, 100, 698])
# torch.Size([68, 3])
# torch.Size([34, 100, 698])
# torch.Size([34, 3])

# %%
##### Visualise data from one trial
plt.figure(figsize = (10, 6))
plt.imshow(x[0,:,:].T, cmap='gray_r', vmax = 3, vmin=0, aspect='auto')
plt.xticks([0, 20, 40, 60, 80], [500, 700, 900, 1100, 1300]) 
plt.xlabel('Time (ms) with 10ms bins')
plt.ylabel('Cell #')
plt.colorbar(orientation='vertical', label='# Spikes in 10ms time bin')
plt.title('Example trial')
plt.show()

# %% [markdown]
# ##### Dataloader

# %%
# batch_size of 34 used to match number of trials
batch_size = 34

# Create DataLoader for training data
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Create DataLoader for validation data
val_dataset = TensorDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Create DataLoader for test data
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### Hyperparameters

# %%
# number of hidden RNN stages, inputs and outputs
hidden_size = x.shape[1]
input_size = x.shape[2]
output_size = y_train.shape[1]
num_layers = 1
learning_rate = 0.003
number_of_epochs = 10000
RNN_number_of_epochs = 200
LSTM_number_of_epochs = 100
GRU_number_of_epochs = 75

# %%
print(hidden_size)
print(input_size)
print(output_size)
# Out:
# 100
# 698
# 3

# %% [markdown]
# ##### Define RNN
# Since the `hidden_size` is 250 we can expect to see either exploding or vanishing gradients in the RNN. For this case we can't expect the RNN to be able to predict well. But, as Dev did, we can reduce the `hidden_size` by slicing off data which doesn't correspond to wheel movement.

# %%
# chatgpt 3.5 generated code
# RNN Model with Softmax
class RNNWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(RNNWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Define the RNN layer
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        
        # Define the fully connected layer to map RNN output to class labels
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        # h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.rnn(x, h0)

        # Use only the last time step's output for classification
        out = self.fc(out[:, -1, :]) 

        # Apply softmax activation
        return nn.functional.softmax(out, dim=1)

# %% [markdown]
# ##### Train the RNN: setup

# %%
# chatgpt 3.5 generated code
model = RNNWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ##### Train the RNN and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code
# Training loop
# RNN_total_epochs = number_of_epochs
RNN_total_epochs = RNN_number_of_epochs

# Lists to store training/validation losses and training/validation accuracies
RNN_train_losses = []  
RNN_val_losses = []    
RNN_train_accuracies = []  
RNN_val_accuracies = []    

for epoch in range(RNN_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    RNN_train_losses.append(average_train_loss)
    RNN_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{RNN_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Store validation loss and accuracy values
    RNN_val_losses.append(average_val_loss)
    RNN_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{RNN_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')

# Plot the losses and accuracies at the end of all epochs
RNN_x_epochs = list(range(1, RNN_total_epochs + 1))

plt.figure(figsize=(12, 4))

# Plot Losses
plt.subplot(1, 2, 1)
plt.plot(RNN_x_epochs, RNN_train_losses, label='RNN Training Loss')
plt.plot(RNN_x_epochs, RNN_val_losses, label='RNN Validation Loss')
plt.xlabel('RNN Epochs')
plt.ylabel('RNN Loss')
plt.title('RNN Training and Validation Loss')
plt.legend()

# Plot Accuracies
plt.subplot(1, 2, 2)
plt.plot(RNN_x_epochs, RNN_train_accuracies, label='RNN Training Accuracy')
plt.plot(RNN_x_epochs, RNN_val_accuracies, label='RNN Validation Accuracy')
plt.xlabel('RNN Epochs')
plt.ylabel('RNN Accuracy')
plt.title('RNN Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/200], Training Loss: 1.05597766, Training Accuracy: 0.4454
# Epoch [1/200], Validation Loss: 1.06257397, Validation Accuracy: 0.3676
# Epoch [2/200], Training Loss: 0.94559876, Training Accuracy: 0.5966
# Epoch [2/200], Validation Loss: 0.97351381, Validation Accuracy: 0.6176
# Epoch [3/200], Training Loss: 0.80982793, Training Accuracy: 0.8908
# Epoch [3/200], Validation Loss: 0.97102642, Validation Accuracy: 0.5441
# Epoch [4/200], Training Loss: 0.63517761, Training Accuracy: 0.9832
# Epoch [4/200], Validation Loss: 0.86670807, Validation Accuracy: 0.6765
# Epoch [5/200], Training Loss: 0.57137954, Training Accuracy: 1.0000
# Epoch [5/200], Validation Loss: 0.94492486, Validation Accuracy: 0.5735
# Epoch [6/200], Training Loss: 0.55667023, Training Accuracy: 1.0000
# Epoch [6/200], Validation Loss: 0.89597318, Validation Accuracy: 0.6471
# Epoch [7/200], Training Loss: 0.55355372, Training Accuracy: 1.0000
# Epoch [7/200], Validation Loss: 0.91513774, Validation Accuracy: 0.6176
# Epoch [8/200], Training Loss: 0.55241484, Training Accuracy: 1.0000
# Epoch [8/200], Validation Loss: 0.89716759, Validation Accuracy: 0.6176
# Epoch [9/200], Training Loss: 0.55200956, Training Accuracy: 1.0000
# Epoch [9/200], Validation Loss: 0.86299688, Validation Accuracy: 0.6765
# Epoch [10/200], Training Loss: 0.55186544, Training Accuracy: 1.0000
# Epoch [10/200], Validation Loss: 0.84892651, Validation Accuracy: 0.7059
# Epoch [11/200], Training Loss: 0.55179099, Training Accuracy: 1.0000
# Epoch [11/200], Validation Loss: 0.85442504, Validation Accuracy: 0.6912
# Epoch [12/200], Training Loss: 0.55173354, Training Accuracy: 1.0000
# Epoch [12/200], Validation Loss: 0.86376831, Validation Accuracy: 0.6618
# Epoch [13/200], Training Loss: 0.55170186, Training Accuracy: 1.0000
# Epoch [13/200], Validation Loss: 0.86655003, Validation Accuracy: 0.6618
# Epoch [14/200], Training Loss: 0.55167941, Training Accuracy: 1.0000
# Epoch [14/200], Validation Loss: 0.86695892, Validation Accuracy: 0.6618
# Epoch [15/200], Training Loss: 0.55166327, Training Accuracy: 1.0000
# Epoch [15/200], Validation Loss: 0.86634630, Validation Accuracy: 0.6618
# Epoch [16/200], Training Loss: 0.55165000, Training Accuracy: 1.0000
# Epoch [16/200], Validation Loss: 0.86599946, Validation Accuracy: 0.6471
# Epoch [17/200], Training Loss: 0.55163842, Training Accuracy: 1.0000
# Epoch [17/200], Validation Loss: 0.86559787, Validation Accuracy: 0.6471
# Epoch [18/200], Training Loss: 0.55162853, Training Accuracy: 1.0000
# Epoch [18/200], Validation Loss: 0.86550543, Validation Accuracy: 0.6471
# Epoch [19/200], Training Loss: 0.55161957, Training Accuracy: 1.0000
# Epoch [19/200], Validation Loss: 0.86481813, Validation Accuracy: 0.6471
# Epoch [20/200], Training Loss: 0.55161129, Training Accuracy: 1.0000
# Epoch [20/200], Validation Loss: 0.86350524, Validation Accuracy: 0.6618
# Epoch [21/200], Training Loss: 0.55160379, Training Accuracy: 1.0000
# Epoch [21/200], Validation Loss: 0.86247551, Validation Accuracy: 0.6618
# Epoch [22/200], Training Loss: 0.55159711, Training Accuracy: 1.0000
# Epoch [22/200], Validation Loss: 0.86240843, Validation Accuracy: 0.6618
# Epoch [23/200], Training Loss: 0.55159079, Training Accuracy: 1.0000
# Epoch [23/200], Validation Loss: 0.86190709, Validation Accuracy: 0.6618
# Epoch [24/200], Training Loss: 0.55158478, Training Accuracy: 1.0000
# Epoch [24/200], Validation Loss: 0.86102673, Validation Accuracy: 0.6618
# Epoch [25/200], Training Loss: 0.55157921, Training Accuracy: 1.0000
# Epoch [25/200], Validation Loss: 0.86031073, Validation Accuracy: 0.6618
# Epoch [26/200], Training Loss: 0.55157405, Training Accuracy: 1.0000
# Epoch [26/200], Validation Loss: 0.85884857, Validation Accuracy: 0.6618
# Epoch [27/200], Training Loss: 0.55156911, Training Accuracy: 1.0000
# Epoch [27/200], Validation Loss: 0.85785058, Validation Accuracy: 0.6618
# Epoch [28/200], Training Loss: 0.55156457, Training Accuracy: 1.0000
# Epoch [28/200], Validation Loss: 0.85732442, Validation Accuracy: 0.6618
# Epoch [29/200], Training Loss: 0.55156043, Training Accuracy: 1.0000
# Epoch [29/200], Validation Loss: 0.85681346, Validation Accuracy: 0.6618
# Epoch [30/200], Training Loss: 0.55155631, Training Accuracy: 1.0000
# Epoch [30/200], Validation Loss: 0.85578868, Validation Accuracy: 0.6618
# Epoch [31/200], Training Loss: 0.55155247, Training Accuracy: 1.0000
# Epoch [31/200], Validation Loss: 0.85537884, Validation Accuracy: 0.6618
# Epoch [32/200], Training Loss: 0.55154904, Training Accuracy: 1.0000
# Epoch [32/200], Validation Loss: 0.85567483, Validation Accuracy: 0.6618
# Epoch [33/200], Training Loss: 0.55154553, Training Accuracy: 1.0000
# Epoch [33/200], Validation Loss: 0.85551491, Validation Accuracy: 0.6618
# Epoch [34/200], Training Loss: 0.55154229, Training Accuracy: 1.0000
# Epoch [34/200], Validation Loss: 0.85362488, Validation Accuracy: 0.6618
# Epoch [35/200], Training Loss: 0.55153924, Training Accuracy: 1.0000
# Epoch [35/200], Validation Loss: 0.85221946, Validation Accuracy: 0.6618
# Epoch [36/200], Training Loss: 0.55153636, Training Accuracy: 1.0000
# Epoch [36/200], Validation Loss: 0.85142037, Validation Accuracy: 0.6618
# Epoch [37/200], Training Loss: 0.55153355, Training Accuracy: 1.0000
# Epoch [37/200], Validation Loss: 0.85091269, Validation Accuracy: 0.6618
# Epoch [38/200], Training Loss: 0.55153092, Training Accuracy: 1.0000
# Epoch [38/200], Validation Loss: 0.85070753, Validation Accuracy: 0.6618
# Epoch [39/200], Training Loss: 0.55152837, Training Accuracy: 1.0000
# Epoch [39/200], Validation Loss: 0.85029092, Validation Accuracy: 0.6618
# Epoch [40/200], Training Loss: 0.55152603, Training Accuracy: 1.0000
# Epoch [40/200], Validation Loss: 0.84960315, Validation Accuracy: 0.6618
# Epoch [41/200], Training Loss: 0.55152369, Training Accuracy: 1.0000
# Epoch [41/200], Validation Loss: 0.84808579, Validation Accuracy: 0.6765
# Epoch [42/200], Training Loss: 0.55152154, Training Accuracy: 1.0000
# Epoch [42/200], Validation Loss: 0.84736633, Validation Accuracy: 0.6765
# Epoch [43/200], Training Loss: 0.55151949, Training Accuracy: 1.0000
# Epoch [43/200], Validation Loss: 0.84624040, Validation Accuracy: 0.6912
# Epoch [44/200], Training Loss: 0.55151740, Training Accuracy: 1.0000
# Epoch [44/200], Validation Loss: 0.84654966, Validation Accuracy: 0.6912
# Epoch [45/200], Training Loss: 0.55151555, Training Accuracy: 1.0000
# Epoch [45/200], Validation Loss: 0.84589863, Validation Accuracy: 0.7059
# Epoch [46/200], Training Loss: 0.55151365, Training Accuracy: 1.0000
# Epoch [46/200], Validation Loss: 0.84577528, Validation Accuracy: 0.7059
# Epoch [47/200], Training Loss: 0.55151193, Training Accuracy: 1.0000
# Epoch [47/200], Validation Loss: 0.84513208, Validation Accuracy: 0.7059
# Epoch [48/200], Training Loss: 0.55151018, Training Accuracy: 1.0000
# Epoch [48/200], Validation Loss: 0.84367338, Validation Accuracy: 0.7059
# Epoch [49/200], Training Loss: 0.55150860, Training Accuracy: 1.0000
# Epoch [49/200], Validation Loss: 0.84266356, Validation Accuracy: 0.7059
# Epoch [50/200], Training Loss: 0.55150697, Training Accuracy: 1.0000
# Epoch [50/200], Validation Loss: 0.84201413, Validation Accuracy: 0.7206
# Epoch [51/200], Training Loss: 0.55150549, Training Accuracy: 1.0000
# Epoch [51/200], Validation Loss: 0.84156305, Validation Accuracy: 0.7206
# Epoch [52/200], Training Loss: 0.55150399, Training Accuracy: 1.0000
# Epoch [52/200], Validation Loss: 0.84128591, Validation Accuracy: 0.7059
# Epoch [53/200], Training Loss: 0.55150267, Training Accuracy: 1.0000
# Epoch [53/200], Validation Loss: 0.84045368, Validation Accuracy: 0.7353
# Epoch [54/200], Training Loss: 0.55150127, Training Accuracy: 1.0000
# Epoch [54/200], Validation Loss: 0.83997431, Validation Accuracy: 0.7206
# Epoch [55/200], Training Loss: 0.55150001, Training Accuracy: 1.0000
# Epoch [55/200], Validation Loss: 0.83987042, Validation Accuracy: 0.7059
# Epoch [56/200], Training Loss: 0.55149873, Training Accuracy: 1.0000
# Epoch [56/200], Validation Loss: 0.83913040, Validation Accuracy: 0.7206
# Epoch [57/200], Training Loss: 0.55149754, Training Accuracy: 1.0000
# Epoch [57/200], Validation Loss: 0.83775279, Validation Accuracy: 0.7206
# Epoch [58/200], Training Loss: 0.55149635, Training Accuracy: 1.0000
# Epoch [58/200], Validation Loss: 0.83686641, Validation Accuracy: 0.7206
# Epoch [59/200], Training Loss: 0.55149525, Training Accuracy: 1.0000
# Epoch [59/200], Validation Loss: 0.83689925, Validation Accuracy: 0.7500
# Epoch [60/200], Training Loss: 0.55149411, Training Accuracy: 1.0000
# Epoch [60/200], Validation Loss: 0.83610016, Validation Accuracy: 0.7500
# Epoch [61/200], Training Loss: 0.55149308, Training Accuracy: 1.0000
# Epoch [61/200], Validation Loss: 0.83598459, Validation Accuracy: 0.7500
# Epoch [62/200], Training Loss: 0.55149206, Training Accuracy: 1.0000
# Epoch [62/200], Validation Loss: 0.83465630, Validation Accuracy: 0.7500
# Epoch [63/200], Training Loss: 0.55149110, Training Accuracy: 1.0000
# Epoch [63/200], Validation Loss: 0.83385476, Validation Accuracy: 0.7500
# Epoch [64/200], Training Loss: 0.55149010, Training Accuracy: 1.0000
# Epoch [64/200], Validation Loss: 0.83357230, Validation Accuracy: 0.7353
# Epoch [65/200], Training Loss: 0.55148918, Training Accuracy: 1.0000
# Epoch [65/200], Validation Loss: 0.83303526, Validation Accuracy: 0.7353
# Epoch [66/200], Training Loss: 0.55148830, Training Accuracy: 1.0000
# Epoch [66/200], Validation Loss: 0.83301654, Validation Accuracy: 0.7353
# Epoch [67/200], Training Loss: 0.55148743, Training Accuracy: 1.0000
# Epoch [67/200], Validation Loss: 0.83194500, Validation Accuracy: 0.7353
# Epoch [68/200], Training Loss: 0.55148657, Training Accuracy: 1.0000
# Epoch [68/200], Validation Loss: 0.83156067, Validation Accuracy: 0.7353
# Epoch [69/200], Training Loss: 0.55148573, Training Accuracy: 1.0000
# Epoch [69/200], Validation Loss: 0.83148545, Validation Accuracy: 0.7353
# Epoch [70/200], Training Loss: 0.55148502, Training Accuracy: 1.0000
# Epoch [70/200], Validation Loss: 0.83031878, Validation Accuracy: 0.7353
# Epoch [71/200], Training Loss: 0.55148420, Training Accuracy: 1.0000
# Epoch [71/200], Validation Loss: 0.83018208, Validation Accuracy: 0.7353
# Epoch [72/200], Training Loss: 0.55148346, Training Accuracy: 1.0000
# Epoch [72/200], Validation Loss: 0.82901686, Validation Accuracy: 0.7353
# Epoch [73/200], Training Loss: 0.55148273, Training Accuracy: 1.0000
# Epoch [73/200], Validation Loss: 0.82843512, Validation Accuracy: 0.7353
# Epoch [74/200], Training Loss: 0.55148201, Training Accuracy: 1.0000
# Epoch [74/200], Validation Loss: 0.82802108, Validation Accuracy: 0.7353
# Epoch [75/200], Training Loss: 0.55148138, Training Accuracy: 1.0000
# Epoch [75/200], Validation Loss: 0.82771674, Validation Accuracy: 0.7353
# Epoch [76/200], Training Loss: 0.55148063, Training Accuracy: 1.0000
# Epoch [76/200], Validation Loss: 0.82714841, Validation Accuracy: 0.7353
# Epoch [77/200], Training Loss: 0.55148004, Training Accuracy: 1.0000
# Epoch [77/200], Validation Loss: 0.82703307, Validation Accuracy: 0.7353
# Epoch [78/200], Training Loss: 0.55147942, Training Accuracy: 1.0000
# Epoch [78/200], Validation Loss: 0.82655093, Validation Accuracy: 0.7353
# Epoch [79/200], Training Loss: 0.55147884, Training Accuracy: 1.0000
# Epoch [79/200], Validation Loss: 0.82569984, Validation Accuracy: 0.7353
# Epoch [80/200], Training Loss: 0.55147820, Training Accuracy: 1.0000
# Epoch [80/200], Validation Loss: 0.82486549, Validation Accuracy: 0.7353
# Epoch [81/200], Training Loss: 0.55147765, Training Accuracy: 1.0000
# Epoch [81/200], Validation Loss: 0.82407215, Validation Accuracy: 0.7353
# Epoch [82/200], Training Loss: 0.55147706, Training Accuracy: 1.0000
# Epoch [82/200], Validation Loss: 0.82390389, Validation Accuracy: 0.7353
# Epoch [83/200], Training Loss: 0.55147649, Training Accuracy: 1.0000
# Epoch [83/200], Validation Loss: 0.82382721, Validation Accuracy: 0.7353
# Epoch [84/200], Training Loss: 0.55147597, Training Accuracy: 1.0000
# Epoch [84/200], Validation Loss: 0.82346696, Validation Accuracy: 0.7353
# Epoch [85/200], Training Loss: 0.55147547, Training Accuracy: 1.0000
# Epoch [85/200], Validation Loss: 0.82267442, Validation Accuracy: 0.7353
# Epoch [86/200], Training Loss: 0.55147495, Training Accuracy: 1.0000
# Epoch [86/200], Validation Loss: 0.82263285, Validation Accuracy: 0.7353
# Epoch [87/200], Training Loss: 0.55147445, Training Accuracy: 1.0000
# Epoch [87/200], Validation Loss: 0.82206851, Validation Accuracy: 0.7353
# Epoch [88/200], Training Loss: 0.55147394, Training Accuracy: 1.0000
# Epoch [88/200], Validation Loss: 0.82152167, Validation Accuracy: 0.7353
# Epoch [89/200], Training Loss: 0.55147352, Training Accuracy: 1.0000
# Epoch [89/200], Validation Loss: 0.82076237, Validation Accuracy: 0.7353
# Epoch [90/200], Training Loss: 0.55147306, Training Accuracy: 1.0000
# Epoch [90/200], Validation Loss: 0.82053974, Validation Accuracy: 0.7353
# Epoch [91/200], Training Loss: 0.55147260, Training Accuracy: 1.0000
# Epoch [91/200], Validation Loss: 0.82003215, Validation Accuracy: 0.7353
# Epoch [92/200], Training Loss: 0.55147218, Training Accuracy: 1.0000
# Epoch [92/200], Validation Loss: 0.81974953, Validation Accuracy: 0.7353
# Epoch [93/200], Training Loss: 0.55147173, Training Accuracy: 1.0000
# Epoch [93/200], Validation Loss: 0.81951946, Validation Accuracy: 0.7353
# Epoch [94/200], Training Loss: 0.55147128, Training Accuracy: 1.0000
# Epoch [94/200], Validation Loss: 0.81878585, Validation Accuracy: 0.7353
# Epoch [95/200], Training Loss: 0.55147090, Training Accuracy: 1.0000
# Epoch [95/200], Validation Loss: 0.81837565, Validation Accuracy: 0.7353
# Epoch [96/200], Training Loss: 0.55147051, Training Accuracy: 1.0000
# Epoch [96/200], Validation Loss: 0.81818321, Validation Accuracy: 0.7353
# Epoch [97/200], Training Loss: 0.55147008, Training Accuracy: 1.0000
# Epoch [97/200], Validation Loss: 0.81769183, Validation Accuracy: 0.7353
# Epoch [98/200], Training Loss: 0.55146973, Training Accuracy: 1.0000
# Epoch [98/200], Validation Loss: 0.81712627, Validation Accuracy: 0.7353
# Epoch [99/200], Training Loss: 0.55146935, Training Accuracy: 1.0000
# Epoch [99/200], Validation Loss: 0.81698692, Validation Accuracy: 0.7353
# Epoch [100/200], Training Loss: 0.55146901, Training Accuracy: 1.0000
# Epoch [100/200], Validation Loss: 0.81656080, Validation Accuracy: 0.7353
# Epoch [101/200], Training Loss: 0.55146867, Training Accuracy: 1.0000
# Epoch [101/200], Validation Loss: 0.81621692, Validation Accuracy: 0.7353
# Epoch [102/200], Training Loss: 0.55146830, Training Accuracy: 1.0000
# Epoch [102/200], Validation Loss: 0.81583437, Validation Accuracy: 0.7353
# Epoch [103/200], Training Loss: 0.55146792, Training Accuracy: 1.0000
# Epoch [103/200], Validation Loss: 0.81553274, Validation Accuracy: 0.7353
# Epoch [104/200], Training Loss: 0.55146758, Training Accuracy: 1.0000
# Epoch [104/200], Validation Loss: 0.81511310, Validation Accuracy: 0.7353
# Epoch [105/200], Training Loss: 0.55146730, Training Accuracy: 1.0000
# Epoch [105/200], Validation Loss: 0.81446472, Validation Accuracy: 0.7353
# Epoch [106/200], Training Loss: 0.55146698, Training Accuracy: 1.0000
# Epoch [106/200], Validation Loss: 0.81354955, Validation Accuracy: 0.7353
# Epoch [107/200], Training Loss: 0.55146668, Training Accuracy: 1.0000
# Epoch [107/200], Validation Loss: 0.81368321, Validation Accuracy: 0.7353
# Epoch [108/200], Training Loss: 0.55146634, Training Accuracy: 1.0000
# Epoch [108/200], Validation Loss: 0.81353557, Validation Accuracy: 0.7353
# Epoch [109/200], Training Loss: 0.55146604, Training Accuracy: 1.0000
# Epoch [109/200], Validation Loss: 0.81308174, Validation Accuracy: 0.7353
# Epoch [110/200], Training Loss: 0.55146576, Training Accuracy: 1.0000
# Epoch [110/200], Validation Loss: 0.81275520, Validation Accuracy: 0.7353
# Epoch [111/200], Training Loss: 0.55146549, Training Accuracy: 1.0000
# Epoch [111/200], Validation Loss: 0.81236759, Validation Accuracy: 0.7353
# Epoch [112/200], Training Loss: 0.55146522, Training Accuracy: 1.0000
# Epoch [112/200], Validation Loss: 0.81196359, Validation Accuracy: 0.7353
# Epoch [113/200], Training Loss: 0.55146494, Training Accuracy: 1.0000
# Epoch [113/200], Validation Loss: 0.81168979, Validation Accuracy: 0.7353
# Epoch [114/200], Training Loss: 0.55146465, Training Accuracy: 1.0000
# Epoch [114/200], Validation Loss: 0.81119677, Validation Accuracy: 0.7353
# Epoch [115/200], Training Loss: 0.55146437, Training Accuracy: 1.0000
# Epoch [115/200], Validation Loss: 0.81086275, Validation Accuracy: 0.7353
# Epoch [116/200], Training Loss: 0.55146417, Training Accuracy: 1.0000
# Epoch [116/200], Validation Loss: 0.81078398, Validation Accuracy: 0.7353
# Epoch [117/200], Training Loss: 0.55146389, Training Accuracy: 1.0000
# Epoch [117/200], Validation Loss: 0.81053609, Validation Accuracy: 0.7353
# Epoch [118/200], Training Loss: 0.55146365, Training Accuracy: 1.0000
# Epoch [118/200], Validation Loss: 0.81024089, Validation Accuracy: 0.7353
# Epoch [119/200], Training Loss: 0.55146337, Training Accuracy: 1.0000
# Epoch [119/200], Validation Loss: 0.81054899, Validation Accuracy: 0.7353
# Epoch [120/200], Training Loss: 0.55146315, Training Accuracy: 1.0000
# Epoch [120/200], Validation Loss: 0.81000701, Validation Accuracy: 0.7500
# Epoch [121/200], Training Loss: 0.55146291, Training Accuracy: 1.0000
# Epoch [121/200], Validation Loss: 0.80949223, Validation Accuracy: 0.7500
# Epoch [122/200], Training Loss: 0.55146269, Training Accuracy: 1.0000
# Epoch [122/200], Validation Loss: 0.80907002, Validation Accuracy: 0.7500
# Epoch [123/200], Training Loss: 0.55146246, Training Accuracy: 1.0000
# Epoch [123/200], Validation Loss: 0.80868909, Validation Accuracy: 0.7500
# Epoch [124/200], Training Loss: 0.55146229, Training Accuracy: 1.0000
# Epoch [124/200], Validation Loss: 0.80824095, Validation Accuracy: 0.7500
# Epoch [125/200], Training Loss: 0.55146205, Training Accuracy: 1.0000
# Epoch [125/200], Validation Loss: 0.80769604, Validation Accuracy: 0.7500
# Epoch [126/200], Training Loss: 0.55146182, Training Accuracy: 1.0000
# Epoch [126/200], Validation Loss: 0.80742833, Validation Accuracy: 0.7500
# Epoch [127/200], Training Loss: 0.55146162, Training Accuracy: 1.0000
# Epoch [127/200], Validation Loss: 0.80742136, Validation Accuracy: 0.7500
# Epoch [128/200], Training Loss: 0.55146141, Training Accuracy: 1.0000
# Epoch [128/200], Validation Loss: 0.80699572, Validation Accuracy: 0.7500
# Epoch [129/200], Training Loss: 0.55146120, Training Accuracy: 1.0000
# Epoch [129/200], Validation Loss: 0.80713260, Validation Accuracy: 0.7500
# Epoch [130/200], Training Loss: 0.55146102, Training Accuracy: 1.0000
# Epoch [130/200], Validation Loss: 0.80714959, Validation Accuracy: 0.7500
# Epoch [131/200], Training Loss: 0.55146082, Training Accuracy: 1.0000
# Epoch [131/200], Validation Loss: 0.80669332, Validation Accuracy: 0.7500
# Epoch [132/200], Training Loss: 0.55146059, Training Accuracy: 1.0000
# Epoch [132/200], Validation Loss: 0.80605444, Validation Accuracy: 0.7500
# Epoch [133/200], Training Loss: 0.55146044, Training Accuracy: 1.0000
# Epoch [133/200], Validation Loss: 0.80558008, Validation Accuracy: 0.7500
# Epoch [134/200], Training Loss: 0.55146028, Training Accuracy: 1.0000
# Epoch [134/200], Validation Loss: 0.80481872, Validation Accuracy: 0.7500
# Epoch [135/200], Training Loss: 0.55146006, Training Accuracy: 1.0000
# Epoch [135/200], Validation Loss: 0.80533409, Validation Accuracy: 0.7500
# Epoch [136/200], Training Loss: 0.55145993, Training Accuracy: 1.0000
# Epoch [136/200], Validation Loss: 0.80529314, Validation Accuracy: 0.7500
# Epoch [137/200], Training Loss: 0.55145971, Training Accuracy: 1.0000
# Epoch [137/200], Validation Loss: 0.80521476, Validation Accuracy: 0.7500
# Epoch [138/200], Training Loss: 0.55145955, Training Accuracy: 1.0000
# Epoch [138/200], Validation Loss: 0.80506527, Validation Accuracy: 0.7500
# Epoch [139/200], Training Loss: 0.55145936, Training Accuracy: 1.0000
# Epoch [139/200], Validation Loss: 0.80433723, Validation Accuracy: 0.7500
# Epoch [140/200], Training Loss: 0.55145918, Training Accuracy: 1.0000
# Epoch [140/200], Validation Loss: 0.80416900, Validation Accuracy: 0.7500
# Epoch [141/200], Training Loss: 0.55145905, Training Accuracy: 1.0000
# Epoch [141/200], Validation Loss: 0.80403331, Validation Accuracy: 0.7500
# Epoch [142/200], Training Loss: 0.55145891, Training Accuracy: 1.0000
# Epoch [142/200], Validation Loss: 0.80361867, Validation Accuracy: 0.7500
# Epoch [143/200], Training Loss: 0.55145873, Training Accuracy: 1.0000
# Epoch [143/200], Validation Loss: 0.80356216, Validation Accuracy: 0.7500
# Epoch [144/200], Training Loss: 0.55145859, Training Accuracy: 1.0000
# Epoch [144/200], Validation Loss: 0.80319041, Validation Accuracy: 0.7500
# Epoch [145/200], Training Loss: 0.55145840, Training Accuracy: 1.0000
# Epoch [145/200], Validation Loss: 0.80275694, Validation Accuracy: 0.7500
# Epoch [146/200], Training Loss: 0.55145830, Training Accuracy: 1.0000
# Epoch [146/200], Validation Loss: 0.80273050, Validation Accuracy: 0.7500
# Epoch [147/200], Training Loss: 0.55145812, Training Accuracy: 1.0000
# Epoch [147/200], Validation Loss: 0.80253020, Validation Accuracy: 0.7500
# Epoch [148/200], Training Loss: 0.55145799, Training Accuracy: 1.0000
# Epoch [148/200], Validation Loss: 0.80247536, Validation Accuracy: 0.7500
# Epoch [149/200], Training Loss: 0.55145784, Training Accuracy: 1.0000
# Epoch [149/200], Validation Loss: 0.80200025, Validation Accuracy: 0.7500
# Epoch [150/200], Training Loss: 0.55145767, Training Accuracy: 1.0000
# Epoch [150/200], Validation Loss: 0.80188251, Validation Accuracy: 0.7500
# Epoch [151/200], Training Loss: 0.55145753, Training Accuracy: 1.0000
# Epoch [151/200], Validation Loss: 0.80176824, Validation Accuracy: 0.7500
# Epoch [152/200], Training Loss: 0.55145743, Training Accuracy: 1.0000
# Epoch [152/200], Validation Loss: 0.80152470, Validation Accuracy: 0.7500
# Epoch [153/200], Training Loss: 0.55145729, Training Accuracy: 1.0000
# Epoch [153/200], Validation Loss: 0.80118719, Validation Accuracy: 0.7500
# Epoch [154/200], Training Loss: 0.55145712, Training Accuracy: 1.0000
# Epoch [154/200], Validation Loss: 0.80103526, Validation Accuracy: 0.7500
# Epoch [155/200], Training Loss: 0.55145700, Training Accuracy: 1.0000
# Epoch [155/200], Validation Loss: 0.80086961, Validation Accuracy: 0.7500
# Epoch [156/200], Training Loss: 0.55145690, Training Accuracy: 1.0000
# Epoch [156/200], Validation Loss: 0.80077654, Validation Accuracy: 0.7500
# Epoch [157/200], Training Loss: 0.55145676, Training Accuracy: 1.0000
# Epoch [157/200], Validation Loss: 0.80053747, Validation Accuracy: 0.7500
# Epoch [158/200], Training Loss: 0.55145664, Training Accuracy: 1.0000
# Epoch [158/200], Validation Loss: 0.79997846, Validation Accuracy: 0.7500
# Epoch [159/200], Training Loss: 0.55145655, Training Accuracy: 1.0000
# Epoch [159/200], Validation Loss: 0.79991519, Validation Accuracy: 0.7500
# Epoch [160/200], Training Loss: 0.55145638, Training Accuracy: 1.0000
# Epoch [160/200], Validation Loss: 0.79950541, Validation Accuracy: 0.7500
# Epoch [161/200], Training Loss: 0.55145632, Training Accuracy: 1.0000
# Epoch [161/200], Validation Loss: 0.79966781, Validation Accuracy: 0.7500
# Epoch [162/200], Training Loss: 0.55145617, Training Accuracy: 1.0000
# Epoch [162/200], Validation Loss: 0.79948771, Validation Accuracy: 0.7500
# Epoch [163/200], Training Loss: 0.55145608, Training Accuracy: 1.0000
# Epoch [163/200], Validation Loss: 0.79941416, Validation Accuracy: 0.7500
# Epoch [164/200], Training Loss: 0.55145596, Training Accuracy: 1.0000
# Epoch [164/200], Validation Loss: 0.79933986, Validation Accuracy: 0.7500
# Epoch [165/200], Training Loss: 0.55145586, Training Accuracy: 1.0000
# Epoch [165/200], Validation Loss: 0.79905376, Validation Accuracy: 0.7500
# Epoch [166/200], Training Loss: 0.55145576, Training Accuracy: 1.0000
# Epoch [166/200], Validation Loss: 0.79864115, Validation Accuracy: 0.7500
# Epoch [167/200], Training Loss: 0.55145564, Training Accuracy: 1.0000
# Epoch [167/200], Validation Loss: 0.79825738, Validation Accuracy: 0.7500
# Epoch [168/200], Training Loss: 0.55145551, Training Accuracy: 1.0000
# Epoch [168/200], Validation Loss: 0.79809546, Validation Accuracy: 0.7500
# Epoch [169/200], Training Loss: 0.55145540, Training Accuracy: 1.0000
# Epoch [169/200], Validation Loss: 0.79800212, Validation Accuracy: 0.7500
# Epoch [170/200], Training Loss: 0.55145530, Training Accuracy: 1.0000
# Epoch [170/200], Validation Loss: 0.79798684, Validation Accuracy: 0.7500
# Epoch [171/200], Training Loss: 0.55145521, Training Accuracy: 1.0000
# Epoch [171/200], Validation Loss: 0.79800797, Validation Accuracy: 0.7500
# Epoch [172/200], Training Loss: 0.55145512, Training Accuracy: 1.0000
# Epoch [172/200], Validation Loss: 0.79769936, Validation Accuracy: 0.7500
# Epoch [173/200], Training Loss: 0.55145502, Training Accuracy: 1.0000
# Epoch [173/200], Validation Loss: 0.79766873, Validation Accuracy: 0.7500
# Epoch [174/200], Training Loss: 0.55145492, Training Accuracy: 1.0000
# Epoch [174/200], Validation Loss: 0.79721579, Validation Accuracy: 0.7500
# Epoch [175/200], Training Loss: 0.55145483, Training Accuracy: 1.0000
# Epoch [175/200], Validation Loss: 0.79683518, Validation Accuracy: 0.7500
# Epoch [176/200], Training Loss: 0.55145471, Training Accuracy: 1.0000
# Epoch [176/200], Validation Loss: 0.79670203, Validation Accuracy: 0.7500
# Epoch [177/200], Training Loss: 0.55145460, Training Accuracy: 1.0000
# Epoch [177/200], Validation Loss: 0.79644018, Validation Accuracy: 0.7500
# Epoch [178/200], Training Loss: 0.55145453, Training Accuracy: 1.0000
# Epoch [178/200], Validation Loss: 0.79649284, Validation Accuracy: 0.7500
# Epoch [179/200], Training Loss: 0.55145443, Training Accuracy: 1.0000
# Epoch [179/200], Validation Loss: 0.79649943, Validation Accuracy: 0.7500
# Epoch [180/200], Training Loss: 0.55145435, Training Accuracy: 1.0000
# Epoch [180/200], Validation Loss: 0.79641429, Validation Accuracy: 0.7500
# Epoch [181/200], Training Loss: 0.55145427, Training Accuracy: 1.0000
# Epoch [181/200], Validation Loss: 0.79642284, Validation Accuracy: 0.7500
# Epoch [182/200], Training Loss: 0.55145418, Training Accuracy: 1.0000
# Epoch [182/200], Validation Loss: 0.79603356, Validation Accuracy: 0.7500
# Epoch [183/200], Training Loss: 0.55145411, Training Accuracy: 1.0000
# Epoch [183/200], Validation Loss: 0.79562563, Validation Accuracy: 0.7500
# Epoch [184/200], Training Loss: 0.55145398, Training Accuracy: 1.0000
# Epoch [184/200], Validation Loss: 0.79544681, Validation Accuracy: 0.7500
# Epoch [185/200], Training Loss: 0.55145391, Training Accuracy: 1.0000
# Epoch [185/200], Validation Loss: 0.79540753, Validation Accuracy: 0.7500
# Epoch [186/200], Training Loss: 0.55145382, Training Accuracy: 1.0000
# Epoch [186/200], Validation Loss: 0.79519045, Validation Accuracy: 0.7500
# Epoch [187/200], Training Loss: 0.55145371, Training Accuracy: 1.0000
# Epoch [187/200], Validation Loss: 0.79504552, Validation Accuracy: 0.7500
# Epoch [188/200], Training Loss: 0.55145369, Training Accuracy: 1.0000
# Epoch [188/200], Validation Loss: 0.79516181, Validation Accuracy: 0.7500
# Epoch [189/200], Training Loss: 0.55145359, Training Accuracy: 1.0000
# Epoch [189/200], Validation Loss: 0.79520535, Validation Accuracy: 0.7500
# Epoch [190/200], Training Loss: 0.55145351, Training Accuracy: 1.0000
# Epoch [190/200], Validation Loss: 0.79507911, Validation Accuracy: 0.7500
# Epoch [191/200], Training Loss: 0.55145340, Training Accuracy: 1.0000
# Epoch [191/200], Validation Loss: 0.79497913, Validation Accuracy: 0.7500
# Epoch [192/200], Training Loss: 0.55145333, Training Accuracy: 1.0000
# Epoch [192/200], Validation Loss: 0.79465175, Validation Accuracy: 0.7500
# Epoch [193/200], Training Loss: 0.55145332, Training Accuracy: 1.0000
# Epoch [193/200], Validation Loss: 0.79445884, Validation Accuracy: 0.7500
# Epoch [194/200], Training Loss: 0.55145317, Training Accuracy: 1.0000
# Epoch [194/200], Validation Loss: 0.79402319, Validation Accuracy: 0.7500
# Epoch [195/200], Training Loss: 0.55145311, Training Accuracy: 1.0000
# Epoch [195/200], Validation Loss: 0.79373893, Validation Accuracy: 0.7500
# Epoch [196/200], Training Loss: 0.55145304, Training Accuracy: 1.0000
# Epoch [196/200], Validation Loss: 0.79400611, Validation Accuracy: 0.7500
# Epoch [197/200], Training Loss: 0.55145299, Training Accuracy: 1.0000
# Epoch [197/200], Validation Loss: 0.79394099, Validation Accuracy: 0.7500
# Epoch [198/200], Training Loss: 0.55145291, Training Accuracy: 1.0000
# Epoch [198/200], Validation Loss: 0.79362205, Validation Accuracy: 0.7500
# Epoch [199/200], Training Loss: 0.55145283, Training Accuracy: 1.0000
# Epoch [199/200], Validation Loss: 0.79338503, Validation Accuracy: 0.7500
# Epoch [200/200], Training Loss: 0.55145279, Training Accuracy: 1.0000
# Epoch [200/200], Validation Loss: 0.79340643, Validation Accuracy: 0.7500

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 0.5882

# %% [markdown]
# ##### Analysis RNN
# Validation accuracy peaks to 0.75 very early at 120 epochs. Test accuracy is 0.5882.

# %% [markdown]
# ##### Define LSTM

# %%
# chatgpt 3.5 generated code
# LSTM Model with Softmax
class LSTMWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(LSTMWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])  # Use only the last time step's output for classification
        return nn.functional.softmax(out, dim=1)  # Apply softmax activation

# %% [markdown]
# ##### Train LSTM: setup

# %%
# chatgpt 3.5 generated code
model = LSTMWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the LSTM and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code (this code is a copy of the RNN code)
# Training loop
# LSTM_total_epochs = number_of_epochs
LSTM_total_epochs = LSTM_number_of_epochs

# Lists to store training/validation losses and training/validation accuracies
LSTM_train_losses = []  
LSTM_val_losses = []    
LSTM_train_accuracies = []  
LSTM_val_accuracies = []    

for epoch in range(LSTM_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    LSTM_train_losses.append(average_train_loss)
    LSTM_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{LSTM_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Store validation loss and accuracy values
    LSTM_val_losses.append(average_val_loss)
    LSTM_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{LSTM_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')

# Plot the losses and accuracies at the end of all epochs
LSTM_x_epochs = list(range(1, LSTM_total_epochs + 1))

plt.figure(figsize=(12, 4))

# Plot Losses
plt.subplot(1, 2, 1)
plt.plot(LSTM_x_epochs, LSTM_train_losses, label='LSTM Training Loss')
plt.plot(LSTM_x_epochs, LSTM_val_losses, label='LSTM Validation Loss')
plt.xlabel('LSTM Epochs')
plt.ylabel('LSTM Loss')
plt.title('LSTM Training and Validation Loss')
plt.legend()

# Plot Accuracies
plt.subplot(1, 2, 2)
plt.plot(LSTM_x_epochs, LSTM_train_accuracies, label='LSTM Training Accuracy')
plt.plot(LSTM_x_epochs, LSTM_val_accuracies, label='LSTM Validation Accuracy')
plt.xlabel('LSTM Epochs')
plt.ylabel('LSTM Accuracy')
plt.title('LSTM Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/100], Training Loss: 1.06002525, Training Accuracy: 0.4580
# Epoch [1/100], Validation Loss: 1.02713382, Validation Accuracy: 0.3676
# Epoch [2/100], Training Loss: 0.95183751, Training Accuracy: 0.6008
# Epoch [2/100], Validation Loss: 0.99940088, Validation Accuracy: 0.4559
# Epoch [3/100], Training Loss: 0.83808310, Training Accuracy: 0.7269
# Epoch [3/100], Validation Loss: 0.87159669, Validation Accuracy: 0.6765
# Epoch [4/100], Training Loss: 0.79856108, Training Accuracy: 0.7143
# Epoch [4/100], Validation Loss: 1.04886419, Validation Accuracy: 0.3971
# Epoch [5/100], Training Loss: 0.79711334, Training Accuracy: 0.8739
# Epoch [5/100], Validation Loss: 0.91281730, Validation Accuracy: 0.7500
# Epoch [6/100], Training Loss: 0.74848337, Training Accuracy: 0.9286
# Epoch [6/100], Validation Loss: 0.90153438, Validation Accuracy: 0.6176
# Epoch [7/100], Training Loss: 0.67222907, Training Accuracy: 0.9412
# Epoch [7/100], Validation Loss: 0.82162893, Validation Accuracy: 0.7500
# Epoch [8/100], Training Loss: 0.62073026, Training Accuracy: 0.9580
# Epoch [8/100], Validation Loss: 0.89384440, Validation Accuracy: 0.6471
# Epoch [9/100], Training Loss: 0.59272064, Training Accuracy: 0.9748
# Epoch [9/100], Validation Loss: 0.77013934, Validation Accuracy: 0.7941
# Epoch [10/100], Training Loss: 0.56763462, Training Accuracy: 1.0000
# Epoch [10/100], Validation Loss: 0.89014471, Validation Accuracy: 0.6618
# Epoch [11/100], Training Loss: 0.56032848, Training Accuracy: 1.0000
# Epoch [11/100], Validation Loss: 0.88199967, Validation Accuracy: 0.6765
# Epoch [12/100], Training Loss: 0.55497825, Training Accuracy: 1.0000
# Epoch [12/100], Validation Loss: 0.79828936, Validation Accuracy: 0.7353
# Epoch [13/100], Training Loss: 0.55308987, Training Accuracy: 1.0000
# Epoch [13/100], Validation Loss: 0.76164716, Validation Accuracy: 0.7941
# Epoch [14/100], Training Loss: 0.55262698, Training Accuracy: 1.0000
# Epoch [14/100], Validation Loss: 0.75047374, Validation Accuracy: 0.7941
# Epoch [15/100], Training Loss: 0.55228243, Training Accuracy: 1.0000
# Epoch [15/100], Validation Loss: 0.75408107, Validation Accuracy: 0.7794
# Epoch [16/100], Training Loss: 0.55206278, Training Accuracy: 1.0000
# Epoch [16/100], Validation Loss: 0.76385364, Validation Accuracy: 0.7794
# Epoch [17/100], Training Loss: 0.55196588, Training Accuracy: 1.0000
# Epoch [17/100], Validation Loss: 0.76767957, Validation Accuracy: 0.7794
# Epoch [18/100], Training Loss: 0.55189749, Training Accuracy: 1.0000
# Epoch [18/100], Validation Loss: 0.76721323, Validation Accuracy: 0.7647
# Epoch [19/100], Training Loss: 0.55184225, Training Accuracy: 1.0000
# Epoch [19/100], Validation Loss: 0.76668721, Validation Accuracy: 0.7794
# Epoch [20/100], Training Loss: 0.55180120, Training Accuracy: 1.0000
# Epoch [20/100], Validation Loss: 0.76266322, Validation Accuracy: 0.7794
# Epoch [21/100], Training Loss: 0.55176931, Training Accuracy: 1.0000
# Epoch [21/100], Validation Loss: 0.75786933, Validation Accuracy: 0.7941
# Epoch [22/100], Training Loss: 0.55174029, Training Accuracy: 1.0000
# Epoch [22/100], Validation Loss: 0.75607541, Validation Accuracy: 0.7941
# Epoch [23/100], Training Loss: 0.55171918, Training Accuracy: 1.0000
# Epoch [23/100], Validation Loss: 0.75645706, Validation Accuracy: 0.7941
# Epoch [24/100], Training Loss: 0.55169722, Training Accuracy: 1.0000
# Epoch [24/100], Validation Loss: 0.75693274, Validation Accuracy: 0.7941
# Epoch [25/100], Training Loss: 0.55167961, Training Accuracy: 1.0000
# Epoch [25/100], Validation Loss: 0.75660542, Validation Accuracy: 0.7941
# Epoch [26/100], Training Loss: 0.55166434, Training Accuracy: 1.0000
# Epoch [26/100], Validation Loss: 0.75655675, Validation Accuracy: 0.7941
# Epoch [27/100], Training Loss: 0.55164895, Training Accuracy: 1.0000
# Epoch [27/100], Validation Loss: 0.75586832, Validation Accuracy: 0.7941
# Epoch [28/100], Training Loss: 0.55163567, Training Accuracy: 1.0000
# Epoch [28/100], Validation Loss: 0.75579068, Validation Accuracy: 0.7941
# Epoch [29/100], Training Loss: 0.55162391, Training Accuracy: 1.0000
# Epoch [29/100], Validation Loss: 0.75723803, Validation Accuracy: 0.7941
# Epoch [30/100], Training Loss: 0.55161396, Training Accuracy: 1.0000
# Epoch [30/100], Validation Loss: 0.75720948, Validation Accuracy: 0.7941
# Epoch [31/100], Training Loss: 0.55160445, Training Accuracy: 1.0000
# Epoch [31/100], Validation Loss: 0.75650516, Validation Accuracy: 0.7941
# Epoch [32/100], Training Loss: 0.55159520, Training Accuracy: 1.0000
# Epoch [32/100], Validation Loss: 0.75507724, Validation Accuracy: 0.7941
# Epoch [33/100], Training Loss: 0.55158711, Training Accuracy: 1.0000
# Epoch [33/100], Validation Loss: 0.75341669, Validation Accuracy: 0.7941
# Epoch [34/100], Training Loss: 0.55157970, Training Accuracy: 1.0000
# Epoch [34/100], Validation Loss: 0.75311133, Validation Accuracy: 0.7941
# Epoch [35/100], Training Loss: 0.55157265, Training Accuracy: 1.0000
# Epoch [35/100], Validation Loss: 0.75033212, Validation Accuracy: 0.7941
# Epoch [36/100], Training Loss: 0.55156635, Training Accuracy: 1.0000
# Epoch [36/100], Validation Loss: 0.74983633, Validation Accuracy: 0.7941
# Epoch [37/100], Training Loss: 0.55156035, Training Accuracy: 1.0000
# Epoch [37/100], Validation Loss: 0.74734226, Validation Accuracy: 0.8088
# Epoch [38/100], Training Loss: 0.55155511, Training Accuracy: 1.0000
# Epoch [38/100], Validation Loss: 0.74436274, Validation Accuracy: 0.8088
# Epoch [39/100], Training Loss: 0.55154991, Training Accuracy: 1.0000
# Epoch [39/100], Validation Loss: 0.74402350, Validation Accuracy: 0.8088
# Epoch [40/100], Training Loss: 0.55154519, Training Accuracy: 1.0000
# Epoch [40/100], Validation Loss: 0.74455890, Validation Accuracy: 0.8088
# Epoch [41/100], Training Loss: 0.55154157, Training Accuracy: 1.0000
# Epoch [41/100], Validation Loss: 0.73818156, Validation Accuracy: 0.8088
# Epoch [42/100], Training Loss: 0.55153681, Training Accuracy: 1.0000
# Epoch [42/100], Validation Loss: 0.74068671, Validation Accuracy: 0.8088
# Epoch [43/100], Training Loss: 0.55153301, Training Accuracy: 1.0000
# Epoch [43/100], Validation Loss: 0.73992610, Validation Accuracy: 0.8088
# Epoch [44/100], Training Loss: 0.55152948, Training Accuracy: 1.0000
# Epoch [44/100], Validation Loss: 0.73941079, Validation Accuracy: 0.8088
# Epoch [45/100], Training Loss: 0.55152640, Training Accuracy: 1.0000
# Epoch [45/100], Validation Loss: 0.73633924, Validation Accuracy: 0.8088
# Epoch [46/100], Training Loss: 0.55152307, Training Accuracy: 1.0000
# Epoch [46/100], Validation Loss: 0.73709175, Validation Accuracy: 0.8088
# Epoch [47/100], Training Loss: 0.55152019, Training Accuracy: 1.0000
# Epoch [47/100], Validation Loss: 0.73685536, Validation Accuracy: 0.8088
# Epoch [48/100], Training Loss: 0.55151750, Training Accuracy: 1.0000
# Epoch [48/100], Validation Loss: 0.73521358, Validation Accuracy: 0.8088
# Epoch [49/100], Training Loss: 0.55151487, Training Accuracy: 1.0000
# Epoch [49/100], Validation Loss: 0.73514640, Validation Accuracy: 0.8088
# Epoch [50/100], Training Loss: 0.55151239, Training Accuracy: 1.0000
# Epoch [50/100], Validation Loss: 0.73476404, Validation Accuracy: 0.8088
# Epoch [51/100], Training Loss: 0.55151017, Training Accuracy: 1.0000
# Epoch [51/100], Validation Loss: 0.73155728, Validation Accuracy: 0.8235
# Epoch [52/100], Training Loss: 0.55150809, Training Accuracy: 1.0000
# Epoch [52/100], Validation Loss: 0.73383525, Validation Accuracy: 0.8088
# Epoch [53/100], Training Loss: 0.55150591, Training Accuracy: 1.0000
# Epoch [53/100], Validation Loss: 0.73486009, Validation Accuracy: 0.8088
# Epoch [54/100], Training Loss: 0.55150418, Training Accuracy: 1.0000
# Epoch [54/100], Validation Loss: 0.73234060, Validation Accuracy: 0.8235
# Epoch [55/100], Training Loss: 0.55150212, Training Accuracy: 1.0000
# Epoch [55/100], Validation Loss: 0.73106363, Validation Accuracy: 0.8235
# Epoch [56/100], Training Loss: 0.55150035, Training Accuracy: 1.0000
# Epoch [56/100], Validation Loss: 0.73075446, Validation Accuracy: 0.8235
# Epoch [57/100], Training Loss: 0.55149879, Training Accuracy: 1.0000
# Epoch [57/100], Validation Loss: 0.73000214, Validation Accuracy: 0.8235
# Epoch [58/100], Training Loss: 0.55149724, Training Accuracy: 1.0000
# Epoch [58/100], Validation Loss: 0.73018742, Validation Accuracy: 0.8235
# Epoch [59/100], Training Loss: 0.55149556, Training Accuracy: 1.0000
# Epoch [59/100], Validation Loss: 0.73060688, Validation Accuracy: 0.8235
# Epoch [60/100], Training Loss: 0.55149412, Training Accuracy: 1.0000
# Epoch [60/100], Validation Loss: 0.73065183, Validation Accuracy: 0.8235
# Epoch [61/100], Training Loss: 0.55149280, Training Accuracy: 1.0000
# Epoch [61/100], Validation Loss: 0.73020509, Validation Accuracy: 0.8235
# Epoch [62/100], Training Loss: 0.55149148, Training Accuracy: 1.0000
# Epoch [62/100], Validation Loss: 0.72975072, Validation Accuracy: 0.8235
# Epoch [63/100], Training Loss: 0.55149013, Training Accuracy: 1.0000
# Epoch [63/100], Validation Loss: 0.72943842, Validation Accuracy: 0.8235
# Epoch [64/100], Training Loss: 0.55148895, Training Accuracy: 1.0000
# Epoch [64/100], Validation Loss: 0.72936010, Validation Accuracy: 0.8235
# Epoch [65/100], Training Loss: 0.55148779, Training Accuracy: 1.0000
# Epoch [65/100], Validation Loss: 0.72982123, Validation Accuracy: 0.8235
# Epoch [66/100], Training Loss: 0.55148671, Training Accuracy: 1.0000
# Epoch [66/100], Validation Loss: 0.72956851, Validation Accuracy: 0.8235
# Epoch [67/100], Training Loss: 0.55148560, Training Accuracy: 1.0000
# Epoch [67/100], Validation Loss: 0.72961506, Validation Accuracy: 0.8235
# Epoch [68/100], Training Loss: 0.55148453, Training Accuracy: 1.0000
# Epoch [68/100], Validation Loss: 0.72939137, Validation Accuracy: 0.8235
# Epoch [69/100], Training Loss: 0.55148361, Training Accuracy: 1.0000
# Epoch [69/100], Validation Loss: 0.72936714, Validation Accuracy: 0.8235
# Epoch [70/100], Training Loss: 0.55148261, Training Accuracy: 1.0000
# Epoch [70/100], Validation Loss: 0.72900939, Validation Accuracy: 0.8235
# Epoch [71/100], Training Loss: 0.55148165, Training Accuracy: 1.0000
# Epoch [71/100], Validation Loss: 0.72903758, Validation Accuracy: 0.8235
# Epoch [72/100], Training Loss: 0.55148086, Training Accuracy: 1.0000
# Epoch [72/100], Validation Loss: 0.72924739, Validation Accuracy: 0.8235
# Epoch [73/100], Training Loss: 0.55147995, Training Accuracy: 1.0000
# Epoch [73/100], Validation Loss: 0.72932932, Validation Accuracy: 0.8235
# Epoch [74/100], Training Loss: 0.55147913, Training Accuracy: 1.0000
# Epoch [74/100], Validation Loss: 0.72930640, Validation Accuracy: 0.8235
# Epoch [75/100], Training Loss: 0.55147845, Training Accuracy: 1.0000
# Epoch [75/100], Validation Loss: 0.72868583, Validation Accuracy: 0.8235
# Epoch [76/100], Training Loss: 0.55147768, Training Accuracy: 1.0000
# Epoch [76/100], Validation Loss: 0.72846207, Validation Accuracy: 0.8235
# Epoch [77/100], Training Loss: 0.55147687, Training Accuracy: 1.0000
# Epoch [77/100], Validation Loss: 0.72864875, Validation Accuracy: 0.8235
# Epoch [78/100], Training Loss: 0.55147622, Training Accuracy: 1.0000
# Epoch [78/100], Validation Loss: 0.72912544, Validation Accuracy: 0.8235
# Epoch [79/100], Training Loss: 0.55147555, Training Accuracy: 1.0000
# Epoch [79/100], Validation Loss: 0.72840515, Validation Accuracy: 0.8235
# Epoch [80/100], Training Loss: 0.55147482, Training Accuracy: 1.0000
# Epoch [80/100], Validation Loss: 0.72847605, Validation Accuracy: 0.8235
# Epoch [81/100], Training Loss: 0.55147421, Training Accuracy: 1.0000
# Epoch [81/100], Validation Loss: 0.72818255, Validation Accuracy: 0.8235
# Epoch [82/100], Training Loss: 0.55147363, Training Accuracy: 1.0000
# Epoch [82/100], Validation Loss: 0.72821552, Validation Accuracy: 0.8235
# Epoch [83/100], Training Loss: 0.55147300, Training Accuracy: 1.0000
# Epoch [83/100], Validation Loss: 0.72855064, Validation Accuracy: 0.8235
# Epoch [84/100], Training Loss: 0.55147260, Training Accuracy: 1.0000
# Epoch [84/100], Validation Loss: 0.72816667, Validation Accuracy: 0.8235
# Epoch [85/100], Training Loss: 0.55147196, Training Accuracy: 1.0000
# Epoch [85/100], Validation Loss: 0.72734162, Validation Accuracy: 0.8235
# Epoch [86/100], Training Loss: 0.55147143, Training Accuracy: 1.0000
# Epoch [86/100], Validation Loss: 0.72711328, Validation Accuracy: 0.8235
# Epoch [87/100], Training Loss: 0.55147091, Training Accuracy: 1.0000
# Epoch [87/100], Validation Loss: 0.72757226, Validation Accuracy: 0.8235
# Epoch [88/100], Training Loss: 0.55147032, Training Accuracy: 1.0000
# Epoch [88/100], Validation Loss: 0.72788593, Validation Accuracy: 0.8235
# Epoch [89/100], Training Loss: 0.55146985, Training Accuracy: 1.0000
# Epoch [89/100], Validation Loss: 0.72796968, Validation Accuracy: 0.8235
# Epoch [90/100], Training Loss: 0.55146937, Training Accuracy: 1.0000
# Epoch [90/100], Validation Loss: 0.72748140, Validation Accuracy: 0.8235
# Epoch [91/100], Training Loss: 0.55146889, Training Accuracy: 1.0000
# Epoch [91/100], Validation Loss: 0.72669592, Validation Accuracy: 0.8235
# Epoch [92/100], Training Loss: 0.55146847, Training Accuracy: 1.0000
# Epoch [92/100], Validation Loss: 0.72697127, Validation Accuracy: 0.8235
# Epoch [93/100], Training Loss: 0.55146807, Training Accuracy: 1.0000
# Epoch [93/100], Validation Loss: 0.72708285, Validation Accuracy: 0.8235
# Epoch [94/100], Training Loss: 0.55146762, Training Accuracy: 1.0000
# Epoch [94/100], Validation Loss: 0.72693083, Validation Accuracy: 0.8235
# Epoch [95/100], Training Loss: 0.55146721, Training Accuracy: 1.0000
# Epoch [95/100], Validation Loss: 0.72693810, Validation Accuracy: 0.8235
# Epoch [96/100], Training Loss: 0.55146682, Training Accuracy: 1.0000
# Epoch [96/100], Validation Loss: 0.72675744, Validation Accuracy: 0.8235
# Epoch [97/100], Training Loss: 0.55146644, Training Accuracy: 1.0000
# Epoch [97/100], Validation Loss: 0.72667375, Validation Accuracy: 0.8235
# Epoch [98/100], Training Loss: 0.55146605, Training Accuracy: 1.0000
# Epoch [98/100], Validation Loss: 0.72610360, Validation Accuracy: 0.8235
# Epoch [99/100], Training Loss: 0.55146571, Training Accuracy: 1.0000
# Epoch [99/100], Validation Loss: 0.72613171, Validation Accuracy: 0.8235
# Epoch [100/100], Training Loss: 0.55146533, Training Accuracy: 1.0000
# Epoch [100/100], Validation Loss: 0.72635889, Validation Accuracy: 0.8235

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 0.6765

# %% [markdown]
# ##### Analysis LSTM
# Validation accuracy peaks to 0.8235 very early at 55 epochs. Test accuracy is 0.6765.

# %% [markdown]
# ##### Define GRU

# %%
# chatgpt 3.5 generated code
# GRU Model with Softmax
class GRUWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(GRUWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.gru(x, h0)
        out = self.fc(out[:, -1, :])  # Use only the last time step's output for classification
        return nn.functional.softmax(out, dim=1)  # Apply softmax activation

# %% [markdown]
# ##### Train GRU: setup

# %%
# chatgpt 3.5 generated code
model = GRUWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the GRU and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code (this code is a copy of the RNN code)
# Training loop
# GRU_total_epochs = number_of_epochs
GRU_total_epochs = GRU_number_of_epochs

# Lists to store training/validation losses and training/validation accuracies
GRU_train_losses = []  
GRU_val_losses = []    
GRU_train_accuracies = []  
GRU_val_accuracies = []    

for epoch in range(GRU_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    GRU_train_losses.append(average_train_loss)
    GRU_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{GRU_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Store validation loss and accuracy values
    GRU_val_losses.append(average_val_loss)
    GRU_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{GRU_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')

# Plot the losses and accuracies at the end of all epochs
GRU_x_epochs = list(range(1, GRU_total_epochs + 1))

plt.figure(figsize=(12, 4))

# Plot Losses
plt.subplot(1, 2, 1)
plt.plot(GRU_x_epochs, GRU_train_losses, label='GRU Training Loss')
plt.plot(GRU_x_epochs, GRU_val_losses, label='GRU Validation Loss')
plt.xlabel('GRU Epochs')
plt.ylabel('GRU Loss')
plt.title('GRU Training and Validation Loss')
plt.legend()

# Plot Accuracies
plt.subplot(1, 2, 2)
plt.plot(GRU_x_epochs, GRU_train_accuracies, label='GRU Training Accuracy')
plt.plot(GRU_x_epochs, GRU_val_accuracies, label='GRU Validation Accuracy')
plt.xlabel('GRU Epochs')
plt.ylabel('GRU Accuracy')
plt.title('GRU Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/75], Training Loss: 1.06487191, Training Accuracy: 0.4160
# Epoch [1/75], Validation Loss: 1.04531300, Validation Accuracy: 0.3676
# Epoch [2/75], Training Loss: 0.98955949, Training Accuracy: 0.4622
# Epoch [2/75], Validation Loss: 0.99337682, Validation Accuracy: 0.4706
# Epoch [3/75], Training Loss: 0.90022551, Training Accuracy: 0.7605
# Epoch [3/75], Validation Loss: 0.95405197, Validation Accuracy: 0.5735
# Epoch [4/75], Training Loss: 0.76882503, Training Accuracy: 0.8992
# Epoch [4/75], Validation Loss: 0.82522514, Validation Accuracy: 0.7941
# Epoch [5/75], Training Loss: 0.66112555, Training Accuracy: 0.9202
# Epoch [5/75], Validation Loss: 0.79935202, Validation Accuracy: 0.7647
# Epoch [6/75], Training Loss: 0.60162450, Training Accuracy: 0.9706
# Epoch [6/75], Validation Loss: 0.82508758, Validation Accuracy: 0.7500
# Epoch [7/75], Training Loss: 0.57382257, Training Accuracy: 0.9958
# Epoch [7/75], Validation Loss: 0.83040369, Validation Accuracy: 0.7206
# Epoch [8/75], Training Loss: 0.56159822, Training Accuracy: 0.9958
# Epoch [8/75], Validation Loss: 0.81273252, Validation Accuracy: 0.7500
# Epoch [9/75], Training Loss: 0.55459269, Training Accuracy: 1.0000
# Epoch [9/75], Validation Loss: 0.79776344, Validation Accuracy: 0.7500
# Epoch [10/75], Training Loss: 0.55238719, Training Accuracy: 1.0000
# Epoch [10/75], Validation Loss: 0.78557014, Validation Accuracy: 0.7500
# Epoch [11/75], Training Loss: 0.55197716, Training Accuracy: 1.0000
# Epoch [11/75], Validation Loss: 0.76773477, Validation Accuracy: 0.7941
# Epoch [12/75], Training Loss: 0.55177760, Training Accuracy: 1.0000
# Epoch [12/75], Validation Loss: 0.75807676, Validation Accuracy: 0.7794
# Epoch [13/75], Training Loss: 0.55170036, Training Accuracy: 1.0000
# Epoch [13/75], Validation Loss: 0.75869527, Validation Accuracy: 0.7647
# Epoch [14/75], Training Loss: 0.55164194, Training Accuracy: 1.0000
# Epoch [14/75], Validation Loss: 0.74542150, Validation Accuracy: 0.7941
# Epoch [15/75], Training Loss: 0.55161104, Training Accuracy: 1.0000
# Epoch [15/75], Validation Loss: 0.73824757, Validation Accuracy: 0.7941
# Epoch [16/75], Training Loss: 0.55159236, Training Accuracy: 1.0000
# Epoch [16/75], Validation Loss: 0.73703063, Validation Accuracy: 0.7941
# Epoch [17/75], Training Loss: 0.55157813, Training Accuracy: 1.0000
# Epoch [17/75], Validation Loss: 0.74014461, Validation Accuracy: 0.7794
# Epoch [18/75], Training Loss: 0.55156921, Training Accuracy: 1.0000
# Epoch [18/75], Validation Loss: 0.74531794, Validation Accuracy: 0.7794
# Epoch [19/75], Training Loss: 0.55156123, Training Accuracy: 1.0000
# Epoch [19/75], Validation Loss: 0.74022648, Validation Accuracy: 0.7794
# Epoch [20/75], Training Loss: 0.55155427, Training Accuracy: 1.0000
# Epoch [20/75], Validation Loss: 0.73914212, Validation Accuracy: 0.7941
# Epoch [21/75], Training Loss: 0.55154829, Training Accuracy: 1.0000
# Epoch [21/75], Validation Loss: 0.73764646, Validation Accuracy: 0.8088
# Epoch [22/75], Training Loss: 0.55154320, Training Accuracy: 1.0000
# Epoch [22/75], Validation Loss: 0.73447201, Validation Accuracy: 0.8088
# Epoch [23/75], Training Loss: 0.55153841, Training Accuracy: 1.0000
# Epoch [23/75], Validation Loss: 0.73412845, Validation Accuracy: 0.8088
# Epoch [24/75], Training Loss: 0.55153372, Training Accuracy: 1.0000
# Epoch [24/75], Validation Loss: 0.73557609, Validation Accuracy: 0.8088
# Epoch [25/75], Training Loss: 0.55152959, Training Accuracy: 1.0000
# Epoch [25/75], Validation Loss: 0.73552430, Validation Accuracy: 0.8235
# Epoch [26/75], Training Loss: 0.55152608, Training Accuracy: 1.0000
# Epoch [26/75], Validation Loss: 0.72989348, Validation Accuracy: 0.8235
# Epoch [27/75], Training Loss: 0.55152227, Training Accuracy: 1.0000
# Epoch [27/75], Validation Loss: 0.72766787, Validation Accuracy: 0.8235
# Epoch [28/75], Training Loss: 0.55151884, Training Accuracy: 1.0000
# Epoch [28/75], Validation Loss: 0.72798806, Validation Accuracy: 0.8235
# Epoch [29/75], Training Loss: 0.55151602, Training Accuracy: 1.0000
# Epoch [29/75], Validation Loss: 0.72692886, Validation Accuracy: 0.8235
# Epoch [30/75], Training Loss: 0.55151325, Training Accuracy: 1.0000
# Epoch [30/75], Validation Loss: 0.72484925, Validation Accuracy: 0.8382
# Epoch [31/75], Training Loss: 0.55151053, Training Accuracy: 1.0000
# Epoch [31/75], Validation Loss: 0.72318479, Validation Accuracy: 0.8382
# Epoch [32/75], Training Loss: 0.55150809, Training Accuracy: 1.0000
# Epoch [32/75], Validation Loss: 0.72148427, Validation Accuracy: 0.8382
# Epoch [33/75], Training Loss: 0.55150574, Training Accuracy: 1.0000
# Epoch [33/75], Validation Loss: 0.72117719, Validation Accuracy: 0.8382
# Epoch [34/75], Training Loss: 0.55150355, Training Accuracy: 1.0000
# Epoch [34/75], Validation Loss: 0.72086188, Validation Accuracy: 0.8382
# Epoch [35/75], Training Loss: 0.55150156, Training Accuracy: 1.0000
# Epoch [35/75], Validation Loss: 0.72054869, Validation Accuracy: 0.8382
# Epoch [36/75], Training Loss: 0.55149965, Training Accuracy: 1.0000
# Epoch [36/75], Validation Loss: 0.71925128, Validation Accuracy: 0.8382
# Epoch [37/75], Training Loss: 0.55149786, Training Accuracy: 1.0000
# Epoch [37/75], Validation Loss: 0.71742412, Validation Accuracy: 0.8382
# Epoch [38/75], Training Loss: 0.55149618, Training Accuracy: 1.0000
# Epoch [38/75], Validation Loss: 0.71672955, Validation Accuracy: 0.8382
# Epoch [39/75], Training Loss: 0.55149450, Training Accuracy: 1.0000
# Epoch [39/75], Validation Loss: 0.71755615, Validation Accuracy: 0.8382
# Epoch [40/75], Training Loss: 0.55149304, Training Accuracy: 1.0000
# Epoch [40/75], Validation Loss: 0.71800658, Validation Accuracy: 0.8382
# Epoch [41/75], Training Loss: 0.55149170, Training Accuracy: 1.0000
# Epoch [41/75], Validation Loss: 0.71624771, Validation Accuracy: 0.8382
# Epoch [42/75], Training Loss: 0.55149023, Training Accuracy: 1.0000
# Epoch [42/75], Validation Loss: 0.71675467, Validation Accuracy: 0.8382
# Epoch [43/75], Training Loss: 0.55148890, Training Accuracy: 1.0000
# Epoch [43/75], Validation Loss: 0.71732503, Validation Accuracy: 0.8382
# Epoch [44/75], Training Loss: 0.55148779, Training Accuracy: 1.0000
# Epoch [44/75], Validation Loss: 0.71578923, Validation Accuracy: 0.8382
# Epoch [45/75], Training Loss: 0.55148656, Training Accuracy: 1.0000
# Epoch [45/75], Validation Loss: 0.71622127, Validation Accuracy: 0.8382
# Epoch [46/75], Training Loss: 0.55148539, Training Accuracy: 1.0000
# Epoch [46/75], Validation Loss: 0.71577528, Validation Accuracy: 0.8382
# Epoch [47/75], Training Loss: 0.55148432, Training Accuracy: 1.0000
# Epoch [47/75], Validation Loss: 0.71529570, Validation Accuracy: 0.8382
# Epoch [48/75], Training Loss: 0.55148326, Training Accuracy: 1.0000
# Epoch [48/75], Validation Loss: 0.71542698, Validation Accuracy: 0.8382
# Epoch [49/75], Training Loss: 0.55148230, Training Accuracy: 1.0000
# Epoch [49/75], Validation Loss: 0.71606076, Validation Accuracy: 0.8382
# Epoch [50/75], Training Loss: 0.55148146, Training Accuracy: 1.0000
# Epoch [50/75], Validation Loss: 0.71363235, Validation Accuracy: 0.8382
# Epoch [51/75], Training Loss: 0.55148042, Training Accuracy: 1.0000
# Epoch [51/75], Validation Loss: 0.71508509, Validation Accuracy: 0.8382
# Epoch [52/75], Training Loss: 0.55147962, Training Accuracy: 1.0000
# Epoch [52/75], Validation Loss: 0.71612918, Validation Accuracy: 0.8382
# Epoch [53/75], Training Loss: 0.55147872, Training Accuracy: 1.0000
# Epoch [53/75], Validation Loss: 0.71624961, Validation Accuracy: 0.8382
# Epoch [54/75], Training Loss: 0.55147788, Training Accuracy: 1.0000
# Epoch [54/75], Validation Loss: 0.71621761, Validation Accuracy: 0.8382
# Epoch [55/75], Training Loss: 0.55147720, Training Accuracy: 1.0000
# Epoch [55/75], Validation Loss: 0.71455252, Validation Accuracy: 0.8382
# Epoch [56/75], Training Loss: 0.55147646, Training Accuracy: 1.0000
# Epoch [56/75], Validation Loss: 0.71420062, Validation Accuracy: 0.8382
# Epoch [57/75], Training Loss: 0.55147575, Training Accuracy: 1.0000
# Epoch [57/75], Validation Loss: 0.71403980, Validation Accuracy: 0.8382
# Epoch [58/75], Training Loss: 0.55147496, Training Accuracy: 1.0000
# Epoch [58/75], Validation Loss: 0.71384972, Validation Accuracy: 0.8382
# Epoch [59/75], Training Loss: 0.55147431, Training Accuracy: 1.0000
# Epoch [59/75], Validation Loss: 0.71346465, Validation Accuracy: 0.8382
# Epoch [60/75], Training Loss: 0.55147372, Training Accuracy: 1.0000
# Epoch [60/75], Validation Loss: 0.71436507, Validation Accuracy: 0.8382
# Epoch [61/75], Training Loss: 0.55147303, Training Accuracy: 1.0000
# Epoch [61/75], Validation Loss: 0.71584997, Validation Accuracy: 0.8382
# Epoch [62/75], Training Loss: 0.55147243, Training Accuracy: 1.0000
# Epoch [62/75], Validation Loss: 0.71608567, Validation Accuracy: 0.8382
# Epoch [63/75], Training Loss: 0.55147189, Training Accuracy: 1.0000
# Epoch [63/75], Validation Loss: 0.71398172, Validation Accuracy: 0.8382
# Epoch [64/75], Training Loss: 0.55147129, Training Accuracy: 1.0000
# Epoch [64/75], Validation Loss: 0.71261147, Validation Accuracy: 0.8382
# Epoch [65/75], Training Loss: 0.55147079, Training Accuracy: 1.0000
# Epoch [65/75], Validation Loss: 0.71258309, Validation Accuracy: 0.8382
# Epoch [66/75], Training Loss: 0.55147019, Training Accuracy: 1.0000
# Epoch [66/75], Validation Loss: 0.71298373, Validation Accuracy: 0.8382
# Epoch [67/75], Training Loss: 0.55146964, Training Accuracy: 1.0000
# Epoch [67/75], Validation Loss: 0.71234134, Validation Accuracy: 0.8382
# Epoch [68/75], Training Loss: 0.55146925, Training Accuracy: 1.0000
# Epoch [68/75], Validation Loss: 0.71156955, Validation Accuracy: 0.8382
# Epoch [69/75], Training Loss: 0.55146874, Training Accuracy: 1.0000
# Epoch [69/75], Validation Loss: 0.71130988, Validation Accuracy: 0.8382
# Epoch [70/75], Training Loss: 0.55146828, Training Accuracy: 1.0000
# Epoch [70/75], Validation Loss: 0.71394101, Validation Accuracy: 0.8382
# Epoch [71/75], Training Loss: 0.55146779, Training Accuracy: 1.0000
# Epoch [71/75], Validation Loss: 0.71419299, Validation Accuracy: 0.8382
# Epoch [72/75], Training Loss: 0.55146738, Training Accuracy: 1.0000
# Epoch [72/75], Validation Loss: 0.71550310, Validation Accuracy: 0.8382
# Epoch [73/75], Training Loss: 0.55146698, Training Accuracy: 1.0000
# Epoch [73/75], Validation Loss: 0.71161419, Validation Accuracy: 0.8382
# Epoch [74/75], Training Loss: 0.55146655, Training Accuracy: 1.0000
# Epoch [74/75], Validation Loss: 0.71102017, Validation Accuracy: 0.8382
# Epoch [75/75], Training Loss: 0.55146613, Training Accuracy: 1.0000
# Epoch [75/75], Validation Loss: 0.71168146, Validation Accuracy: 0.8382

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 0.6765

# %% [markdown]
# ##### Analysis GRU
# Validation accuracy peaks to 0.8382 very early at 75 epochs. Test accuracy is 0.6765.
