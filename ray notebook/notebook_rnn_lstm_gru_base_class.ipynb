# %% [markdown]
# #### RNN, LSTM, GRU classification of mouse wheel movement based on Steinmetz `spks` dataset and code from [nma](https://deeplearning.neuromatch.io/projects/Neuroscience/neuro_seq_to_seq.html) for sliced time sample data
#
# __Note__: You must restart the notebook for training the LSTM and GRU models and each time you rerun a model. This appears to be an issue of the previous model remaining on the GPU after training.

# %% [markdown]
# ##### Imports

# %%
# Imports
import torch
import random
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets, io, models, ops, transforms, utils
from matplotlib import pyplot as plt

# %% [markdown]
# ##### Device

# %%
# @title Set device (GPU or CPU). Execute `set_device()`

# Inform the user if the notebook uses GPU or CPU.

def set_device():
  """
  Set the device. CUDA if available, CPU otherwise

  Args:
    None

  Returns:
    Nothing
  """
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
  else:
    print("GPU is enabled in this notebook.")

  return device

# %% [markdown]
# ##### Set random seed

# %%
# @markdown Executing `set_seed(seed=seed)` you are setting the seed

# For DL its critical to set the random seed so that students can have a
# baseline to compare their results to expected results.
# Read more here: https://pytorch.org/docs/stable/notes/randomness.html

# Call `set_seed` function in the exercises to ensure reproducibility.

def set_seed(seed=None, seed_torch=True):
  """
  Function that controls randomness. NumPy and random modules must be imported.

  Args:
    seed : Integer
      A non-negative integer that defines the random state. Default is `None`.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors, so pytorch module
      must be imported. Default is `True`.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):
  """
  DataLoader will reseed workers following randomness in
  multi-process data loading algorithm.

  Args:
    worker_id: integer
      ID of subprocess to seed. 0 means that
      the data will be loaded in the main process
      Refer: https://pytorch.org/docs/stable/data.html#data-loading-randomness for more details

  Returns:
    Nothing
  """
  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)

# %%
SEED = 2021
set_seed(seed=SEED)
device = set_device()
# Out:
# Random seed 2021 has been set.
# GPU is enabled in this notebook.

# %% [markdown]
# ##### Data retrieval

# %%
# store the dataset files in the datasets folder
import os, requests

fname = []
ds = "../datasets"

for j in range(3):
  fname.append('steinmetz_part%d.npz'%j)
url = ["https://osf.io/agvxh/download"]
url.append("https://osf.io/uv3mw/download")
url.append("https://osf.io/ehmw2/download")

for j in range(len(url)):
  if not os.path.isfile("/".join([ds, fname[j]])):
    try:
      r = requests.get(url[j])
    except requests.ConnectionError:
      print("!!! Failed to download data !!!")
    else:
      if r.status_code != requests.codes.ok:
        print("!!! Failed to download data !!!")
      else:
        with open("/".join([ds, fname[j]]), "wb") as fid:
          fid.write(r.content)

# %%
# data loading
alldat = np.array([])
for j in range(len(fname)):
  alldat = np.hstack((alldat,
                      np.load("/".join([ds, 'steinmetz_part%d.npz'%j]),
                              allow_pickle=True)['dat']))

# %% [markdown]
# ##### Select recording 11

# %%
# select recording 11
dat = alldat[11]

# %% [markdown]
# ##### Format dataset
# An RNN has specific data requirements fed into the network for training, testing, and prediction. The depth of the network in a time or data series is given by `hidden_size`. In the case of the `spks` dataset this is 250 because one trial lasts for this many samples. These are the 250 sequenced datapoints related to the same mouse event trial from the same probe sensor size of 698 neurons over a time period of 2500ms. Further mouse trials are added in sequence in the dataset, where the training and forward algorithms reset to the start of the RNN. This dataset is then 698 neurons wide with 250 datapoints and 340 trials in length, before being split into train and test sets.

# %%
def shuffle_dataset(X, y):
  """
  Helper function to shuffle and split data
  Assumes that set_seed has already been run

  Args:
    X: torch.tensor
      Input data trials X time samples X neurons
    y: torch.tensor
      Corresponding one hot target variables as trials x categories
      
  Returns:
    X: torch.tensor
    y: torch.tensor
  """

  # Number of trials
  N = X.shape[0]

  # Shuffle data
  shuffled_indices = np.random.permutation(N) 
  X = X[shuffled_indices, :, :]
  y = y[shuffled_indices, :]
  
  return X, y

# %%
# data are neurons X trials x time samples, but permute to trials X time samples X neurons
x = torch.tensor(dat['spks']).permute(1,2,0)

# slice time samples so that we retain values between 50 to 150, dropping 0-49 and 151-250
x = x[:,50:150,:]

# response is -1, 0, 1, but convert to one hot where 2 takes the place of -1 to satisfy torch one hot
dat['response'][dat['response'] == -1] = 2 
y = torch.as_tensor(dat['response']).long()
y = F.one_hot(y)

# shuffle dataset before split
x, y = shuffle_dataset(x, y)

# split into train (70%), validation(20%) and test(10%) sets using batch size of 34
n_trials = int(x.shape[0])
ntr = int(n_trials * 7 / 10)
nv = int(n_trials * 2 / 10) + ntr

X_train = x[:ntr, :, :].to(device).float()
X_val = x[ntr:nv, :, :].to(device).float()
X_test = x[nv:, :, :].to(device).float()

y_train = y[:ntr].to(device).float()
y_val = y[ntr:nv].to(device).float()
y_test = y[nv:].to(device).float()

# %%
print(y[0])
print(x.shape)
print(y.shape)
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# tensor([0, 0, 1])
# torch.Size([340, 100, 698])
# torch.Size([340, 3])
# torch.Size([238, 100, 698])
# torch.Size([238, 3])
# torch.Size([68, 100, 698])
# torch.Size([68, 3])
# torch.Size([34, 100, 698])
# torch.Size([34, 3])

# %%
##### Visualise data from one trial to show time slicing
plt.figure(figsize = (10, 6))
plt.imshow(x[0,:,:].T, cmap='gray_r', vmax = 3, vmin=0, aspect='auto')
plt.xticks([0, 20, 40, 60, 80], [500, 700, 900, 1100, 1300]) 
plt.xlabel('Time (ms) with 10ms bins')
plt.ylabel('Cell #')
plt.colorbar(orientation='vertical', label='# Spikes in 10ms time bin')
plt.title('Example trial')
plt.show()

# %% [markdown]
# ##### Dataloader

# %%
# batch_size of 34 used to match number of trials
batch_size = 34

# Create DataLoader for training data
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Create DataLoader for validation data
val_dataset = TensorDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Create DataLoader for test data
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### Hyperparameters

# %%
# number of hidden RNN stages, inputs and outputs
hidden_size = x.shape[1]
input_size = x.shape[2]
output_size = y_train.shape[1]
num_layers = 1
learning_rate = 0.001
number_of_epochs = 1000

# try similar epochs
RNN_number_of_epochs = 70
LSTM_number_of_epochs = 70
GRU_number_of_epochs = 70

# early stopping not used
# RNN_patience = 5
# LSTM_patience = 5
# GRU_patience = 5

# %%
print(hidden_size)
print(input_size)
print(output_size)
# Out:
# 100
# 698
# 3

# %% [markdown]
# ##### Define RNN
# Since the `hidden_size` is 250 we can expect to see either exploding or vanishing gradients in the RNN. For this case we can't expect the RNN to be able to predict well. But, as Dev did, we can reduce the `hidden_size` by slicing off data which doesn't correspond to wheel movement.

# %%
# chatgpt 3.5 generated code
# RNN Model with Softmax
class RNNWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(RNNWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Define the RNN layer
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        
        # Define the fully connected layer to map RNN output to class labels
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.rnn(x, h0)

        # Use only the last time step's output for classification
        out = self.fc(out[:, -1, :]) 

        # Apply softmax activation
        return nn.functional.softmax(out, dim=1)

# %% [markdown]
# ##### Train the RNN: setup

# %%
# chatgpt 3.5 generated code
model = RNNWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ##### Train the RNN and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code
# Training loop
# RNN_total_epochs = number_of_epochs
RNN_total_epochs = RNN_number_of_epochs

# Early stopping parameters
# best_val_loss = float('inf')
# epochs_since_best = 0

# Number of epochs to wait for improvement in validation loss
# patience = RNN_patience

# Lists to store training/validation losses and training/validation accuracies
RNN_train_losses = []  
RNN_val_losses = []    
RNN_train_accuracies = []  
RNN_val_accuracies = []    

for epoch in range(RNN_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    RNN_train_losses.append(average_train_loss)
    RNN_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{RNN_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Check if validation loss has improved
    # if average_val_loss < best_val_loss:
    #    best_val_loss = average_val_loss
    #    epochs_since_best = 0
    # else:
    #    epochs_since_best += 1

    # Store validation loss and accuracy values
    RNN_val_losses.append(average_val_loss)
    RNN_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{RNN_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')

    # Early stopping check
    # if epochs_since_best >= patience:
    #    print(f"Early stopping at epoch {epoch + 1}. Validation loss did not improve for {patience} epochs.")
    #    break
# Out:
# Epoch [1/70], Training Loss: 1.07036500, Training Accuracy: 0.4496
# Epoch [1/70], Validation Loss: 1.07958597, Validation Accuracy: 0.2941
# Epoch [2/70], Training Loss: 1.00776352, Training Accuracy: 0.5168
# Epoch [2/70], Validation Loss: 1.06735802, Validation Accuracy: 0.3529
# Epoch [3/70], Training Loss: 0.96925672, Training Accuracy: 0.7143
# Epoch [3/70], Validation Loss: 1.04939395, Validation Accuracy: 0.4412
# Epoch [4/70], Training Loss: 0.91269012, Training Accuracy: 0.7941
# Epoch [4/70], Validation Loss: 1.03802580, Validation Accuracy: 0.4706
# Epoch [5/70], Training Loss: 0.83418588, Training Accuracy: 0.8697
# Epoch [5/70], Validation Loss: 0.99087742, Validation Accuracy: 0.5735
# Epoch [6/70], Training Loss: 0.73246628, Training Accuracy: 0.9202
# Epoch [6/70], Validation Loss: 0.81348380, Validation Accuracy: 0.7647
# Epoch [7/70], Training Loss: 0.67037347, Training Accuracy: 0.9664
# Epoch [7/70], Validation Loss: 0.91365957, Validation Accuracy: 0.7206
# Epoch [8/70], Training Loss: 0.63801731, Training Accuracy: 0.9832
# Epoch [8/70], Validation Loss: 0.89719495, Validation Accuracy: 0.6765
# Epoch [9/70], Training Loss: 0.61052806, Training Accuracy: 0.9790
# Epoch [9/70], Validation Loss: 0.82216161, Validation Accuracy: 0.7500
# Epoch [10/70], Training Loss: 0.58799590, Training Accuracy: 0.9874
# Epoch [10/70], Validation Loss: 0.82609802, Validation Accuracy: 0.7500
# Epoch [11/70], Training Loss: 0.57185576, Training Accuracy: 0.9958
# Epoch [11/70], Validation Loss: 0.82224336, Validation Accuracy: 0.7647
# Epoch [12/70], Training Loss: 0.56568130, Training Accuracy: 1.0000
# Epoch [12/70], Validation Loss: 0.78232267, Validation Accuracy: 0.8088
# Epoch [13/70], Training Loss: 0.56053415, Training Accuracy: 1.0000
# Epoch [13/70], Validation Loss: 0.77684745, Validation Accuracy: 0.8088
# Epoch [14/70], Training Loss: 0.55749179, Training Accuracy: 1.0000
# Epoch [14/70], Validation Loss: 0.75548846, Validation Accuracy: 0.8235
# Epoch [15/70], Training Loss: 0.55617702, Training Accuracy: 1.0000
# Epoch [15/70], Validation Loss: 0.75648099, Validation Accuracy: 0.8088
# Epoch [16/70], Training Loss: 0.55533473, Training Accuracy: 1.0000
# Epoch [16/70], Validation Loss: 0.75256130, Validation Accuracy: 0.7794
# Epoch [17/70], Training Loss: 0.55472190, Training Accuracy: 1.0000
# Epoch [17/70], Validation Loss: 0.73695120, Validation Accuracy: 0.7941
# Epoch [18/70], Training Loss: 0.55427538, Training Accuracy: 1.0000
# Epoch [18/70], Validation Loss: 0.73197919, Validation Accuracy: 0.8088
# Epoch [19/70], Training Loss: 0.55395414, Training Accuracy: 1.0000
# Epoch [19/70], Validation Loss: 0.73452595, Validation Accuracy: 0.8235
# Epoch [20/70], Training Loss: 0.55369543, Training Accuracy: 1.0000
# Epoch [20/70], Validation Loss: 0.73215553, Validation Accuracy: 0.8235
# Epoch [21/70], Training Loss: 0.55348137, Training Accuracy: 1.0000
# Epoch [21/70], Validation Loss: 0.72508234, Validation Accuracy: 0.8235
# Epoch [22/70], Training Loss: 0.55330558, Training Accuracy: 1.0000
# Epoch [22/70], Validation Loss: 0.72289398, Validation Accuracy: 0.8088
# Epoch [23/70], Training Loss: 0.55316518, Training Accuracy: 1.0000
# Epoch [23/70], Validation Loss: 0.72142529, Validation Accuracy: 0.8235
# Epoch [24/70], Training Loss: 0.55303108, Training Accuracy: 1.0000
# Epoch [24/70], Validation Loss: 0.71982062, Validation Accuracy: 0.8235
# Epoch [25/70], Training Loss: 0.55291587, Training Accuracy: 1.0000
# Epoch [25/70], Validation Loss: 0.71654895, Validation Accuracy: 0.8235
# Epoch [26/70], Training Loss: 0.55281575, Training Accuracy: 1.0000
# Epoch [26/70], Validation Loss: 0.71704566, Validation Accuracy: 0.8235
# Epoch [27/70], Training Loss: 0.55272626, Training Accuracy: 1.0000
# Epoch [27/70], Validation Loss: 0.71529043, Validation Accuracy: 0.8088
# Epoch [28/70], Training Loss: 0.55264699, Training Accuracy: 1.0000
# Epoch [28/70], Validation Loss: 0.70979893, Validation Accuracy: 0.8235
# Epoch [29/70], Training Loss: 0.55257262, Training Accuracy: 1.0000
# Epoch [29/70], Validation Loss: 0.70876381, Validation Accuracy: 0.8235
# Epoch [30/70], Training Loss: 0.55250607, Training Accuracy: 1.0000
# Epoch [30/70], Validation Loss: 0.70837414, Validation Accuracy: 0.8382
# Epoch [31/70], Training Loss: 0.55244988, Training Accuracy: 1.0000
# Epoch [31/70], Validation Loss: 0.70701799, Validation Accuracy: 0.8382
# Epoch [32/70], Training Loss: 0.55239504, Training Accuracy: 1.0000
# Epoch [32/70], Validation Loss: 0.70556480, Validation Accuracy: 0.8235
# Epoch [33/70], Training Loss: 0.55235180, Training Accuracy: 1.0000
# Epoch [33/70], Validation Loss: 0.70399275, Validation Accuracy: 0.8382
# Epoch [34/70], Training Loss: 0.55230194, Training Accuracy: 1.0000
# Epoch [34/70], Validation Loss: 0.70202613, Validation Accuracy: 0.8382
# Epoch [35/70], Training Loss: 0.55225924, Training Accuracy: 1.0000
# Epoch [35/70], Validation Loss: 0.70182219, Validation Accuracy: 0.8382
# Epoch [36/70], Training Loss: 0.55222155, Training Accuracy: 1.0000
# Epoch [36/70], Validation Loss: 0.70183811, Validation Accuracy: 0.8235
# Epoch [37/70], Training Loss: 0.55218863, Training Accuracy: 1.0000
# Epoch [37/70], Validation Loss: 0.70185062, Validation Accuracy: 0.8235
# Epoch [38/70], Training Loss: 0.55215435, Training Accuracy: 1.0000
# Epoch [38/70], Validation Loss: 0.69945410, Validation Accuracy: 0.8382
# Epoch [39/70], Training Loss: 0.55212477, Training Accuracy: 1.0000
# Epoch [39/70], Validation Loss: 0.69741914, Validation Accuracy: 0.8529
# Epoch [40/70], Training Loss: 0.55209658, Training Accuracy: 1.0000
# Epoch [40/70], Validation Loss: 0.69732723, Validation Accuracy: 0.8529
# Epoch [41/70], Training Loss: 0.55207028, Training Accuracy: 1.0000
# Epoch [41/70], Validation Loss: 0.69700772, Validation Accuracy: 0.8382
# Epoch [42/70], Training Loss: 0.55204472, Training Accuracy: 1.0000
# Epoch [42/70], Validation Loss: 0.69534996, Validation Accuracy: 0.8529
# Epoch [43/70], Training Loss: 0.55202112, Training Accuracy: 1.0000
# Epoch [43/70], Validation Loss: 0.69449699, Validation Accuracy: 0.8529
# Epoch [44/70], Training Loss: 0.55200015, Training Accuracy: 1.0000
# Epoch [44/70], Validation Loss: 0.69504237, Validation Accuracy: 0.8529
# Epoch [45/70], Training Loss: 0.55197958, Training Accuracy: 1.0000
# Epoch [45/70], Validation Loss: 0.69349977, Validation Accuracy: 0.8529
# Epoch [46/70], Training Loss: 0.55196302, Training Accuracy: 1.0000
# Epoch [46/70], Validation Loss: 0.69182539, Validation Accuracy: 0.8529
# Epoch [47/70], Training Loss: 0.55194273, Training Accuracy: 1.0000
# Epoch [47/70], Validation Loss: 0.69297102, Validation Accuracy: 0.8529
# Epoch [48/70], Training Loss: 0.55192519, Training Accuracy: 1.0000
# Epoch [48/70], Validation Loss: 0.69310504, Validation Accuracy: 0.8529
# Epoch [49/70], Training Loss: 0.55191037, Training Accuracy: 1.0000
# Epoch [49/70], Validation Loss: 0.69270489, Validation Accuracy: 0.8382
# Epoch [50/70], Training Loss: 0.55189348, Training Accuracy: 1.0000
# Epoch [50/70], Validation Loss: 0.69022167, Validation Accuracy: 0.8529
# Epoch [51/70], Training Loss: 0.55187948, Training Accuracy: 1.0000
# Epoch [51/70], Validation Loss: 0.69010249, Validation Accuracy: 0.8529
# Epoch [52/70], Training Loss: 0.55186569, Training Accuracy: 1.0000
# Epoch [52/70], Validation Loss: 0.69024101, Validation Accuracy: 0.8529
# Epoch [53/70], Training Loss: 0.55185235, Training Accuracy: 1.0000
# Epoch [53/70], Validation Loss: 0.68902409, Validation Accuracy: 0.8529
# Epoch [54/70], Training Loss: 0.55184050, Training Accuracy: 1.0000
# Epoch [54/70], Validation Loss: 0.68898562, Validation Accuracy: 0.8529
# Epoch [55/70], Training Loss: 0.55182888, Training Accuracy: 1.0000
# Epoch [55/70], Validation Loss: 0.68924969, Validation Accuracy: 0.8529
# Epoch [56/70], Training Loss: 0.55181688, Training Accuracy: 1.0000
# Epoch [56/70], Validation Loss: 0.68825036, Validation Accuracy: 0.8529
# Epoch [57/70], Training Loss: 0.55180622, Training Accuracy: 1.0000
# Epoch [57/70], Validation Loss: 0.68756062, Validation Accuracy: 0.8529
# Epoch [58/70], Training Loss: 0.55179588, Training Accuracy: 1.0000
# Epoch [58/70], Validation Loss: 0.68725517, Validation Accuracy: 0.8529
# Epoch [59/70], Training Loss: 0.55178741, Training Accuracy: 1.0000
# Epoch [59/70], Validation Loss: 0.68830121, Validation Accuracy: 0.8529
# Epoch [60/70], Training Loss: 0.55177718, Training Accuracy: 1.0000
# Epoch [60/70], Validation Loss: 0.68640065, Validation Accuracy: 0.8529
# Epoch [61/70], Training Loss: 0.55176829, Training Accuracy: 1.0000
# Epoch [61/70], Validation Loss: 0.68620133, Validation Accuracy: 0.8529
# Epoch [62/70], Training Loss: 0.55175962, Training Accuracy: 1.0000
# Epoch [62/70], Validation Loss: 0.68708575, Validation Accuracy: 0.8529
# Epoch [63/70], Training Loss: 0.55175135, Training Accuracy: 1.0000
# Epoch [63/70], Validation Loss: 0.68681121, Validation Accuracy: 0.8529
# Epoch [64/70], Training Loss: 0.55174321, Training Accuracy: 1.0000
# Epoch [64/70], Validation Loss: 0.68562695, Validation Accuracy: 0.8676
# Epoch [65/70], Training Loss: 0.55173591, Training Accuracy: 1.0000
# Epoch [65/70], Validation Loss: 0.68509665, Validation Accuracy: 0.8676
# Epoch [66/70], Training Loss: 0.55172835, Training Accuracy: 1.0000
# Epoch [66/70], Validation Loss: 0.68517032, Validation Accuracy: 0.8676
# Epoch [67/70], Training Loss: 0.55172154, Training Accuracy: 1.0000
# Epoch [67/70], Validation Loss: 0.68517527, Validation Accuracy: 0.8676
# Epoch [68/70], Training Loss: 0.55171489, Training Accuracy: 1.0000
# Epoch [68/70], Validation Loss: 0.68512151, Validation Accuracy: 0.8676
# Epoch [69/70], Training Loss: 0.55170849, Training Accuracy: 1.0000
# Epoch [69/70], Validation Loss: 0.68479893, Validation Accuracy: 0.8676
# Epoch [70/70], Training Loss: 0.55170219, Training Accuracy: 1.0000
# Epoch [70/70], Validation Loss: 0.68459919, Validation Accuracy: 0.8676

# %%
# Plot the losses and accuracies at the end of all epochs
RNN_x_epochs = list(range(1, RNN_total_epochs + 1))
plt.figure(figsize=(7, 5))
plt.rcParams.update({'font.size': 11})

# Plot losses (dashed) and accuracies (solid)
plt.plot(RNN_x_epochs, RNN_train_losses, linestyle='--', label='RNN Training Loss')
plt.plot(RNN_x_epochs, RNN_val_losses, linestyle='--', label='RNN Validation Loss')
plt.plot(RNN_x_epochs, RNN_train_accuracies, label='RNN Training Accuracy')
plt.plot(RNN_x_epochs, RNN_val_accuracies, label='RNN Validation Accuracy')
plt.xlabel('RNN Epochs')
plt.ylabel('RNN Loss and Accuracy')
plt.title('RNN Training and Validation Losses/Accuracies for Sliced Time Samples')
plt.legend()

plt.tight_layout()
plt.savefig('eps/RNN_11_base_spks_class.eps')
plt.savefig('svg/RNN_11_base_spks_class.svg')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.5f}')
# Out:
# Test Accuracy: 0.88235

# %% [markdown]
# ##### Analysis RNN
# Validation accuracy is 0.8676 at 70 epochs. Test accuracy is 0.88235.

# %% [markdown]
# ##### Define LSTM

# %%
# chatgpt 3.5 generated code
# LSTM Model with Softmax
class LSTMWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(LSTMWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])  # Use only the last time step's output for classification
        return nn.functional.softmax(out, dim=1)  # Apply softmax activation

# %% [markdown]
# ##### Train LSTM: setup

# %%
# chatgpt 3.5 generated code
model = LSTMWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the LSTM and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code (this code is a copy of the RNN code)
# Training loop
# LSTM_total_epochs = number_of_epochs
LSTM_total_epochs = LSTM_number_of_epochs

# Lists to store training/validation losses and training/validation accuracies
LSTM_train_losses = []  
LSTM_val_losses = []    
LSTM_train_accuracies = []  
LSTM_val_accuracies = []    

for epoch in range(LSTM_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    LSTM_train_losses.append(average_train_loss)
    LSTM_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{LSTM_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Store validation loss and accuracy values
    LSTM_val_losses.append(average_val_loss)
    LSTM_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{LSTM_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch [1/70], Training Loss: 1.07965849, Training Accuracy: 0.4370
# Epoch [1/70], Validation Loss: 1.07977235, Validation Accuracy: 0.3088
# Epoch [2/70], Training Loss: 1.04150816, Training Accuracy: 0.4328
# Epoch [2/70], Validation Loss: 1.06279069, Validation Accuracy: 0.3088
# Epoch [3/70], Training Loss: 1.00429222, Training Accuracy: 0.5084
# Epoch [3/70], Validation Loss: 1.04411688, Validation Accuracy: 0.3529
# Epoch [4/70], Training Loss: 0.93109364, Training Accuracy: 0.6765
# Epoch [4/70], Validation Loss: 0.92092630, Validation Accuracy: 0.6471
# Epoch [5/70], Training Loss: 0.95948417, Training Accuracy: 0.5084
# Epoch [5/70], Validation Loss: 1.00464904, Validation Accuracy: 0.5000
# Epoch [6/70], Training Loss: 0.89626897, Training Accuracy: 0.6681
# Epoch [6/70], Validation Loss: 1.01435596, Validation Accuracy: 0.3824
# Epoch [7/70], Training Loss: 0.84741327, Training Accuracy: 0.7941
# Epoch [7/70], Validation Loss: 0.95411164, Validation Accuracy: 0.6912
# Epoch [8/70], Training Loss: 0.80762470, Training Accuracy: 0.8571
# Epoch [8/70], Validation Loss: 0.86867899, Validation Accuracy: 0.6912
# Epoch [9/70], Training Loss: 0.74064285, Training Accuracy: 0.8319
# Epoch [9/70], Validation Loss: 0.81905159, Validation Accuracy: 0.7059
# Epoch [10/70], Training Loss: 0.72378832, Training Accuracy: 0.8782
# Epoch [10/70], Validation Loss: 0.83484420, Validation Accuracy: 0.7647
# Epoch [11/70], Training Loss: 0.68465629, Training Accuracy: 0.9622
# Epoch [11/70], Validation Loss: 0.82034850, Validation Accuracy: 0.7206
# Epoch [12/70], Training Loss: 0.66145290, Training Accuracy: 0.9286
# Epoch [12/70], Validation Loss: 0.72404295, Validation Accuracy: 0.8824
# Epoch [13/70], Training Loss: 0.63085599, Training Accuracy: 0.9664
# Epoch [13/70], Validation Loss: 0.74584219, Validation Accuracy: 0.8382
# Epoch [14/70], Training Loss: 0.61535358, Training Accuracy: 0.9706
# Epoch [14/70], Validation Loss: 0.69252950, Validation Accuracy: 0.8824
# Epoch [15/70], Training Loss: 0.59685907, Training Accuracy: 0.9706
# Epoch [15/70], Validation Loss: 0.68280482, Validation Accuracy: 0.8971
# Epoch [16/70], Training Loss: 0.58497425, Training Accuracy: 0.9832
# Epoch [16/70], Validation Loss: 0.68072769, Validation Accuracy: 0.8971
# Epoch [17/70], Training Loss: 0.57753389, Training Accuracy: 0.9874
# Epoch [17/70], Validation Loss: 0.69065067, Validation Accuracy: 0.8676
# Epoch [18/70], Training Loss: 0.57324800, Training Accuracy: 0.9874
# Epoch [18/70], Validation Loss: 0.67436117, Validation Accuracy: 0.8971
# Epoch [19/70], Training Loss: 0.56938819, Training Accuracy: 0.9874
# Epoch [19/70], Validation Loss: 0.69063815, Validation Accuracy: 0.8676
# Epoch [20/70], Training Loss: 0.56641109, Training Accuracy: 0.9916
# Epoch [20/70], Validation Loss: 0.68415126, Validation Accuracy: 0.8676
# Epoch [21/70], Training Loss: 0.56288139, Training Accuracy: 0.9916
# Epoch [21/70], Validation Loss: 0.67109880, Validation Accuracy: 0.8676
# Epoch [22/70], Training Loss: 0.56154189, Training Accuracy: 0.9916
# Epoch [22/70], Validation Loss: 0.69953460, Validation Accuracy: 0.8529
# Epoch [23/70], Training Loss: 0.55929559, Training Accuracy: 0.9958
# Epoch [23/70], Validation Loss: 0.69108045, Validation Accuracy: 0.8824
# Epoch [24/70], Training Loss: 0.55764214, Training Accuracy: 0.9958
# Epoch [24/70], Validation Loss: 0.67732224, Validation Accuracy: 0.8824
# Epoch [25/70], Training Loss: 0.55709715, Training Accuracy: 0.9958
# Epoch [25/70], Validation Loss: 0.74631336, Validation Accuracy: 0.7941
# Epoch [26/70], Training Loss: 0.55707316, Training Accuracy: 0.9958
# Epoch [26/70], Validation Loss: 0.67816052, Validation Accuracy: 0.8676
# Epoch [27/70], Training Loss: 0.55874284, Training Accuracy: 0.9916
# Epoch [27/70], Validation Loss: 0.68543866, Validation Accuracy: 0.8676
# Epoch [28/70], Training Loss: 0.55728804, Training Accuracy: 0.9958
# Epoch [28/70], Validation Loss: 0.70580053, Validation Accuracy: 0.8676
# Epoch [29/70], Training Loss: 0.55575111, Training Accuracy: 1.0000
# Epoch [29/70], Validation Loss: 0.68753108, Validation Accuracy: 0.8676
# Epoch [30/70], Training Loss: 0.55436521, Training Accuracy: 1.0000
# Epoch [30/70], Validation Loss: 0.68699169, Validation Accuracy: 0.8676
# Epoch [31/70], Training Loss: 0.55312904, Training Accuracy: 1.0000
# Epoch [31/70], Validation Loss: 0.68774846, Validation Accuracy: 0.8676
# Epoch [32/70], Training Loss: 0.55274458, Training Accuracy: 1.0000
# Epoch [32/70], Validation Loss: 0.69180846, Validation Accuracy: 0.8676
# Epoch [33/70], Training Loss: 0.55246054, Training Accuracy: 1.0000
# Epoch [33/70], Validation Loss: 0.68733332, Validation Accuracy: 0.8676
# Epoch [34/70], Training Loss: 0.55229998, Training Accuracy: 1.0000
# Epoch [34/70], Validation Loss: 0.66264084, Validation Accuracy: 0.8824
# Epoch [35/70], Training Loss: 0.55221251, Training Accuracy: 1.0000
# Epoch [35/70], Validation Loss: 0.65119922, Validation Accuracy: 0.8971
# Epoch [36/70], Training Loss: 0.55216093, Training Accuracy: 1.0000
# Epoch [36/70], Validation Loss: 0.65835175, Validation Accuracy: 0.8971
# Epoch [37/70], Training Loss: 0.55210371, Training Accuracy: 1.0000
# Epoch [37/70], Validation Loss: 0.66264656, Validation Accuracy: 0.8824
# Epoch [38/70], Training Loss: 0.55204936, Training Accuracy: 1.0000
# Epoch [38/70], Validation Loss: 0.65908608, Validation Accuracy: 0.8971
# Epoch [39/70], Training Loss: 0.55200757, Training Accuracy: 1.0000
# Epoch [39/70], Validation Loss: 0.65609273, Validation Accuracy: 0.8971
# Epoch [40/70], Training Loss: 0.55197557, Training Accuracy: 1.0000
# Epoch [40/70], Validation Loss: 0.65450233, Validation Accuracy: 0.8971
# Epoch [41/70], Training Loss: 0.55194767, Training Accuracy: 1.0000
# Epoch [41/70], Validation Loss: 0.65574449, Validation Accuracy: 0.8971
# Epoch [42/70], Training Loss: 0.55192096, Training Accuracy: 1.0000
# Epoch [42/70], Validation Loss: 0.65681633, Validation Accuracy: 0.8971
# Epoch [43/70], Training Loss: 0.55189851, Training Accuracy: 1.0000
# Epoch [43/70], Validation Loss: 0.65576154, Validation Accuracy: 0.8971
# Epoch [44/70], Training Loss: 0.55187775, Training Accuracy: 1.0000
# Epoch [44/70], Validation Loss: 0.65589938, Validation Accuracy: 0.8971
# Epoch [45/70], Training Loss: 0.55185934, Training Accuracy: 1.0000
# Epoch [45/70], Validation Loss: 0.65781334, Validation Accuracy: 0.8971
# Epoch [46/70], Training Loss: 0.55184151, Training Accuracy: 1.0000
# Epoch [46/70], Validation Loss: 0.65744773, Validation Accuracy: 0.8971
# Epoch [47/70], Training Loss: 0.55182518, Training Accuracy: 1.0000
# Epoch [47/70], Validation Loss: 0.65898550, Validation Accuracy: 0.8971
# Epoch [48/70], Training Loss: 0.55181134, Training Accuracy: 1.0000
# Epoch [48/70], Validation Loss: 0.65963441, Validation Accuracy: 0.8824
# Epoch [49/70], Training Loss: 0.55179751, Training Accuracy: 1.0000
# Epoch [49/70], Validation Loss: 0.65786386, Validation Accuracy: 0.8971
# Epoch [50/70], Training Loss: 0.55178444, Training Accuracy: 1.0000
# Epoch [50/70], Validation Loss: 0.65767002, Validation Accuracy: 0.8971
# Epoch [51/70], Training Loss: 0.55177212, Training Accuracy: 1.0000
# Epoch [51/70], Validation Loss: 0.65778717, Validation Accuracy: 0.8971
# Epoch [52/70], Training Loss: 0.55176130, Training Accuracy: 1.0000
# Epoch [52/70], Validation Loss: 0.65766585, Validation Accuracy: 0.8971
# Epoch [53/70], Training Loss: 0.55175054, Training Accuracy: 1.0000
# Epoch [53/70], Validation Loss: 0.65854880, Validation Accuracy: 0.8824
# Epoch [54/70], Training Loss: 0.55174061, Training Accuracy: 1.0000
# Epoch [54/70], Validation Loss: 0.65865624, Validation Accuracy: 0.8824
# Epoch [55/70], Training Loss: 0.55173129, Training Accuracy: 1.0000
# Epoch [55/70], Validation Loss: 0.65650657, Validation Accuracy: 0.9118
# Epoch [56/70], Training Loss: 0.55172222, Training Accuracy: 1.0000
# Epoch [56/70], Validation Loss: 0.65811110, Validation Accuracy: 0.8824
# Epoch [57/70], Training Loss: 0.55171417, Training Accuracy: 1.0000
# Epoch [57/70], Validation Loss: 0.65652043, Validation Accuracy: 0.9118
# Epoch [58/70], Training Loss: 0.55170632, Training Accuracy: 1.0000
# Epoch [58/70], Validation Loss: 0.65782496, Validation Accuracy: 0.8971
# Epoch [59/70], Training Loss: 0.55169863, Training Accuracy: 1.0000
# Epoch [59/70], Validation Loss: 0.65755635, Validation Accuracy: 0.8971
# Epoch [60/70], Training Loss: 0.55169123, Training Accuracy: 1.0000
# Epoch [60/70], Validation Loss: 0.65604344, Validation Accuracy: 0.9118
# Epoch [61/70], Training Loss: 0.55168441, Training Accuracy: 1.0000
# Epoch [61/70], Validation Loss: 0.65717620, Validation Accuracy: 0.8971
# Epoch [62/70], Training Loss: 0.55167804, Training Accuracy: 1.0000
# Epoch [62/70], Validation Loss: 0.65820298, Validation Accuracy: 0.8971
# Epoch [63/70], Training Loss: 0.55167162, Training Accuracy: 1.0000
# Epoch [63/70], Validation Loss: 0.65725827, Validation Accuracy: 0.8971
# Epoch [64/70], Training Loss: 0.55166572, Training Accuracy: 1.0000
# Epoch [64/70], Validation Loss: 0.65855977, Validation Accuracy: 0.8971
# Epoch [65/70], Training Loss: 0.55166027, Training Accuracy: 1.0000
# Epoch [65/70], Validation Loss: 0.65783116, Validation Accuracy: 0.8971
# Epoch [66/70], Training Loss: 0.55165484, Training Accuracy: 1.0000
# Epoch [66/70], Validation Loss: 0.65817037, Validation Accuracy: 0.8971
# Epoch [67/70], Training Loss: 0.55164969, Training Accuracy: 1.0000
# Epoch [67/70], Validation Loss: 0.65867537, Validation Accuracy: 0.8971
# Epoch [68/70], Training Loss: 0.55164495, Training Accuracy: 1.0000
# Epoch [68/70], Validation Loss: 0.65822250, Validation Accuracy: 0.8971
# Epoch [69/70], Training Loss: 0.55164016, Training Accuracy: 1.0000
# Epoch [69/70], Validation Loss: 0.65902632, Validation Accuracy: 0.8824
# Epoch [70/70], Training Loss: 0.55163553, Training Accuracy: 1.0000
# Epoch [70/70], Validation Loss: 0.65822116, Validation Accuracy: 0.8971

# %%
# Plot the losses and accuracies at the end of all epochs
LSTM_x_epochs = list(range(1, LSTM_total_epochs + 1))
plt.figure(figsize=(7, 5))
plt.rcParams.update({'font.size': 11})

# Plot losses (dashed) and accuracies (solid)
plt.plot(LSTM_x_epochs, LSTM_train_losses, linestyle='--', label='LSTM Training Loss')
plt.plot(LSTM_x_epochs, LSTM_val_losses, linestyle='--', label='LSTM Validation Loss')
plt.plot(LSTM_x_epochs, LSTM_train_accuracies, label='LSTM Training Accuracy')
plt.plot(LSTM_x_epochs, LSTM_val_accuracies, label='LSTM Validation Accuracy')
plt.xlabel('LSTM Epochs')
plt.ylabel('LSTM Loss and Accuracy')
plt.title('LSTM Training and Validation Losses/Accuracies for Sliced Time Samples')
plt.legend()

plt.tight_layout()
plt.savefig('eps/LSTM_11_base_spks_class.eps')
plt.savefig('svg/LSTM_11_base_spks_class.svg')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.5f}')
# Out:
# Test Accuracy: 0.85294

# %% [markdown]
# ##### Analysis LSTM
# Validation accuracy is 0.8971 at 70 epochs. Test accuracy is 0.85294.

# %% [markdown]
# ##### Define GRU

# %%
# chatgpt 3.5 generated code
# GRU Model with Softmax
class GRUWithSoftmax(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(GRUWithSoftmax, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.gru(x, h0)
        out = self.fc(out[:, -1, :])  # Use only the last time step's output for classification
        return nn.functional.softmax(out, dim=1)  # Apply softmax activation

# %% [markdown]
# ##### Train GRU: setup

# %%
# chatgpt 3.5 generated code
model = GRUWithSoftmax(input_size, hidden_size, output_size, num_layers).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the GRU and plot training and validation losses and accuracies
# Note that the trained model seems to remain resident on the graphics card unless we restart the notebook.

# %%
# chatgpt 3.5 generated code (this code is a copy of the RNN code)
# Training loop
# GRU_total_epochs = number_of_epochs
GRU_total_epochs = GRU_number_of_epochs

# Lists to store training/validation losses and training/validation accuracies
GRU_train_losses = []  
GRU_val_losses = []    
GRU_train_accuracies = []  
GRU_val_accuracies = []    

for epoch in range(GRU_total_epochs):
    model.train()
    total_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for inputs, one_hot_labels in train_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update the total training loss for this epoch
        total_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
        total_train += one_hot_labels.size(0)
    
    # Calculate average training loss and accuracy for this epoch
    average_train_loss = total_loss / len(train_loader)
    train_accuracy = correct_train / total_train
    
    # Store training loss and accuracy values
    GRU_train_losses.append(average_train_loss)
    GRU_train_accuracies.append(train_accuracy)
    
    # Print the training loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{GRU_total_epochs}], Training Loss: {average_train_loss:.8f}, Training Accuracy: {train_accuracy:.4f}')
    
    # Validation loop
    model.eval()
    total_val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for inputs, one_hot_labels in val_loader:
            inputs = inputs.to(device)
            one_hot_labels = one_hot_labels.to(device)
            
            # Forward pass (validation)
            outputs = model(inputs)
            loss = criterion(outputs, torch.argmax(one_hot_labels, dim=1))
            
            # Update the total validation loss for this epoch
            total_val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == torch.argmax(one_hot_labels, dim=1)).sum().item()
            total_val += one_hot_labels.size(0)
    
    # Calculate average validation loss and accuracy for this epoch
    average_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val
    
    # Store validation loss and accuracy values
    GRU_val_losses.append(average_val_loss)
    GRU_val_accuracies.append(val_accuracy)
    
    # Print the validation loss and accuracy for this epoch
    print(f'Epoch [{epoch+1}/{GRU_total_epochs}], Validation Loss: {average_val_loss:.8f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch [1/70], Training Loss: 1.06967264, Training Accuracy: 0.3950
# Epoch [1/70], Validation Loss: 1.07179099, Validation Accuracy: 0.2941
# Epoch [2/70], Training Loss: 1.02496640, Training Accuracy: 0.4370
# Epoch [2/70], Validation Loss: 1.07337540, Validation Accuracy: 0.3088
# Epoch [3/70], Training Loss: 0.98999724, Training Accuracy: 0.6218
# Epoch [3/70], Validation Loss: 1.03721356, Validation Accuracy: 0.4412
# Epoch [4/70], Training Loss: 0.95248083, Training Accuracy: 0.7647
# Epoch [4/70], Validation Loss: 1.02865794, Validation Accuracy: 0.4853
# Epoch [5/70], Training Loss: 0.89939122, Training Accuracy: 0.7773
# Epoch [5/70], Validation Loss: 1.00547978, Validation Accuracy: 0.5294
# Epoch [6/70], Training Loss: 0.81778904, Training Accuracy: 0.7899
# Epoch [6/70], Validation Loss: 0.88179609, Validation Accuracy: 0.7206
# Epoch [7/70], Training Loss: 0.74593396, Training Accuracy: 0.7899
# Epoch [7/70], Validation Loss: 0.91848958, Validation Accuracy: 0.5735
# Epoch [8/70], Training Loss: 0.71644892, Training Accuracy: 0.8529
# Epoch [8/70], Validation Loss: 0.86243185, Validation Accuracy: 0.7353
# Epoch [9/70], Training Loss: 0.69311524, Training Accuracy: 0.9244
# Epoch [9/70], Validation Loss: 0.88295078, Validation Accuracy: 0.7059
# Epoch [10/70], Training Loss: 0.64357335, Training Accuracy: 0.9664
# Epoch [10/70], Validation Loss: 0.77029893, Validation Accuracy: 0.7941
# Epoch [11/70], Training Loss: 0.63047916, Training Accuracy: 0.9412
# Epoch [11/70], Validation Loss: 0.79941094, Validation Accuracy: 0.7647
# Epoch [12/70], Training Loss: 0.60606169, Training Accuracy: 0.9706
# Epoch [12/70], Validation Loss: 0.76902565, Validation Accuracy: 0.8235
# Epoch [13/70], Training Loss: 0.58957078, Training Accuracy: 0.9790
# Epoch [13/70], Validation Loss: 0.70979160, Validation Accuracy: 0.8529
# Epoch [14/70], Training Loss: 0.58177093, Training Accuracy: 0.9790
# Epoch [14/70], Validation Loss: 0.72546041, Validation Accuracy: 0.8382
# Epoch [15/70], Training Loss: 0.56834498, Training Accuracy: 1.0000
# Epoch [15/70], Validation Loss: 0.73462933, Validation Accuracy: 0.8088
# Epoch [16/70], Training Loss: 0.56153507, Training Accuracy: 1.0000
# Epoch [16/70], Validation Loss: 0.70356184, Validation Accuracy: 0.8529
# Epoch [17/70], Training Loss: 0.55750923, Training Accuracy: 1.0000
# Epoch [17/70], Validation Loss: 0.69154161, Validation Accuracy: 0.8529
# Epoch [18/70], Training Loss: 0.55510539, Training Accuracy: 1.0000
# Epoch [18/70], Validation Loss: 0.69801804, Validation Accuracy: 0.8824
# Epoch [19/70], Training Loss: 0.55438472, Training Accuracy: 1.0000
# Epoch [19/70], Validation Loss: 0.69361183, Validation Accuracy: 0.8676
# Epoch [20/70], Training Loss: 0.55352710, Training Accuracy: 1.0000
# Epoch [20/70], Validation Loss: 0.69080874, Validation Accuracy: 0.8676
# Epoch [21/70], Training Loss: 0.55322393, Training Accuracy: 1.0000
# Epoch [21/70], Validation Loss: 0.68942645, Validation Accuracy: 0.8676
# Epoch [22/70], Training Loss: 0.55293985, Training Accuracy: 1.0000
# Epoch [22/70], Validation Loss: 0.68901256, Validation Accuracy: 0.8676
# Epoch [23/70], Training Loss: 0.55273000, Training Accuracy: 1.0000
# Epoch [23/70], Validation Loss: 0.68822086, Validation Accuracy: 0.8676
# Epoch [24/70], Training Loss: 0.55257304, Training Accuracy: 1.0000
# Epoch [24/70], Validation Loss: 0.68735385, Validation Accuracy: 0.8676
# Epoch [25/70], Training Loss: 0.55246357, Training Accuracy: 1.0000
# Epoch [25/70], Validation Loss: 0.69719803, Validation Accuracy: 0.8529
# Epoch [26/70], Training Loss: 0.55237697, Training Accuracy: 1.0000
# Epoch [26/70], Validation Loss: 0.69693398, Validation Accuracy: 0.8529
# Epoch [27/70], Training Loss: 0.55229819, Training Accuracy: 1.0000
# Epoch [27/70], Validation Loss: 0.69287184, Validation Accuracy: 0.8529
# Epoch [28/70], Training Loss: 0.55223203, Training Accuracy: 1.0000
# Epoch [28/70], Validation Loss: 0.69497919, Validation Accuracy: 0.8529
# Epoch [29/70], Training Loss: 0.55218161, Training Accuracy: 1.0000
# Epoch [29/70], Validation Loss: 0.69453681, Validation Accuracy: 0.8529
# Epoch [30/70], Training Loss: 0.55212931, Training Accuracy: 1.0000
# Epoch [30/70], Validation Loss: 0.69481704, Validation Accuracy: 0.8529
# Epoch [31/70], Training Loss: 0.55209071, Training Accuracy: 1.0000
# Epoch [31/70], Validation Loss: 0.69473431, Validation Accuracy: 0.8529
# Epoch [32/70], Training Loss: 0.55204809, Training Accuracy: 1.0000
# Epoch [32/70], Validation Loss: 0.69464037, Validation Accuracy: 0.8529
# Epoch [33/70], Training Loss: 0.55201625, Training Accuracy: 1.0000
# Epoch [33/70], Validation Loss: 0.69231549, Validation Accuracy: 0.8529
# Epoch [34/70], Training Loss: 0.55198751, Training Accuracy: 1.0000
# Epoch [34/70], Validation Loss: 0.69345737, Validation Accuracy: 0.8676
# Epoch [35/70], Training Loss: 0.55195493, Training Accuracy: 1.0000
# Epoch [35/70], Validation Loss: 0.69313541, Validation Accuracy: 0.8529
# Epoch [36/70], Training Loss: 0.55193021, Training Accuracy: 1.0000
# Epoch [36/70], Validation Loss: 0.69171032, Validation Accuracy: 0.8529
# Epoch [37/70], Training Loss: 0.55190637, Training Accuracy: 1.0000
# Epoch [37/70], Validation Loss: 0.69038504, Validation Accuracy: 0.8529
# Epoch [38/70], Training Loss: 0.55188604, Training Accuracy: 1.0000
# Epoch [38/70], Validation Loss: 0.69116870, Validation Accuracy: 0.8676
# Epoch [39/70], Training Loss: 0.55186498, Training Accuracy: 1.0000
# Epoch [39/70], Validation Loss: 0.69006029, Validation Accuracy: 0.8676
# Epoch [40/70], Training Loss: 0.55184492, Training Accuracy: 1.0000
# Epoch [40/70], Validation Loss: 0.69003102, Validation Accuracy: 0.8676
# Epoch [41/70], Training Loss: 0.55182570, Training Accuracy: 1.0000
# Epoch [41/70], Validation Loss: 0.69088537, Validation Accuracy: 0.8676
# Epoch [42/70], Training Loss: 0.55181170, Training Accuracy: 1.0000
# Epoch [42/70], Validation Loss: 0.68940872, Validation Accuracy: 0.8676
# Epoch [43/70], Training Loss: 0.55179642, Training Accuracy: 1.0000
# Epoch [43/70], Validation Loss: 0.68273205, Validation Accuracy: 0.8824
# Epoch [44/70], Training Loss: 0.55178339, Training Accuracy: 1.0000
# Epoch [44/70], Validation Loss: 0.68630406, Validation Accuracy: 0.8676
# Epoch [45/70], Training Loss: 0.55176825, Training Accuracy: 1.0000
# Epoch [45/70], Validation Loss: 0.68404195, Validation Accuracy: 0.8676
# Epoch [46/70], Training Loss: 0.55175552, Training Accuracy: 1.0000
# Epoch [46/70], Validation Loss: 0.68086281, Validation Accuracy: 0.8824
# Epoch [47/70], Training Loss: 0.55174614, Training Accuracy: 1.0000
# Epoch [47/70], Validation Loss: 0.68025950, Validation Accuracy: 0.8824
# Epoch [48/70], Training Loss: 0.55173494, Training Accuracy: 1.0000
# Epoch [48/70], Validation Loss: 0.67987791, Validation Accuracy: 0.8824
# Epoch [49/70], Training Loss: 0.55172569, Training Accuracy: 1.0000
# Epoch [49/70], Validation Loss: 0.67953262, Validation Accuracy: 0.8824
# Epoch [50/70], Training Loss: 0.55171727, Training Accuracy: 1.0000
# Epoch [50/70], Validation Loss: 0.67813146, Validation Accuracy: 0.8824
# Epoch [51/70], Training Loss: 0.55170910, Training Accuracy: 1.0000
# Epoch [51/70], Validation Loss: 0.67759192, Validation Accuracy: 0.8824
# Epoch [52/70], Training Loss: 0.55170112, Training Accuracy: 1.0000
# Epoch [52/70], Validation Loss: 0.67767930, Validation Accuracy: 0.8824
# Epoch [53/70], Training Loss: 0.55169415, Training Accuracy: 1.0000
# Epoch [53/70], Validation Loss: 0.67840537, Validation Accuracy: 0.8824
# Epoch [54/70], Training Loss: 0.55168675, Training Accuracy: 1.0000
# Epoch [54/70], Validation Loss: 0.67768925, Validation Accuracy: 0.8824
# Epoch [55/70], Training Loss: 0.55168011, Training Accuracy: 1.0000
# Epoch [55/70], Validation Loss: 0.67748961, Validation Accuracy: 0.8824
# Epoch [56/70], Training Loss: 0.55167363, Training Accuracy: 1.0000
# Epoch [56/70], Validation Loss: 0.67704403, Validation Accuracy: 0.8824
# Epoch [57/70], Training Loss: 0.55166735, Training Accuracy: 1.0000
# Epoch [57/70], Validation Loss: 0.67765459, Validation Accuracy: 0.8824
# Epoch [58/70], Training Loss: 0.55166261, Training Accuracy: 1.0000
# Epoch [58/70], Validation Loss: 0.67786339, Validation Accuracy: 0.8824
# Epoch [59/70], Training Loss: 0.55165627, Training Accuracy: 1.0000
# Epoch [59/70], Validation Loss: 0.67809755, Validation Accuracy: 0.8824
# Epoch [60/70], Training Loss: 0.55165077, Training Accuracy: 1.0000
# Epoch [60/70], Validation Loss: 0.67789629, Validation Accuracy: 0.8824
# Epoch [61/70], Training Loss: 0.55164580, Training Accuracy: 1.0000
# Epoch [61/70], Validation Loss: 0.67769969, Validation Accuracy: 0.8824
# Epoch [62/70], Training Loss: 0.55164093, Training Accuracy: 1.0000
# Epoch [62/70], Validation Loss: 0.67733908, Validation Accuracy: 0.8824
# Epoch [63/70], Training Loss: 0.55163638, Training Accuracy: 1.0000
# Epoch [63/70], Validation Loss: 0.67735654, Validation Accuracy: 0.8824
# Epoch [64/70], Training Loss: 0.55163183, Training Accuracy: 1.0000
# Epoch [64/70], Validation Loss: 0.67817515, Validation Accuracy: 0.8824
# Epoch [65/70], Training Loss: 0.55162782, Training Accuracy: 1.0000
# Epoch [65/70], Validation Loss: 0.67891592, Validation Accuracy: 0.8676
# Epoch [66/70], Training Loss: 0.55162351, Training Accuracy: 1.0000
# Epoch [66/70], Validation Loss: 0.68790907, Validation Accuracy: 0.8676
# Epoch [67/70], Training Loss: 0.55161954, Training Accuracy: 1.0000
# Epoch [67/70], Validation Loss: 0.68846554, Validation Accuracy: 0.8529
# Epoch [68/70], Training Loss: 0.55161538, Training Accuracy: 1.0000
# Epoch [68/70], Validation Loss: 0.69247299, Validation Accuracy: 0.8529
# Epoch [69/70], Training Loss: 0.55161205, Training Accuracy: 1.0000
# Epoch [69/70], Validation Loss: 0.69367000, Validation Accuracy: 0.8529
# Epoch [70/70], Training Loss: 0.55160845, Training Accuracy: 1.0000
# Epoch [70/70], Validation Loss: 0.69367197, Validation Accuracy: 0.8529

# %%
# Plot the losses and accuracies at the end of all epochs
GRU_x_epochs = list(range(1, GRU_total_epochs + 1))
plt.figure(figsize=(7, 5))
plt.rcParams.update({'font.size': 11})

# Plot losses (dashed) and accuracies (solid)
plt.plot(GRU_x_epochs, GRU_train_losses, linestyle='--', label='GRU Training Loss')
plt.plot(GRU_x_epochs, GRU_val_losses, linestyle='--', label='GRU Validation Loss')
plt.plot(GRU_x_epochs, GRU_train_accuracies, label='GRU Training Accuracy')
plt.plot(GRU_x_epochs, GRU_val_accuracies, label='GRU Validation Accuracy')
plt.xlabel('GRU Epochs')
plt.ylabel('GRU Loss and Accuracy')
plt.title('GRU Training and Validation Losses/Accuracies for Sliced Time Samples')
plt.legend()

plt.tight_layout()
plt.savefig('eps/GRU_11_base_spks_class.eps')
plt.savefig('svg/GRU_11_base_spks_class.svg')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ##### Testing

# %%
# chatgpt 3.5 generated code
# Test the model
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, one_hot_labels in test_loader:
        inputs = inputs.to(device)
        one_hot_labels = one_hot_labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        _, labels = torch.max(one_hot_labels, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

    accuracy = total_correct / total_samples
    print(f'Test Accuracy: {accuracy:.5f}')
# Out:
# Test Accuracy: 0.88235

# %% [markdown]
# ##### Analysis GRU
# Validation accuracy is 0.8529 at 70 epochs. Test accuracy is 0.88235.

# %% [markdown]
# ##### Final notes
# |  | epochs | validation accuracy (%) | test accuracy (%) | time (s) |
# | --- | --- | ---| --- | --- |
# | RNN | 70 | 86.76 | 88.235 | 1.4 |
# | LSTM | 70 | 89.71 | 85.294 | 1.8 |
# | GRU | 70 | 85.29 | 88.235 | 1.5 |
#
# The RNN, LSTM and GRU performed equally well. What is not shown in the figures is how the different methods react when approaching their training limits. The RNN validation accuracy flattens out while the LSTM and GRU both jump to lower validation accuracy at higher epochs.
#
# When the dataset was not shuffled all methods showed lower test accuracies, with the RNN being the worst at about 53%. This significant (35%) jump in performance for RNN dataset shuffling required an explanation.
#
# Generally we have an expectation of uniformity in the trials data of the dataset when we assume data leakage must be present to explain such a large variance in test accuracy. However, shuffling prior to slicing into training, validation and test sets cannot introduce data leakage because no results from training were carried over to the selection of data from the dataset. The test set was always held in reserve to be evaluated after training.
#
# The uniformity hypothesis, however, is rarely true for neural data recordings. For the Steinmetz `spks` dataset, 340 trials were recorded in one session. We can expect to see reductions in probe sensitivity and mouse responses over time, and therefore trials, as the recording session progesses. When the trials are not shuffled the first 238 trials go towards the training set, the next 68 trials go into the validation set and the last 32 trials go into the test set. Therefore the test set is heavily biased towards reduced probe sensitivity effects and fatigued mouse behaviours.
#
# By shuffling the dataset before slicing into training, validation and test sets we spread out the variance introduced by reduced probe sensitivity and mouse fatigue over the complete trial set, thereby increasing training ability and validation and test accuracies.
#
# Dropout was tried, but there was a small reduction in accuracies. There was a warning that dropout should not be applied to a single layer (which is true for the RNN, LSTM, or GRU methods used in this notebook), so dropout was dropped.
